# %%
#增加交叉特征
#Score: Score: 0.89048
#使用5折交叉验证,增加scale_pos_weight参数
#Score: Score: 0.89292
#增加G/L
#Score: 0.88696
#交叉特征增加location_type，不使用G/L
#Score: 0.88777
#增加incident_location_type、incident_location_street、policy_bind_date_year&auto_year_diff、incident_date_year&auto_year_diff、duration、出险情况2、出险车信息
#Score: 0.88804
#使用insured_zip，训练使用earlystop，LGBM
#Score: 0.89861
#使用insured_zip, 7折lgbm
#Score: 0.88845
#调整'colsample_bytree': 0.8，7折lgbm
#Score:0.88370

#lgbm
#train、test不合并做StandScaler变换，先做train的fit_trans，在做test的trans
#Score: 0.89319

#K折lgbm
#train、test不合并做StandScaler变换，先做train的fit_trans，在做test的trans
#Score: 0.89129

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib # 注意这个也要import一次
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score, mean_squared_error, roc_curve, auc
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")

# %%
#数据加载
train_data = pd.read_csv('./data/train.csv')
test_data = pd.read_csv('./data/test.csv')

# %%
datas = pd.concat((train_data, test_data))
datas.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 数据探索

# %%
cat_columns = datas.select_dtypes(include=['O']).columns
numerical_columns = datas.select_dtypes(exclude=['O']).columns

# %%
col_name = []
unique_value = []
for col in cat_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_cat_col_unique = pd.DataFrame()
df_cat_col_unique['col_name'] = col_name
df_cat_col_unique['unique_value'] = unique_value
df_cat_col_unique = df_cat_col_unique.sort_values('unique_value', ascending= False)
# df_cat_col_unique

# %%
col_name = []
unique_value = []
for col in numerical_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_numerical_col_unique = pd.DataFrame()
df_numerical_col_unique['col_name'] = col_name
df_numerical_col_unique['unique_value'] = unique_value
df_numerical_col_unique = df_numerical_col_unique.sort_values('unique_value', ascending= False)
# df_numerical_col_unique

# %%
# df_cat_col_unique
df_numerical_col_unique
# Out:
#                        col_name  unique_value
# 2                 policy_number          1000
# 6                   insured_zip           995
# 4         policy_annual_premium           991
# 13           total_claim_amount           763
# 16                vehicle_claim           726
# 14                 injury_claim           638
# 15               property_claim           626
# 0            months_as_customer           391
# 8                  capital-loss           354
# 7                 capital-gains           338
# 1                           age            46
# 9      incident_hour_of_the_day            24
# 17                    auto_year            21
# 5                umbrella_limit            11
# 10  number_of_vehicles_involved             4
# 12                    witnesses             4
# 11              bodily_injuries             3
# 3             policy_deductable             3
# 18               fraud_reported             2
# 19                         _c39             0

# %% [markdown]
# ## 特征工程

# %% [markdown]
# #### 标签编码 policy_bind_date、incident_date

# %%
datas['policy_bind_date'] = pd.to_datetime(datas['policy_bind_date'])
datas['incident_date'] = pd.to_datetime(datas['incident_date'])

# %%
#时间多尺度
datas['policy_bind_date_year'] = datas['policy_bind_date'].dt.year
datas['policy_bind_date_month'] = datas['policy_bind_date'].dt.month
datas['policy_bind_date_day'] = datas['policy_bind_date'].dt.day
datas['policy_bind_date_weekday'] = datas['policy_bind_date'].dt.weekday

datas['incident_date_year'] = datas['incident_date'].dt.year
datas['incident_date_month'] = datas['incident_date'].dt.month
datas['incident_date_day'] = datas['incident_date'].dt.day
datas['incident_date_weekday'] = datas['incident_date'].dt.weekday

# %%
# 查看最小、最大日期
# datas.policy_bind_date.min() #1990-01-08
# datas.policy_bind_date.max() #2015-02-22

# datas.incident_date.min() #2015-01-01
# datas.incident_date.max() #2015-03-01

# %%
base_date = datas.policy_bind_date.min()
#转换为diff
datas['policy_bind_date_diff'] = (datas['policy_bind_date'] - base_date).dt.days
datas['incident_date_diff'] = (datas['incident_date'] - base_date).dt.days
datas['incident_date&policy_bind_date_diff'] = datas['incident_date_diff'] - datas['policy_bind_date_diff']

# %% [markdown]
# #### 构造交叉业务特征

# %%
datas['injury_claim_pct'] = datas['injury_claim']/datas['total_claim_amount']
datas['property_claim_pct'] = datas['property_claim']/datas['total_claim_amount']
datas['vehicle_claim_pct'] = datas['vehicle_claim']/datas['total_claim_amount']

# %%
datas['is_injury_claim'] = datas['injury_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_property_claim'] = datas['property_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_vehicle_claim'] = datas['vehicle_claim'].apply(lambda x: '1' if x >0 else '0')

# %%
#出险情况1
datas['incident_type_&_is_injury_claim'] = datas['incident_type'] + '_' + datas['is_injury_claim']
datas['incident_type_&_is_property_claim'] = datas['incident_type'] + '_' + datas['is_property_claim']
datas['incident_type_&_is_vehicle_claim'] = datas['incident_type'] + '_' + datas['is_vehicle_claim']

datas['collision_type_&_is_injury_claim'] = datas['collision_type'] + '_' + datas['is_injury_claim']
datas['collision_type_&_is_property_claim'] = datas['collision_type'] + '_' + datas['is_property_claim']
datas['collision_type_&_is_vehicle_claim'] = datas['collision_type'] + '_' + datas['is_vehicle_claim']

# %%
datas['umbrella_limit_2_total_claim_amount'] = datas['umbrella_limit']/datas['total_claim_amount']

# %%
# datas['G/L'] = datas['capital-gains'] + datas['capital-loss']

# %%
datas['incident_location_type'] = datas['incident_location'].apply(lambda x: x.split()[-1])
datas['incident_location_street'] = datas['incident_location'].apply(lambda x: ' '.join(x.split()[-2:]))

# %%
#购车年份与投保年份之差
datas['policy_bind_date_year&auto_year_diff'] = datas['policy_bind_date_year'] - datas['auto_year']

#购车年份与出险年份之差
datas['incident_date_year&auto_year_diff'] = datas['incident_date_year'] - datas['auto_year']

#成为客户的时长与购报后出险时长之差
datas['duration'] = round((datas['incident_date'] - datas['policy_bind_date']).dt.days/30) - datas['months_as_customer']

# %%
#出险情况2
datas['incident_type&collision_type'] = (datas['incident_type'] + "_" + datas['collision_type'])

datas['incident_type&incident_severity'] = (datas['incident_type'] + "_" + datas['incident_severity'])
datas['collision_type&incident_severity'] = (datas['collision_type'] + "_" + datas['incident_severity'])

datas['incident_type&bodily_injuries'] = (datas['incident_type'] + "_" + datas['bodily_injuries'].apply(lambda x : str(x)))
datas['collision_type&bodily_injuries'] = (datas['collision_type'] + "_" + datas['bodily_injuries'].apply(lambda x : str(x)))

datas['incident_type&property_damage'] = (datas['incident_type'] + "_" + datas['property_damage'])
datas['collision_type&property_damage'] = (datas['collision_type'] + "_" + datas['property_damage'])

datas['incident_type&collision_type&incident_severity&bodily_injuries&property_damage'] = (datas['incident_type'] + "_" + datas['collision_type'] + "_" + datas['incident_severity'] 
 + "_" + datas['bodily_injuries'].apply(lambda x : str(x)) + "_" + datas['property_damage'])

# %%
#出险车信息
datas['auto_make&auto_model'] = datas['auto_make'] + "_" + datas['auto_model']

# %%
# datas[['incident_type', 'collision_type', 'bodily_injuries', 'incident_severity', 'property_damage', 'policy_csl', 'policy_annual_premium', 'umbrella_limit', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'capital-gains', 'capital-loss']][datas['fraud_reported'] > 0]

# %%
#检查单个特征
# datas.property_damage.nunique()
# datas['property_damage'].value_counts()

# %%
datas.drop(['policy_bind_date', 'incident_date', '_c39', 'incident_location', 'policy_number', 'auto_make', 'auto_model'], axis= 1, inplace=True)
#下次保留insured_zip试试

# %%
numerical_columns = datas.select_dtypes(exclude=['O']).columns
cat_columns = datas.select_dtypes(include=['O']).columns

# %%
numerical_columns = numerical_columns.delete(numerical_columns.get_loc('fraud_reported'))

# %%
import math

# %%
df_melted = pd.melt(datas[numerical_columns].join(pd.DataFrame(['Train' if not math.isnan(label) else 'Test' 
                                                                for label in datas['fraud_reported']], index=datas.index, columns=['Source'])
                                                  , how='left'), id_vars= ['Source'],
                    )

# %%
numerical_columns
# Out:
# Index(['months_as_customer', 'age', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year', 'policy_bind_date_year', 'policy_bind_date_month',
#        'policy_bind_date_day', 'policy_bind_date_weekday',
#        'incident_date_year', 'incident_date_month', 'incident_date_day',
#        'incident_date_weekday', 'policy_bind_date_diff', 'incident_date_diff',
#        'incident_date&policy_bind_date_diff', 'injury_claim_pct',
#        'property_claim_pct', 'vehicle_claim_pct',
#        'umbrella_limit_2_total_claim_amount',
#        'policy_bind_date_year&auto_year_diff',
#        'incident_date_year&auto_year_diff', 'duration'],
#       dtype='object')

# %%
sns.distplot(datas['capital-gains'])
# Out:
# <AxesSubplot:xlabel='capital-gains', ylabel='Density'>

# %%
#画出各特征的分布图

g = sns.FacetGrid(df_melted, hue = 'Source', col='variable', col_wrap= 2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")
g.add_legend()

# %%
from sklearn.preprocessing import StandardScaler

# %%
# 数据集切分
train = datas[datas['fraud_reported'].notnull()]
test = datas[datas['fraud_reported'].isnull()]

# %%
scaler = StandardScaler()

train[numerical_columns] = scaler.fit_transform(train[numerical_columns])
test[numerical_columns] = scaler.transform(test[numerical_columns])

# %%
datas = pd.concat((train, test))
datas.reset_index(drop=True, inplace=True)

# %%
df_melted = pd.melt(datas[numerical_columns].join(pd.DataFrame(['Train' if not math.isnan(label) else 'Test' 
                                                                for label in datas['fraud_reported']], index=datas.index, columns=['Source'])
                                                  , how='left'), id_vars= ['Source'],
                    )

# %%
sns.distplot(datas['capital-gains'])
# Out:
# <AxesSubplot:xlabel='capital-gains', ylabel='Density'>

# %%
#画出各特征的分布图

g = sns.FacetGrid(df_melted, hue = 'Source', col='variable', col_wrap= 2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")
g.add_legend()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_columns = datas.select_dtypes(include= ['O']).columns

# %%
for col in cat_columns:
    le = LabelEncoder()
    datas[col] = le.fit_transform(datas[col])

datas[cat_columns]
# Out:
#      policy_state  policy_csl  insured_sex  insured_education_level  \
# 0               1           2            0                        5
# 1               0           1            1                        3
# 2               0           2            0                        2
# 3               2           2            1                        3
# 4               2           0            0                        4
# ..            ...         ...          ...                      ...
# 995             0           2            0                        1
# 996             1           1            1                        4
# 997             1           2            0                        0
# 998             1           0            0                        4
# 999             1           0            1                        5
#
#      insured_occupation  insured_hobbies  insured_relationship  incident_type  \
# 0                    10               15                     1              2
# 1                     2               14                     2              0
# 2                     6               16                     5              2
# 3                    13               18                     3              0
# 4                     2               18                     3              0
# ..                  ...              ...                   ...            ...
# 995                   9               11                     1              1
# 996                   0               12                     4              0
# 997                   7               10                     1              2
# 998                  10               10                     4              0
# 999                  10                7                     2              2
#
#      collision_type  incident_severity  ...  incident_location_street  \
# 0                 3                  2  ...                       106
# 1                 3                  1  ...                       144
# 2                 3                  2  ...                        78
# 3                 1                  0  ...                       144
# 4                 2                  2  ...                        18
# ..              ...                ...  ...                       ...
# 995               0                  3  ...                       125
# 996               3                  2  ...                        73
# 997               2                  1  ...                        78
# 998               3                  1  ...                       100
# 999               1                  1  ...                        93
#
#      incident_type&collision_type  incident_type&incident_severity  \
# 0                               6                                7
# 1                               2                                1
# 2                               6                                7
# 3                               0                                0
# 4                               1                                2
# ..                            ...                              ...
# 995                             3                                4
# 996                             2                                2
# 997                             5                                6
# 998                             2                                1
# 999                             4                                6
#
#      collision_type&incident_severity  incident_type&bodily_injuries  \
# 0                                  10                              6
# 1                                   9                              2
# 2                                  10                              8
# 3                                   2                              2
# 4                                   7                              2
# ..                                ...                            ...
# 995                                 1                              3
# 996                                10                              0
# 997                                 6                              6
# 998                                 9                              2
# 999                                 3                              7
#
#      collision_type&bodily_injuries  incident_type&property_damage  \
# 0                                 9                              6
# 1                                11                              0
# 2                                11                              6
# 3                                 5                              2
# 4                                 8                              2
# ..                              ...                            ...
# 995                               0                              4
# 996                               9                              0
# 997                               6                              8
# 998                              11                              2
# 999                               4                              7
#
#      collision_type&property_damage  \
# 0                                 9
# 1                                 9
# 2                                 9
# 3                                 5
# 4                                 8
# ..                              ...
# 995                               1
# 996                               9
# 997                               8
# 998                              11
# 999                               4
#
#      incident_type&collision_type&incident_severity&bodily_injuries&property_damage  \
# 0                                                  170
# 1                                                   69
# 2                                                  176
# 3                                                    8
# 4                                                   53
# ..                                                 ...
# 995                                                 91
# 996                                                 72
# 997                                                136
# 998                                                 71
# 999                                                111
#
#      auto_make&auto_model
# 0                      25
# 1                      19
# 2                      21
# 3                      33
# 4                      15
# ..                    ...
# 995                    12
# 996                    20
# 997                    13
# 998                    25
# 999                    19
#
# [1000 rows x 35 columns]

# %%
# 数据集切分
train = datas[datas['fraud_reported'].notnull()]
test = datas[datas['fraud_reported'].isnull()]

# %%
train_X = train.drop(['fraud_reported'], axis=1)
train_y = train['fraud_reported']
test_X = test.drop(['fraud_reported'], axis=1)

# %%
#增加检验
train_X2,eval_X,train_y2,eval_y = train_test_split(train_X, train_y, test_size=0.2, random_state=2022, stratify=train_y)

# %% [markdown]
# ## 使用lgbm 训练

# %%
import lightgbm as lgb

# %%
model_lgb = lgb.LGBMClassifier(
            num_leaves=2**5-1, reg_alpha=0.25, reg_lambda=0.25, objective='binary', metric = 'binary_logloss,auc',
            max_depth=-1, learning_rate=0.005, min_child_samples=3, random_state=2022,
            n_estimators=2000, subsample=1, colsample_bytree=1,
        )

# %%
model_lgb.fit(train_X2, train_y2, eval_set=(eval_X, eval_y), #categorical_feature = cat_columns.values.tolist(),
              early_stopping_rounds = 400)
# Out:
# [1]	valid_0's binary_logloss: 0.567865	valid_0's auc: 0.830262
# Training until validation scores don't improve for 400 rounds
# [2]	valid_0's binary_logloss: 0.565782	valid_0's auc: 0.825721
# [3]	valid_0's binary_logloss: 0.563679	valid_0's auc: 0.826255
# [4]	valid_0's binary_logloss: 0.561609	valid_0's auc: 0.826255
# [5]	valid_0's binary_logloss: 0.559624	valid_0's auc: 0.825988
# [6]	valid_0's binary_logloss: 0.557599	valid_0's auc: 0.826255
# [7]	valid_0's binary_logloss: 0.555658	valid_0's auc: 0.826255
# [8]	valid_0's binary_logloss: 0.553799	valid_0's auc: 0.826255
# [9]	valid_0's binary_logloss: 0.552045	valid_0's auc: 0.825988
# [10]	valid_0's binary_logloss: 0.550317	valid_0's auc: 0.825988
# [11]	valid_0's binary_logloss: 0.548687	valid_0's auc: 0.825988
# [12]	valid_0's binary_logloss: 0.546826	valid_0's auc: 0.826122
# [13]	valid_0's binary_logloss: 0.545124	valid_0's auc: 0.821448
# [14]	valid_0's binary_logloss: 0.543526	valid_0's auc: 0.821581
# [15]	valid_0's binary_logloss: 0.541846	valid_0's auc: 0.82078
# [16]	valid_0's binary_logloss: 0.540315	valid_0's auc: 0.821581
# [17]	valid_0's binary_logloss: 0.538788	valid_0's auc: 0.839744
# [18]	valid_0's binary_logloss: 0.537229	valid_0's auc: 0.838141
# [19]	valid_0's binary_logloss: 0.535765	valid_0's auc: 0.837073
# [20]	valid_0's binary_logloss: 0.534182	valid_0's auc: 0.836806
# [21]	valid_0's binary_logloss: 0.532545	valid_0's auc: 0.838141
# [22]	valid_0's binary_logloss: 0.531193	valid_0's auc: 0.837874
# [23]	valid_0's binary_logloss: 0.52957	valid_0's auc: 0.838408
# [24]	valid_0's binary_logloss: 0.528031	valid_0's auc: 0.838675
# [25]	valid_0's binary_logloss: 0.526571	valid_0's auc: 0.839744
# [26]	valid_0's binary_logloss: 0.525061	valid_0's auc: 0.839744
# [27]	valid_0's binary_logloss: 0.523552	valid_0's auc: 0.839744
# [28]	valid_0's binary_logloss: 0.522285	valid_0's auc: 0.839076
# [29]	valid_0's binary_logloss: 0.520931	valid_0's auc: 0.839877
# [30]	valid_0's binary_logloss: 0.519663	valid_0's auc: 0.839076
# [31]	valid_0's binary_logloss: 0.518174	valid_0's auc: 0.838675
# [32]	valid_0's binary_logloss: 0.516658	valid_0's auc: 0.838408
# [33]	valid_0's binary_logloss: 0.515251	valid_0's auc: 0.838675
# [34]	valid_0's binary_logloss: 0.513773	valid_0's auc: 0.838942
# [35]	valid_0's binary_logloss: 0.512393	valid_0's auc: 0.839476
# [36]	valid_0's binary_logloss: 0.51067	valid_0's auc: 0.841346
# [37]	valid_0's binary_logloss: 0.509266	valid_0's auc: 0.841613
# [38]	valid_0's binary_logloss: 0.507995	valid_0's auc: 0.841613
# [39]	valid_0's binary_logloss: 0.506434	valid_0's auc: 0.842949
# [40]	valid_0's binary_logloss: 0.505111	valid_0's auc: 0.842682
# [41]	valid_0's binary_logloss: 0.503683	valid_0's auc: 0.842147
# [42]	valid_0's binary_logloss: 0.502521	valid_0's auc: 0.84188
# [43]	valid_0's binary_logloss: 0.501172	valid_0's auc: 0.842949
# [44]	valid_0's binary_logloss: 0.499923	valid_0's auc: 0.844017
# [45]	valid_0's binary_logloss: 0.498437	valid_0's auc: 0.844284
# [46]	valid_0's binary_logloss: 0.497035	valid_0's auc: 0.844017
# [47]	valid_0's binary_logloss: 0.49596	valid_0's auc: 0.84375
# [48]	valid_0's binary_logloss: 0.494717	valid_0's auc: 0.843483
# [49]	valid_0's binary_logloss: 0.493406	valid_0's auc: 0.844284
# [50]	valid_0's binary_logloss: 0.492323	valid_0's auc: 0.843483
# [51]	valid_0's binary_logloss: 0.49117	valid_0's auc: 0.844551
# [52]	valid_0's binary_logloss: 0.490015	valid_0's auc: 0.845353
# [53]	valid_0's binary_logloss: 0.489001	valid_0's auc: 0.843483
# [54]	valid_0's binary_logloss: 0.487897	valid_0's auc: 0.843616
# [55]	valid_0's binary_logloss: 0.486825	valid_0's auc: 0.844151
# [56]	valid_0's binary_logloss: 0.485519	valid_0's auc: 0.844952
# [57]	valid_0's binary_logloss: 0.484398	valid_0's auc: 0.844952
# [58]	valid_0's binary_logloss: 0.483181	valid_0's auc: 0.844952
# [59]	valid_0's binary_logloss: 0.482258	valid_0's auc: 0.844952
# [60]	valid_0's binary_logloss: 0.481184	valid_0's auc: 0.846287
# [61]	valid_0's binary_logloss: 0.480184	valid_0's auc: 0.846554
# [62]	valid_0's binary_logloss: 0.479015	valid_0's auc: 0.845753
# [63]	valid_0's binary_logloss: 0.478134	valid_0's auc: 0.845753
# [64]	valid_0's binary_logloss: 0.477172	valid_0's auc: 0.845486
# [65]	valid_0's binary_logloss: 0.476293	valid_0's auc: 0.844418
# [66]	valid_0's binary_logloss: 0.475358	valid_0's auc: 0.844151
# [67]	valid_0's binary_logloss: 0.474402	valid_0's auc: 0.843884
# [68]	valid_0's binary_logloss: 0.473593	valid_0's auc: 0.843082
# [69]	valid_0's binary_logloss: 0.472661	valid_0's auc: 0.843616
# [70]	valid_0's binary_logloss: 0.471836	valid_0's auc: 0.843349
# [71]	valid_0's binary_logloss: 0.470989	valid_0's auc: 0.843616
# [72]	valid_0's binary_logloss: 0.469964	valid_0's auc: 0.843349
# [73]	valid_0's binary_logloss: 0.468965	valid_0's auc: 0.843349
# [74]	valid_0's binary_logloss: 0.468115	valid_0's auc: 0.844151
# [75]	valid_0's binary_logloss: 0.467248	valid_0's auc: 0.844151
# [76]	valid_0's binary_logloss: 0.466446	valid_0's auc: 0.843616
# [77]	valid_0's binary_logloss: 0.465496	valid_0's auc: 0.844151
# [78]	valid_0's binary_logloss: 0.464636	valid_0's auc: 0.845219
# [79]	valid_0's binary_logloss: 0.463839	valid_0's auc: 0.845753
# [80]	valid_0's binary_logloss: 0.463157	valid_0's auc: 0.844818
# [81]	valid_0's binary_logloss: 0.462313	valid_0's auc: 0.844818
# [82]	valid_0's binary_logloss: 0.461602	valid_0's auc: 0.845353
# [83]	valid_0's binary_logloss: 0.46084	valid_0's auc: 0.845353
# [84]	valid_0's binary_logloss: 0.45997	valid_0's auc: 0.846154
# [85]	valid_0's binary_logloss: 0.459288	valid_0's auc: 0.845353
# [86]	valid_0's binary_logloss: 0.458649	valid_0's auc: 0.84562
# [87]	valid_0's binary_logloss: 0.457894	valid_0's auc: 0.847222
# [88]	valid_0's binary_logloss: 0.457093	valid_0's auc: 0.847222
# [89]	valid_0's binary_logloss: 0.45634	valid_0's auc: 0.848825
# [90]	valid_0's binary_logloss: 0.455753	valid_0's auc: 0.847489
# [91]	valid_0's binary_logloss: 0.454976	valid_0's auc: 0.847489
# [92]	valid_0's binary_logloss: 0.454406	valid_0's auc: 0.846688
# [93]	valid_0's binary_logloss: 0.453843	valid_0's auc: 0.846154
# [94]	valid_0's binary_logloss: 0.453175	valid_0's auc: 0.846421
# [95]	valid_0's binary_logloss: 0.452642	valid_0's auc: 0.846154
# [96]	valid_0's binary_logloss: 0.452103	valid_0's auc: 0.84562
# [97]	valid_0's binary_logloss: 0.451403	valid_0's auc: 0.845486
# [98]	valid_0's binary_logloss: 0.450783	valid_0's auc: 0.84602
# [99]	valid_0's binary_logloss: 0.450204	valid_0's auc: 0.845486
# [100]	valid_0's binary_logloss: 0.449588	valid_0's auc: 0.845486
# [101]	valid_0's binary_logloss: 0.448851	valid_0's auc: 0.846287
# [102]	valid_0's binary_logloss: 0.448434	valid_0's auc: 0.84602
# [103]	valid_0's binary_logloss: 0.447928	valid_0's auc: 0.845486
# [104]	valid_0's binary_logloss: 0.447323	valid_0's auc: 0.846554
# [105]	valid_0's binary_logloss: 0.446805	valid_0's auc: 0.84602
# [106]	valid_0's binary_logloss: 0.446207	valid_0's auc: 0.84789
# [107]	valid_0's binary_logloss: 0.445781	valid_0's auc: 0.847356
# [108]	valid_0's binary_logloss: 0.445242	valid_0's auc: 0.847089
# [109]	valid_0's binary_logloss: 0.444706	valid_0's auc: 0.84602
# [110]	valid_0's binary_logloss: 0.444216	valid_0's auc: 0.846287
# [111]	valid_0's binary_logloss: 0.443564	valid_0's auc: 0.846287
# [112]	valid_0's binary_logloss: 0.443008	valid_0's auc: 0.84602
# [113]	valid_0's binary_logloss: 0.442412	valid_0's auc: 0.846287
# [114]	valid_0's binary_logloss: 0.441743	valid_0's auc: 0.846554
# [115]	valid_0's binary_logloss: 0.441134	valid_0's auc: 0.845753
# [116]	valid_0's binary_logloss: 0.440531	valid_0's auc: 0.845486
# [117]	valid_0's binary_logloss: 0.439955	valid_0's auc: 0.845219
# [118]	valid_0's binary_logloss: 0.439579	valid_0's auc: 0.845219
# [119]	valid_0's binary_logloss: 0.439234	valid_0's auc: 0.845219
# [120]	valid_0's binary_logloss: 0.438668	valid_0's auc: 0.845219
# [121]	valid_0's binary_logloss: 0.438195	valid_0's auc: 0.844685
# [122]	valid_0's binary_logloss: 0.437782	valid_0's auc: 0.844952
# [123]	valid_0's binary_logloss: 0.437418	valid_0's auc: 0.844685
# [124]	valid_0's binary_logloss: 0.436944	valid_0's auc: 0.844952
# [125]	valid_0's binary_logloss: 0.436612	valid_0's auc: 0.845219
# [126]	valid_0's binary_logloss: 0.436057	valid_0's auc: 0.844952
# [127]	valid_0's binary_logloss: 0.435648	valid_0's auc: 0.845219
# [128]	valid_0's binary_logloss: 0.435247	valid_0's auc: 0.845219
# [129]	valid_0's binary_logloss: 0.434857	valid_0's auc: 0.844952
# [130]	valid_0's binary_logloss: 0.434413	valid_0's auc: 0.844952
# [131]	valid_0's binary_logloss: 0.434019	valid_0's auc: 0.845219
# [132]	valid_0's binary_logloss: 0.433645	valid_0's auc: 0.844151
# [133]	valid_0's binary_logloss: 0.433246	valid_0's auc: 0.844151
# [134]	valid_0's binary_logloss: 0.432907	valid_0's auc: 0.844151
# [135]	valid_0's binary_logloss: 0.432217	valid_0's auc: 0.844685
# [136]	valid_0's binary_logloss: 0.431684	valid_0's auc: 0.844952
# [137]	valid_0's binary_logloss: 0.43135	valid_0's auc: 0.844952
# [138]	valid_0's binary_logloss: 0.431089	valid_0's auc: 0.844685
# [139]	valid_0's binary_logloss: 0.430699	valid_0's auc: 0.844685
# [140]	valid_0's binary_logloss: 0.43027	valid_0's auc: 0.844418
# [141]	valid_0's binary_logloss: 0.429861	valid_0's auc: 0.844151
# [142]	valid_0's binary_logloss: 0.429667	valid_0's auc: 0.844151
# [143]	valid_0's binary_logloss: 0.429208	valid_0's auc: 0.843884
# [144]	valid_0's binary_logloss: 0.428868	valid_0's auc: 0.843616
# [145]	valid_0's binary_logloss: 0.428642	valid_0's auc: 0.843349
# [146]	valid_0's binary_logloss: 0.428231	valid_0's auc: 0.843349
# [147]	valid_0's binary_logloss: 0.42783	valid_0's auc: 0.842949
# [148]	valid_0's binary_logloss: 0.42746	valid_0's auc: 0.842949
# [149]	valid_0's binary_logloss: 0.427079	valid_0's auc: 0.843216
# [150]	valid_0's binary_logloss: 0.426775	valid_0's auc: 0.842281
# [151]	valid_0's binary_logloss: 0.426378	valid_0's auc: 0.842281
# [152]	valid_0's binary_logloss: 0.426161	valid_0's auc: 0.842014
# [153]	valid_0's binary_logloss: 0.425708	valid_0's auc: 0.842548
# [154]	valid_0's binary_logloss: 0.425277	valid_0's auc: 0.842281
# [155]	valid_0's binary_logloss: 0.424895	valid_0's auc: 0.842014
# [156]	valid_0's binary_logloss: 0.42472	valid_0's auc: 0.842014
# [157]	valid_0's binary_logloss: 0.424341	valid_0's auc: 0.842548
# [158]	valid_0's binary_logloss: 0.424083	valid_0's auc: 0.842815
# [159]	valid_0's binary_logloss: 0.423964	valid_0's auc: 0.842548
# [160]	valid_0's binary_logloss: 0.423731	valid_0's auc: 0.842548
# [161]	valid_0's binary_logloss: 0.42326	valid_0's auc: 0.842548
# [162]	valid_0's binary_logloss: 0.422924	valid_0's auc: 0.842548
# [163]	valid_0's binary_logloss: 0.422605	valid_0's auc: 0.842548
# [164]	valid_0's binary_logloss: 0.422424	valid_0's auc: 0.842815
# [165]	valid_0's binary_logloss: 0.422172	valid_0's auc: 0.842815
# [166]	valid_0's binary_logloss: 0.421776	valid_0's auc: 0.842815
# [167]	valid_0's binary_logloss: 0.421364	valid_0's auc: 0.843082
# [168]	valid_0's binary_logloss: 0.421084	valid_0's auc: 0.842815
# [169]	valid_0's binary_logloss: 0.420898	valid_0's auc: 0.842548
# [170]	valid_0's binary_logloss: 0.420751	valid_0's auc: 0.842815
# [171]	valid_0's binary_logloss: 0.420516	valid_0's auc: 0.843082
# [172]	valid_0's binary_logloss: 0.420127	valid_0's auc: 0.843616
# [173]	valid_0's binary_logloss: 0.419777	valid_0's auc: 0.843349
# [174]	valid_0's binary_logloss: 0.419527	valid_0's auc: 0.843082
# [175]	valid_0's binary_logloss: 0.419376	valid_0's auc: 0.843616
# [176]	valid_0's binary_logloss: 0.419025	valid_0's auc: 0.843884
# [177]	valid_0's binary_logloss: 0.418881	valid_0's auc: 0.844418
# [178]	valid_0's binary_logloss: 0.4188	valid_0's auc: 0.844151
# [179]	valid_0's binary_logloss: 0.418679	valid_0's auc: 0.844151
# [180]	valid_0's binary_logloss: 0.418554	valid_0's auc: 0.844151
# [181]	valid_0's binary_logloss: 0.41818	valid_0's auc: 0.844151
# [182]	valid_0's binary_logloss: 0.417974	valid_0's auc: 0.844151
# [183]	valid_0's binary_logloss: 0.417883	valid_0's auc: 0.843884
# [184]	valid_0's binary_logloss: 0.417687	valid_0's auc: 0.843884
# [185]	valid_0's binary_logloss: 0.41754	valid_0's auc: 0.843884
# [186]	valid_0's binary_logloss: 0.417451	valid_0's auc: 0.843349
# [187]	valid_0's binary_logloss: 0.417135	valid_0's auc: 0.843884
# [188]	valid_0's binary_logloss: 0.416887	valid_0's auc: 0.843884
# [189]	valid_0's binary_logloss: 0.416654	valid_0's auc: 0.844151
# [190]	valid_0's binary_logloss: 0.416402	valid_0's auc: 0.844151
# [191]	valid_0's binary_logloss: 0.416114	valid_0's auc: 0.844151
# [192]	valid_0's binary_logloss: 0.415826	valid_0's auc: 0.843884
# [193]	valid_0's binary_logloss: 0.415625	valid_0's auc: 0.844418
# [194]	valid_0's binary_logloss: 0.415556	valid_0's auc: 0.843884
# [195]	valid_0's binary_logloss: 0.415318	valid_0's auc: 0.843616
# [196]	valid_0's binary_logloss: 0.415129	valid_0's auc: 0.843349
# [197]	valid_0's binary_logloss: 0.415004	valid_0's auc: 0.843082
# [198]	valid_0's binary_logloss: 0.414735	valid_0's auc: 0.843082
# [199]	valid_0's binary_logloss: 0.414452	valid_0's auc: 0.843884
# [200]	valid_0's binary_logloss: 0.414141	valid_0's auc: 0.843616
# [201]	valid_0's binary_logloss: 0.414008	valid_0's auc: 0.843884
# [202]	valid_0's binary_logloss: 0.413836	valid_0's auc: 0.844151
# [203]	valid_0's binary_logloss: 0.413646	valid_0's auc: 0.844151
# [204]	valid_0's binary_logloss: 0.413474	valid_0's auc: 0.844151
# [205]	valid_0's binary_logloss: 0.413122	valid_0's auc: 0.843884
# [206]	valid_0's binary_logloss: 0.412956	valid_0's auc: 0.843884
# [207]	valid_0's binary_logloss: 0.412727	valid_0's auc: 0.843884
# [208]	valid_0's binary_logloss: 0.412529	valid_0's auc: 0.843884
# [209]	valid_0's binary_logloss: 0.41219	valid_0's auc: 0.843616
# [210]	valid_0's binary_logloss: 0.412084	valid_0's auc: 0.843616
# [211]	valid_0's binary_logloss: 0.411925	valid_0's auc: 0.843349
# [212]	valid_0's binary_logloss: 0.411817	valid_0's auc: 0.843884
# [213]	valid_0's binary_logloss: 0.411722	valid_0's auc: 0.843349
# [214]	valid_0's binary_logloss: 0.411469	valid_0's auc: 0.843082
# [215]	valid_0's binary_logloss: 0.411268	valid_0's auc: 0.842014
# [216]	valid_0's binary_logloss: 0.411005	valid_0's auc: 0.843082
# [217]	valid_0's binary_logloss: 0.410794	valid_0's auc: 0.842281
# [218]	valid_0's binary_logloss: 0.410721	valid_0's auc: 0.842281
# [219]	valid_0's binary_logloss: 0.410736	valid_0's auc: 0.842014
# [220]	valid_0's binary_logloss: 0.410583	valid_0's auc: 0.842014
# [221]	valid_0's binary_logloss: 0.410395	valid_0's auc: 0.842014
# [222]	valid_0's binary_logloss: 0.410221	valid_0's auc: 0.842014
# [223]	valid_0's binary_logloss: 0.410038	valid_0's auc: 0.842014
# [224]	valid_0's binary_logloss: 0.409925	valid_0's auc: 0.841747
# [225]	valid_0's binary_logloss: 0.409693	valid_0's auc: 0.841747
# [226]	valid_0's binary_logloss: 0.409516	valid_0's auc: 0.84148
# [227]	valid_0's binary_logloss: 0.409367	valid_0's auc: 0.84148
# [228]	valid_0's binary_logloss: 0.409252	valid_0's auc: 0.841213
# [229]	valid_0's binary_logloss: 0.409034	valid_0's auc: 0.841213
# [230]	valid_0's binary_logloss: 0.408977	valid_0's auc: 0.840946
# [231]	valid_0's binary_logloss: 0.408781	valid_0's auc: 0.840678
# [232]	valid_0's binary_logloss: 0.408382	valid_0's auc: 0.841613
# [233]	valid_0's binary_logloss: 0.40823	valid_0's auc: 0.841346
# [234]	valid_0's binary_logloss: 0.408043	valid_0's auc: 0.84188
# [235]	valid_0's binary_logloss: 0.4078	valid_0's auc: 0.842147
# [236]	valid_0's binary_logloss: 0.407721	valid_0's auc: 0.842147
# [237]	valid_0's binary_logloss: 0.407448	valid_0's auc: 0.845353
# [238]	valid_0's binary_logloss: 0.407298	valid_0's auc: 0.845353
# [239]	valid_0's binary_logloss: 0.407081	valid_0's auc: 0.84562
# [240]	valid_0's binary_logloss: 0.406805	valid_0's auc: 0.846554
# [241]	valid_0's binary_logloss: 0.406799	valid_0's auc: 0.84602
# [242]	valid_0's binary_logloss: 0.406492	valid_0's auc: 0.846287
# [243]	valid_0's binary_logloss: 0.406351	valid_0's auc: 0.84602
# [244]	valid_0's binary_logloss: 0.40601	valid_0's auc: 0.84602
# [245]	valid_0's binary_logloss: 0.40593	valid_0's auc: 0.846554
# [246]	valid_0's binary_logloss: 0.405661	valid_0's auc: 0.847089
# [247]	valid_0's binary_logloss: 0.405537	valid_0's auc: 0.847089
# [248]	valid_0's binary_logloss: 0.405284	valid_0's auc: 0.847356
# [249]	valid_0's binary_logloss: 0.404995	valid_0's auc: 0.850027
# [250]	valid_0's binary_logloss: 0.404669	valid_0's auc: 0.850427
# [251]	valid_0's binary_logloss: 0.404557	valid_0's auc: 0.85016
# [252]	valid_0's binary_logloss: 0.404423	valid_0's auc: 0.85016
# [253]	valid_0's binary_logloss: 0.404264	valid_0's auc: 0.850427
# [254]	valid_0's binary_logloss: 0.40437	valid_0's auc: 0.85016
# [255]	valid_0's binary_logloss: 0.40422	valid_0's auc: 0.850427
# [256]	valid_0's binary_logloss: 0.404059	valid_0's auc: 0.850694
# [257]	valid_0's binary_logloss: 0.403821	valid_0's auc: 0.850962
# [258]	valid_0's binary_logloss: 0.403632	valid_0's auc: 0.851496
# [259]	valid_0's binary_logloss: 0.403517	valid_0's auc: 0.851229
# [260]	valid_0's binary_logloss: 0.403392	valid_0's auc: 0.851229
# [261]	valid_0's binary_logloss: 0.403282	valid_0's auc: 0.850962
# [262]	valid_0's binary_logloss: 0.403096	valid_0's auc: 0.850962
# [263]	valid_0's binary_logloss: 0.403026	valid_0's auc: 0.850427
# [264]	valid_0's binary_logloss: 0.402862	valid_0's auc: 0.85016
# [265]	valid_0's binary_logloss: 0.402802	valid_0's auc: 0.850962
# [266]	valid_0's binary_logloss: 0.402808	valid_0's auc: 0.850427
# [267]	valid_0's binary_logloss: 0.402523	valid_0's auc: 0.850694
# [268]	valid_0's binary_logloss: 0.402454	valid_0's auc: 0.850427
# [269]	valid_0's binary_logloss: 0.402355	valid_0's auc: 0.852831
# [270]	valid_0's binary_logloss: 0.402122	valid_0's auc: 0.8539
# [271]	valid_0's binary_logloss: 0.402133	valid_0's auc: 0.8539
# [272]	valid_0's binary_logloss: 0.402083	valid_0's auc: 0.853365
# [273]	valid_0's binary_logloss: 0.402069	valid_0's auc: 0.853365
# [274]	valid_0's binary_logloss: 0.402042	valid_0's auc: 0.853365
# [275]	valid_0's binary_logloss: 0.401819	valid_0's auc: 0.853632
# [276]	valid_0's binary_logloss: 0.401779	valid_0's auc: 0.853365
# [277]	valid_0's binary_logloss: 0.401637	valid_0's auc: 0.853632
# [278]	valid_0's binary_logloss: 0.401565	valid_0's auc: 0.853632
# [279]	valid_0's binary_logloss: 0.401504	valid_0's auc: 0.853632
# [280]	valid_0's binary_logloss: 0.401362	valid_0's auc: 0.853632
# [281]	valid_0's binary_logloss: 0.401496	valid_0's auc: 0.853632
# [282]	valid_0's binary_logloss: 0.401261	valid_0's auc: 0.853632
# [283]	valid_0's binary_logloss: 0.401162	valid_0's auc: 0.853632
# [284]	valid_0's binary_logloss: 0.401259	valid_0's auc: 0.853365
# [285]	valid_0's binary_logloss: 0.401233	valid_0's auc: 0.853365
# [286]	valid_0's binary_logloss: 0.40129	valid_0's auc: 0.852831
# [287]	valid_0's binary_logloss: 0.400964	valid_0's auc: 0.853365
# [288]	valid_0's binary_logloss: 0.400872	valid_0's auc: 0.853365
# [289]	valid_0's binary_logloss: 0.400742	valid_0's auc: 0.853632
# [290]	valid_0's binary_logloss: 0.400696	valid_0's auc: 0.853632
# [291]	valid_0's binary_logloss: 0.400848	valid_0's auc: 0.853632
# [292]	valid_0's binary_logloss: 0.40072	valid_0's auc: 0.853365
# [293]	valid_0's binary_logloss: 0.4005	valid_0's auc: 0.853632
# [294]	valid_0's binary_logloss: 0.400408	valid_0's auc: 0.853365
# [295]	valid_0's binary_logloss: 0.400321	valid_0's auc: 0.853365
# [296]	valid_0's binary_logloss: 0.400149	valid_0's auc: 0.853365
# [297]	valid_0's binary_logloss: 0.400159	valid_0's auc: 0.853365
# [298]	valid_0's binary_logloss: 0.4	valid_0's auc: 0.853365
# [299]	valid_0's binary_logloss: 0.39998	valid_0's auc: 0.853365
# [300]	valid_0's binary_logloss: 0.399854	valid_0's auc: 0.853632
# [301]	valid_0's binary_logloss: 0.399658	valid_0's auc: 0.8539
# [302]	valid_0's binary_logloss: 0.399496	valid_0's auc: 0.854167
# [303]	valid_0's binary_logloss: 0.399499	valid_0's auc: 0.8539
# [304]	valid_0's binary_logloss: 0.399414	valid_0's auc: 0.8539
# [305]	valid_0's binary_logloss: 0.399317	valid_0's auc: 0.8539
# [306]	valid_0's binary_logloss: 0.399222	valid_0's auc: 0.8539
# [307]	valid_0's binary_logloss: 0.399193	valid_0's auc: 0.853632
# [308]	valid_0's binary_logloss: 0.399039	valid_0's auc: 0.8539
# [309]	valid_0's binary_logloss: 0.398972	valid_0's auc: 0.8539
# [310]	valid_0's binary_logloss: 0.398917	valid_0's auc: 0.854167
# [311]	valid_0's binary_logloss: 0.398801	valid_0's auc: 0.854968
# [312]	valid_0's binary_logloss: 0.398754	valid_0's auc: 0.854434
# [313]	valid_0's binary_logloss: 0.398799	valid_0's auc: 0.854434
# [314]	valid_0's binary_logloss: 0.398652	valid_0's auc: 0.854701
# [315]	valid_0's binary_logloss: 0.398622	valid_0's auc: 0.854434
# [316]	valid_0's binary_logloss: 0.398665	valid_0's auc: 0.854434
# [317]	valid_0's binary_logloss: 0.398481	valid_0's auc: 0.854701
# [318]	valid_0's binary_logloss: 0.39844	valid_0's auc: 0.854701
# [319]	valid_0's binary_logloss: 0.398391	valid_0's auc: 0.854434
# [320]	valid_0's binary_logloss: 0.398332	valid_0's auc: 0.8543
# [321]	valid_0's binary_logloss: 0.398346	valid_0's auc: 0.854033
# [322]	valid_0's binary_logloss: 0.398252	valid_0's auc: 0.854567
# [323]	valid_0's binary_logloss: 0.398269	valid_0's auc: 0.854567
# [324]	valid_0's binary_logloss: 0.398307	valid_0's auc: 0.854567
# [325]	valid_0's binary_logloss: 0.398253	valid_0's auc: 0.855369
# [326]	valid_0's binary_logloss: 0.398304	valid_0's auc: 0.855369
# [327]	valid_0's binary_logloss: 0.398301	valid_0's auc: 0.854567
# [328]	valid_0's binary_logloss: 0.398304	valid_0's auc: 0.854567
# [329]	valid_0's binary_logloss: 0.398285	valid_0's auc: 0.854567
# [330]	valid_0's binary_logloss: 0.398345	valid_0's auc: 0.8543
# [331]	valid_0's binary_logloss: 0.398467	valid_0's auc: 0.854567
# [332]	valid_0's binary_logloss: 0.398433	valid_0's auc: 0.854834
# [333]	valid_0's binary_logloss: 0.398405	valid_0's auc: 0.854033
# [334]	valid_0's binary_logloss: 0.398353	valid_0's auc: 0.853766
# [335]	valid_0's binary_logloss: 0.39823	valid_0's auc: 0.854033
# [336]	valid_0's binary_logloss: 0.398377	valid_0's auc: 0.853499
# [337]	valid_0's binary_logloss: 0.398365	valid_0's auc: 0.853499
# [338]	valid_0's binary_logloss: 0.398195	valid_0's auc: 0.853499
# [339]	valid_0's binary_logloss: 0.398281	valid_0's auc: 0.853365
# [340]	valid_0's binary_logloss: 0.398248	valid_0's auc: 0.853365
# [341]	valid_0's binary_logloss: 0.398106	valid_0's auc: 0.853365
# [342]	valid_0's binary_logloss: 0.398256	valid_0's auc: 0.853365
# [343]	valid_0's binary_logloss: 0.398263	valid_0's auc: 0.853365
# [344]	valid_0's binary_logloss: 0.398182	valid_0's auc: 0.853365
# [345]	valid_0's binary_logloss: 0.398207	valid_0's auc: 0.853632
# [346]	valid_0's binary_logloss: 0.398247	valid_0's auc: 0.853632
# [347]	valid_0's binary_logloss: 0.398247	valid_0's auc: 0.853632
# [348]	valid_0's binary_logloss: 0.398328	valid_0's auc: 0.853365
# [349]	valid_0's binary_logloss: 0.398245	valid_0's auc: 0.853632
# [350]	valid_0's binary_logloss: 0.398248	valid_0's auc: 0.853632
# [351]	valid_0's binary_logloss: 0.398227	valid_0's auc: 0.853632
# [352]	valid_0's binary_logloss: 0.398147	valid_0's auc: 0.8539
# [353]	valid_0's binary_logloss: 0.398147	valid_0's auc: 0.8539
# [354]	valid_0's binary_logloss: 0.398068	valid_0's auc: 0.8539
# [355]	valid_0's binary_logloss: 0.398013	valid_0's auc: 0.853365
# [356]	valid_0's binary_logloss: 0.39801	valid_0's auc: 0.8539
# [357]	valid_0's binary_logloss: 0.398074	valid_0's auc: 0.8539
# [358]	valid_0's binary_logloss: 0.398003	valid_0's auc: 0.8539
# [359]	valid_0's binary_logloss: 0.397968	valid_0's auc: 0.8539
# [360]	valid_0's binary_logloss: 0.398021	valid_0's auc: 0.854167
# [361]	valid_0's binary_logloss: 0.397956	valid_0's auc: 0.854167
# [362]	valid_0's binary_logloss: 0.397956	valid_0's auc: 0.8539
# [363]	valid_0's binary_logloss: 0.397959	valid_0's auc: 0.8539
# [364]	valid_0's binary_logloss: 0.397886	valid_0's auc: 0.8539
# [365]	valid_0's binary_logloss: 0.39792	valid_0's auc: 0.8539
# [366]	valid_0's binary_logloss: 0.39798	valid_0's auc: 0.853632
# [367]	valid_0's binary_logloss: 0.397817	valid_0's auc: 0.854434
# [368]	valid_0's binary_logloss: 0.397767	valid_0's auc: 0.854434
# [369]	valid_0's binary_logloss: 0.397842	valid_0's auc: 0.8539
# [370]	valid_0's binary_logloss: 0.397981	valid_0's auc: 0.854167
# [371]	valid_0's binary_logloss: 0.397872	valid_0's auc: 0.854434
# [372]	valid_0's binary_logloss: 0.397786	valid_0's auc: 0.854434
# [373]	valid_0's binary_logloss: 0.397693	valid_0's auc: 0.854434
# [374]	valid_0's binary_logloss: 0.397814	valid_0's auc: 0.854701
# [375]	valid_0's binary_logloss: 0.397824	valid_0's auc: 0.854434
# [376]	valid_0's binary_logloss: 0.39777	valid_0's auc: 0.854701
# [377]	valid_0's binary_logloss: 0.397694	valid_0's auc: 0.855235
# [378]	valid_0's binary_logloss: 0.397649	valid_0's auc: 0.854968
# [379]	valid_0's binary_logloss: 0.397685	valid_0's auc: 0.854968
# [380]	valid_0's binary_logloss: 0.397622	valid_0's auc: 0.854167
# [381]	valid_0's binary_logloss: 0.397649	valid_0's auc: 0.854167
# [382]	valid_0's binary_logloss: 0.397759	valid_0's auc: 0.854434
# [383]	valid_0's binary_logloss: 0.39788	valid_0's auc: 0.854434
# [384]	valid_0's binary_logloss: 0.397914	valid_0's auc: 0.854167
# [385]	valid_0's binary_logloss: 0.397863	valid_0's auc: 0.8539
# [386]	valid_0's binary_logloss: 0.397927	valid_0's auc: 0.8539
# [387]	valid_0's binary_logloss: 0.397817	valid_0's auc: 0.8539
# [388]	valid_0's binary_logloss: 0.397827	valid_0's auc: 0.854167
# [389]	valid_0's binary_logloss: 0.397885	valid_0's auc: 0.853632
# [390]	valid_0's binary_logloss: 0.397836	valid_0's auc: 0.853632
# [391]	valid_0's binary_logloss: 0.397993	valid_0's auc: 0.853365
# [392]	valid_0's binary_logloss: 0.397991	valid_0's auc: 0.853632
# [393]	valid_0's binary_logloss: 0.397965	valid_0's auc: 0.853632
# [394]	valid_0's binary_logloss: 0.397911	valid_0's auc: 0.853632
# [395]	valid_0's binary_logloss: 0.39789	valid_0's auc: 0.852831
# [396]	valid_0's binary_logloss: 0.397894	valid_0's auc: 0.852831
# [397]	valid_0's binary_logloss: 0.397764	valid_0's auc: 0.853365
# [398]	valid_0's binary_logloss: 0.397694	valid_0's auc: 0.852564
# [399]	valid_0's binary_logloss: 0.397695	valid_0's auc: 0.852564
# [400]	valid_0's binary_logloss: 0.397588	valid_0's auc: 0.853098
# [401]	valid_0's binary_logloss: 0.397571	valid_0's auc: 0.852564
# [402]	valid_0's binary_logloss: 0.397531	valid_0's auc: 0.852564
# [403]	valid_0's binary_logloss: 0.397486	valid_0's auc: 0.853365
# [404]	valid_0's binary_logloss: 0.397575	valid_0's auc: 0.852297
# [405]	valid_0's binary_logloss: 0.397568	valid_0's auc: 0.852831
# [406]	valid_0's binary_logloss: 0.397499	valid_0's auc: 0.852831
# [407]	valid_0's binary_logloss: 0.397472	valid_0's auc: 0.852831
# [408]	valid_0's binary_logloss: 0.39745	valid_0's auc: 0.853098
# [409]	valid_0's binary_logloss: 0.397457	valid_0's auc: 0.853632
# [410]	valid_0's binary_logloss: 0.397443	valid_0's auc: 0.852831
# [411]	valid_0's binary_logloss: 0.397384	valid_0's auc: 0.853098
# [412]	valid_0's binary_logloss: 0.397398	valid_0's auc: 0.853098
# [413]	valid_0's binary_logloss: 0.397461	valid_0's auc: 0.853365
# [414]	valid_0's binary_logloss: 0.3974	valid_0's auc: 0.853632
# [415]	valid_0's binary_logloss: 0.39748	valid_0's auc: 0.853632
# [416]	valid_0's binary_logloss: 0.39753	valid_0's auc: 0.8539
# [417]	valid_0's binary_logloss: 0.397604	valid_0's auc: 0.8539
# [418]	valid_0's binary_logloss: 0.397561	valid_0's auc: 0.8539
# [419]	valid_0's binary_logloss: 0.397517	valid_0's auc: 0.8539
# [420]	valid_0's binary_logloss: 0.397612	valid_0's auc: 0.854434
# [421]	valid_0's binary_logloss: 0.397602	valid_0's auc: 0.854434
# [422]	valid_0's binary_logloss: 0.397665	valid_0's auc: 0.854434
# [423]	valid_0's binary_logloss: 0.397781	valid_0's auc: 0.854434
# [424]	valid_0's binary_logloss: 0.397906	valid_0's auc: 0.854434
# [425]	valid_0's binary_logloss: 0.397862	valid_0's auc: 0.854167
# [426]	valid_0's binary_logloss: 0.397929	valid_0's auc: 0.854434
# [427]	valid_0's binary_logloss: 0.397963	valid_0's auc: 0.854167
# [428]	valid_0's binary_logloss: 0.398071	valid_0's auc: 0.8539
# [429]	valid_0's binary_logloss: 0.398035	valid_0's auc: 0.8539
# [430]	valid_0's binary_logloss: 0.398086	valid_0's auc: 0.854434
# [431]	valid_0's binary_logloss: 0.398115	valid_0's auc: 0.854434
# [432]	valid_0's binary_logloss: 0.398109	valid_0's auc: 0.854167
# [433]	valid_0's binary_logloss: 0.398208	valid_0's auc: 0.854167
# [434]	valid_0's binary_logloss: 0.398264	valid_0's auc: 0.854434
# [435]	valid_0's binary_logloss: 0.398272	valid_0's auc: 0.854167
# [436]	valid_0's binary_logloss: 0.398319	valid_0's auc: 0.854167
# [437]	valid_0's binary_logloss: 0.398347	valid_0's auc: 0.854167
# [438]	valid_0's binary_logloss: 0.398384	valid_0's auc: 0.854167
# [439]	valid_0's binary_logloss: 0.398491	valid_0's auc: 0.8539
# [440]	valid_0's binary_logloss: 0.398475	valid_0's auc: 0.854167
# [441]	valid_0's binary_logloss: 0.398602	valid_0's auc: 0.853098
# [442]	valid_0's binary_logloss: 0.398436	valid_0's auc: 0.854167
# [443]	valid_0's binary_logloss: 0.398513	valid_0's auc: 0.8539
# [444]	valid_0's binary_logloss: 0.39841	valid_0's auc: 0.8539
# [445]	valid_0's binary_logloss: 0.398327	valid_0's auc: 0.854701
# [446]	valid_0's binary_logloss: 0.398396	valid_0's auc: 0.8539
# [447]	valid_0's binary_logloss: 0.398371	valid_0's auc: 0.853632
# [448]	valid_0's binary_logloss: 0.398452	valid_0's auc: 0.854167
# [449]	valid_0's binary_logloss: 0.39845	valid_0's auc: 0.8539
# [450]	valid_0's binary_logloss: 0.39848	valid_0's auc: 0.854434
# [451]	valid_0's binary_logloss: 0.398562	valid_0's auc: 0.8539
# [452]	valid_0's binary_logloss: 0.398549	valid_0's auc: 0.854968
# [453]	valid_0's binary_logloss: 0.398692	valid_0's auc: 0.854968
# [454]	valid_0's binary_logloss: 0.398662	valid_0's auc: 0.855502
# [455]	valid_0's binary_logloss: 0.398778	valid_0's auc: 0.855235
# [456]	valid_0's binary_logloss: 0.398726	valid_0's auc: 0.855235
# [457]	valid_0's binary_logloss: 0.398557	valid_0's auc: 0.855235
# [458]	valid_0's binary_logloss: 0.398719	valid_0's auc: 0.854968
# [459]	valid_0's binary_logloss: 0.398811	valid_0's auc: 0.854701
# [460]	valid_0's binary_logloss: 0.398961	valid_0's auc: 0.854701
# [461]	valid_0's binary_logloss: 0.399179	valid_0's auc: 0.854701
# [462]	valid_0's binary_logloss: 0.399315	valid_0's auc: 0.854434
# [463]	valid_0's binary_logloss: 0.399334	valid_0's auc: 0.854701
# [464]	valid_0's binary_logloss: 0.399374	valid_0's auc: 0.854167
# [465]	valid_0's binary_logloss: 0.399368	valid_0's auc: 0.854167
# [466]	valid_0's binary_logloss: 0.399444	valid_0's auc: 0.854167
# [467]	valid_0's binary_logloss: 0.399477	valid_0's auc: 0.853632
# [468]	valid_0's binary_logloss: 0.399503	valid_0's auc: 0.853632
# [469]	valid_0's binary_logloss: 0.399657	valid_0's auc: 0.8539
# [470]	valid_0's binary_logloss: 0.399747	valid_0's auc: 0.853632
# [471]	valid_0's binary_logloss: 0.399742	valid_0's auc: 0.854434
# [472]	valid_0's binary_logloss: 0.399727	valid_0's auc: 0.854434
# [473]	valid_0's binary_logloss: 0.399814	valid_0's auc: 0.854701
# [474]	valid_0's binary_logloss: 0.400037	valid_0's auc: 0.854434
# [475]	valid_0's binary_logloss: 0.400189	valid_0's auc: 0.854167
# [476]	valid_0's binary_logloss: 0.400205	valid_0's auc: 0.8539
# [477]	valid_0's binary_logloss: 0.400277	valid_0's auc: 0.853365
# [478]	valid_0's binary_logloss: 0.400348	valid_0's auc: 0.853632
# [479]	valid_0's binary_logloss: 0.400409	valid_0's auc: 0.8539
# [480]	valid_0's binary_logloss: 0.400524	valid_0's auc: 0.853365
# [481]	valid_0's binary_logloss: 0.400611	valid_0's auc: 0.853632
# [482]	valid_0's binary_logloss: 0.400729	valid_0's auc: 0.853632
# [483]	valid_0's binary_logloss: 0.400727	valid_0's auc: 0.854167
# [484]	valid_0's binary_logloss: 0.400929	valid_0's auc: 0.8539
# [485]	valid_0's binary_logloss: 0.400917	valid_0's auc: 0.853632
# [486]	valid_0's binary_logloss: 0.400975	valid_0's auc: 0.854167
# [487]	valid_0's binary_logloss: 0.401071	valid_0's auc: 0.853632
# [488]	valid_0's binary_logloss: 0.401058	valid_0's auc: 0.854167
# [489]	valid_0's binary_logloss: 0.401259	valid_0's auc: 0.8539
# [490]	valid_0's binary_logloss: 0.401416	valid_0's auc: 0.853098
# [491]	valid_0's binary_logloss: 0.401492	valid_0's auc: 0.853365
# [492]	valid_0's binary_logloss: 0.401593	valid_0's auc: 0.853365
# [493]	valid_0's binary_logloss: 0.401526	valid_0's auc: 0.853632
# [494]	valid_0's binary_logloss: 0.401647	valid_0's auc: 0.853098
# [495]	valid_0's binary_logloss: 0.401815	valid_0's auc: 0.852831
# [496]	valid_0's binary_logloss: 0.401957	valid_0's auc: 0.853098
# [497]	valid_0's binary_logloss: 0.402011	valid_0's auc: 0.852831
# [498]	valid_0's binary_logloss: 0.40195	valid_0's auc: 0.852831
# [499]	valid_0's binary_logloss: 0.402089	valid_0's auc: 0.852564
# [500]	valid_0's binary_logloss: 0.40208	valid_0's auc: 0.852297
# [501]	valid_0's binary_logloss: 0.4022	valid_0's auc: 0.85203
# [502]	valid_0's binary_logloss: 0.402276	valid_0's auc: 0.851763
# [503]	valid_0's binary_logloss: 0.402355	valid_0's auc: 0.851496
# [504]	valid_0's binary_logloss: 0.402374	valid_0's auc: 0.851496
# [505]	valid_0's binary_logloss: 0.402537	valid_0's auc: 0.851496
# [506]	valid_0's binary_logloss: 0.402587	valid_0's auc: 0.851763
# [507]	valid_0's binary_logloss: 0.402639	valid_0's auc: 0.851763
# [508]	valid_0's binary_logloss: 0.4028	valid_0's auc: 0.851496
# [509]	valid_0's binary_logloss: 0.402957	valid_0's auc: 0.851496
# [510]	valid_0's binary_logloss: 0.403068	valid_0's auc: 0.851496
# [511]	valid_0's binary_logloss: 0.403043	valid_0's auc: 0.851763
# [512]	valid_0's binary_logloss: 0.40301	valid_0's auc: 0.850962
# [513]	valid_0's binary_logloss: 0.403064	valid_0's auc: 0.851229
# [514]	valid_0's binary_logloss: 0.403187	valid_0's auc: 0.851229
# [515]	valid_0's binary_logloss: 0.403288	valid_0's auc: 0.851229
# [516]	valid_0's binary_logloss: 0.403458	valid_0's auc: 0.850962
# [517]	valid_0's binary_logloss: 0.403562	valid_0's auc: 0.850694
# [518]	valid_0's binary_logloss: 0.403513	valid_0's auc: 0.850962
# [519]	valid_0's binary_logloss: 0.403543	valid_0's auc: 0.850962
# [520]	valid_0's binary_logloss: 0.403627	valid_0's auc: 0.850694
# [521]	valid_0's binary_logloss: 0.403695	valid_0's auc: 0.850962
# [522]	valid_0's binary_logloss: 0.403775	valid_0's auc: 0.850694
# [523]	valid_0's binary_logloss: 0.40383	valid_0's auc: 0.850427
# [524]	valid_0's binary_logloss: 0.403881	valid_0's auc: 0.850427
# [525]	valid_0's binary_logloss: 0.403927	valid_0's auc: 0.850427
# [526]	valid_0's binary_logloss: 0.403937	valid_0's auc: 0.850427
# [527]	valid_0's binary_logloss: 0.404026	valid_0's auc: 0.850427
# [528]	valid_0's binary_logloss: 0.404145	valid_0's auc: 0.850427
# [529]	valid_0's binary_logloss: 0.404122	valid_0's auc: 0.850427
# [530]	valid_0's binary_logloss: 0.404282	valid_0's auc: 0.850427
# [531]	valid_0's binary_logloss: 0.404447	valid_0's auc: 0.85016
# [532]	valid_0's binary_logloss: 0.404619	valid_0's auc: 0.85016
# [533]	valid_0's binary_logloss: 0.404677	valid_0's auc: 0.85016
# [534]	valid_0's binary_logloss: 0.404694	valid_0's auc: 0.849893
# [535]	valid_0's binary_logloss: 0.404821	valid_0's auc: 0.849626
# [536]	valid_0's binary_logloss: 0.404893	valid_0's auc: 0.85016
# [537]	valid_0's binary_logloss: 0.40493	valid_0's auc: 0.849626
# [538]	valid_0's binary_logloss: 0.405017	valid_0's auc: 0.848558
# [539]	valid_0's binary_logloss: 0.405074	valid_0's auc: 0.848558
# [540]	valid_0's binary_logloss: 0.405208	valid_0's auc: 0.848558
# [541]	valid_0's binary_logloss: 0.405267	valid_0's auc: 0.848558
# [542]	valid_0's binary_logloss: 0.405375	valid_0's auc: 0.848558
# [543]	valid_0's binary_logloss: 0.405593	valid_0's auc: 0.848825
# [544]	valid_0's binary_logloss: 0.405711	valid_0's auc: 0.848291
# [545]	valid_0's binary_logloss: 0.405767	valid_0's auc: 0.848291
# [546]	valid_0's binary_logloss: 0.405813	valid_0's auc: 0.848291
# [547]	valid_0's binary_logloss: 0.405811	valid_0's auc: 0.847756
# [548]	valid_0's binary_logloss: 0.405948	valid_0's auc: 0.847489
# [549]	valid_0's binary_logloss: 0.406062	valid_0's auc: 0.847489
# [550]	valid_0's binary_logloss: 0.406077	valid_0's auc: 0.848291
# [551]	valid_0's binary_logloss: 0.406245	valid_0's auc: 0.848024
# [552]	valid_0's binary_logloss: 0.406395	valid_0's auc: 0.848024
# [553]	valid_0's binary_logloss: 0.406515	valid_0's auc: 0.848024
# [554]	valid_0's binary_logloss: 0.406586	valid_0's auc: 0.847489
# [555]	valid_0's binary_logloss: 0.406654	valid_0's auc: 0.847756
# [556]	valid_0's binary_logloss: 0.406822	valid_0's auc: 0.847756
# [557]	valid_0's binary_logloss: 0.406889	valid_0's auc: 0.847222
# [558]	valid_0's binary_logloss: 0.406971	valid_0's auc: 0.846955
# [559]	valid_0's binary_logloss: 0.407119	valid_0's auc: 0.847222
# [560]	valid_0's binary_logloss: 0.407087	valid_0's auc: 0.846955
# [561]	valid_0's binary_logloss: 0.40715	valid_0's auc: 0.847222
# [562]	valid_0's binary_logloss: 0.407257	valid_0's auc: 0.846955
# [563]	valid_0's binary_logloss: 0.407373	valid_0's auc: 0.847222
# [564]	valid_0's binary_logloss: 0.407491	valid_0's auc: 0.846688
# [565]	valid_0's binary_logloss: 0.407585	valid_0's auc: 0.847489
# [566]	valid_0's binary_logloss: 0.407525	valid_0's auc: 0.847222
# [567]	valid_0's binary_logloss: 0.407564	valid_0's auc: 0.847489
# [568]	valid_0's binary_logloss: 0.407742	valid_0's auc: 0.847756
# [569]	valid_0's binary_logloss: 0.40789	valid_0's auc: 0.847222
# [570]	valid_0's binary_logloss: 0.408048	valid_0's auc: 0.847489
# [571]	valid_0's binary_logloss: 0.408157	valid_0's auc: 0.847756
# [572]	valid_0's binary_logloss: 0.408169	valid_0's auc: 0.847489
# [573]	valid_0's binary_logloss: 0.408298	valid_0's auc: 0.847489
# [574]	valid_0's binary_logloss: 0.408369	valid_0's auc: 0.847489
# [575]	valid_0's binary_logloss: 0.408476	valid_0's auc: 0.847489
# [576]	valid_0's binary_logloss: 0.408521	valid_0's auc: 0.847222
# [577]	valid_0's binary_logloss: 0.408577	valid_0's auc: 0.846955
# [578]	valid_0's binary_logloss: 0.408669	valid_0's auc: 0.846955
# [579]	valid_0's binary_logloss: 0.40879	valid_0's auc: 0.846955
# [580]	valid_0's binary_logloss: 0.408834	valid_0's auc: 0.847222
# [581]	valid_0's binary_logloss: 0.408968	valid_0's auc: 0.847489
# [582]	valid_0's binary_logloss: 0.409136	valid_0's auc: 0.846688
# [583]	valid_0's binary_logloss: 0.4092	valid_0's auc: 0.846688
# [584]	valid_0's binary_logloss: 0.409313	valid_0's auc: 0.846421
# [585]	valid_0's binary_logloss: 0.409292	valid_0's auc: 0.846955
# [586]	valid_0's binary_logloss: 0.409338	valid_0's auc: 0.847222
# [587]	valid_0's binary_logloss: 0.409461	valid_0's auc: 0.847222
# [588]	valid_0's binary_logloss: 0.409574	valid_0's auc: 0.847222
# [589]	valid_0's binary_logloss: 0.409568	valid_0's auc: 0.847489
# [590]	valid_0's binary_logloss: 0.409678	valid_0's auc: 0.847222
# [591]	valid_0's binary_logloss: 0.409705	valid_0's auc: 0.847222
# [592]	valid_0's binary_logloss: 0.409759	valid_0's auc: 0.847222
# [593]	valid_0's binary_logloss: 0.409858	valid_0's auc: 0.846688
# [594]	valid_0's binary_logloss: 0.409925	valid_0's auc: 0.846688
# [595]	valid_0's binary_logloss: 0.41008	valid_0's auc: 0.846421
# [596]	valid_0's binary_logloss: 0.4102	valid_0's auc: 0.846154
# [597]	valid_0's binary_logloss: 0.410254	valid_0's auc: 0.846154
# [598]	valid_0's binary_logloss: 0.410312	valid_0's auc: 0.846154
# [599]	valid_0's binary_logloss: 0.410299	valid_0's auc: 0.846154
# [600]	valid_0's binary_logloss: 0.410438	valid_0's auc: 0.846154
# [601]	valid_0's binary_logloss: 0.410596	valid_0's auc: 0.845887
# [602]	valid_0's binary_logloss: 0.410626	valid_0's auc: 0.846421
# [603]	valid_0's binary_logloss: 0.41061	valid_0's auc: 0.846955
# [604]	valid_0's binary_logloss: 0.410837	valid_0's auc: 0.846688
# [605]	valid_0's binary_logloss: 0.41096	valid_0's auc: 0.846688
# [606]	valid_0's binary_logloss: 0.410958	valid_0's auc: 0.846955
# [607]	valid_0's binary_logloss: 0.410984	valid_0's auc: 0.846955
# [608]	valid_0's binary_logloss: 0.411109	valid_0's auc: 0.846955
# [609]	valid_0's binary_logloss: 0.411123	valid_0's auc: 0.846688
# [610]	valid_0's binary_logloss: 0.411217	valid_0's auc: 0.846688
# [611]	valid_0's binary_logloss: 0.411356	valid_0's auc: 0.846688
# [612]	valid_0's binary_logloss: 0.411482	valid_0's auc: 0.846955
# [613]	valid_0's binary_logloss: 0.411567	valid_0's auc: 0.847222
# [614]	valid_0's binary_logloss: 0.411691	valid_0's auc: 0.847222
# [615]	valid_0's binary_logloss: 0.411711	valid_0's auc: 0.847222
# [616]	valid_0's binary_logloss: 0.411854	valid_0's auc: 0.846955
# [617]	valid_0's binary_logloss: 0.411942	valid_0's auc: 0.846688
# [618]	valid_0's binary_logloss: 0.411985	valid_0's auc: 0.846688
# [619]	valid_0's binary_logloss: 0.412015	valid_0's auc: 0.846955
# [620]	valid_0's binary_logloss: 0.412065	valid_0's auc: 0.846955
# [621]	valid_0's binary_logloss: 0.412184	valid_0's auc: 0.846955
# [622]	valid_0's binary_logloss: 0.412231	valid_0's auc: 0.846688
# [623]	valid_0's binary_logloss: 0.412369	valid_0's auc: 0.846421
# [624]	valid_0's binary_logloss: 0.412422	valid_0's auc: 0.846421
# [625]	valid_0's binary_logloss: 0.412457	valid_0's auc: 0.846421
# [626]	valid_0's binary_logloss: 0.412517	valid_0's auc: 0.846154
# [627]	valid_0's binary_logloss: 0.412756	valid_0's auc: 0.846154
# [628]	valid_0's binary_logloss: 0.412834	valid_0's auc: 0.846421
# [629]	valid_0's binary_logloss: 0.412955	valid_0's auc: 0.846421
# [630]	valid_0's binary_logloss: 0.4131	valid_0's auc: 0.846421
# [631]	valid_0's binary_logloss: 0.41319	valid_0's auc: 0.846421
# [632]	valid_0's binary_logloss: 0.413265	valid_0's auc: 0.845887
# [633]	valid_0's binary_logloss: 0.413322	valid_0's auc: 0.846421
# [634]	valid_0's binary_logloss: 0.413397	valid_0's auc: 0.845353
# [635]	valid_0's binary_logloss: 0.413463	valid_0's auc: 0.845085
# [636]	valid_0's binary_logloss: 0.413542	valid_0's auc: 0.844818
# [637]	valid_0's binary_logloss: 0.413721	valid_0's auc: 0.844818
# [638]	valid_0's binary_logloss: 0.413778	valid_0's auc: 0.845085
# [639]	valid_0's binary_logloss: 0.413823	valid_0's auc: 0.845353
# [640]	valid_0's binary_logloss: 0.413891	valid_0's auc: 0.845085
# [641]	valid_0's binary_logloss: 0.413923	valid_0's auc: 0.844284
# [642]	valid_0's binary_logloss: 0.414004	valid_0's auc: 0.844284
# [643]	valid_0's binary_logloss: 0.414164	valid_0's auc: 0.844284
# [644]	valid_0's binary_logloss: 0.414225	valid_0's auc: 0.844551
# [645]	valid_0's binary_logloss: 0.414212	valid_0's auc: 0.844551
# [646]	valid_0's binary_logloss: 0.414451	valid_0's auc: 0.844017
# [647]	valid_0's binary_logloss: 0.414593	valid_0's auc: 0.844284
# [648]	valid_0's binary_logloss: 0.414622	valid_0's auc: 0.844017
# [649]	valid_0's binary_logloss: 0.414568	valid_0's auc: 0.844284
# [650]	valid_0's binary_logloss: 0.414666	valid_0's auc: 0.844017
# [651]	valid_0's binary_logloss: 0.414716	valid_0's auc: 0.844017
# [652]	valid_0's binary_logloss: 0.414863	valid_0's auc: 0.844017
# [653]	valid_0's binary_logloss: 0.414937	valid_0's auc: 0.844017
# [654]	valid_0's binary_logloss: 0.414933	valid_0's auc: 0.844551
# [655]	valid_0's binary_logloss: 0.414932	valid_0's auc: 0.84375
# [656]	valid_0's binary_logloss: 0.415141	valid_0's auc: 0.843483
# [657]	valid_0's binary_logloss: 0.415285	valid_0's auc: 0.84375
# [658]	valid_0's binary_logloss: 0.415335	valid_0's auc: 0.84375
# [659]	valid_0's binary_logloss: 0.415368	valid_0's auc: 0.844284
# [660]	valid_0's binary_logloss: 0.415313	valid_0's auc: 0.844284
# [661]	valid_0's binary_logloss: 0.415318	valid_0's auc: 0.843483
# [662]	valid_0's binary_logloss: 0.41539	valid_0's auc: 0.844284
# [663]	valid_0's binary_logloss: 0.415543	valid_0's auc: 0.844017
# [664]	valid_0's binary_logloss: 0.415691	valid_0's auc: 0.844017
# [665]	valid_0's binary_logloss: 0.415747	valid_0's auc: 0.844017
# [666]	valid_0's binary_logloss: 0.415815	valid_0's auc: 0.844284
# [667]	valid_0's binary_logloss: 0.4158	valid_0's auc: 0.844017
# [668]	valid_0's binary_logloss: 0.416026	valid_0's auc: 0.84375
# [669]	valid_0's binary_logloss: 0.416235	valid_0's auc: 0.844017
# [670]	valid_0's binary_logloss: 0.416278	valid_0's auc: 0.844284
# [671]	valid_0's binary_logloss: 0.416333	valid_0's auc: 0.844284
# [672]	valid_0's binary_logloss: 0.416383	valid_0's auc: 0.844284
# [673]	valid_0's binary_logloss: 0.416379	valid_0's auc: 0.844284
# [674]	valid_0's binary_logloss: 0.416541	valid_0's auc: 0.844017
# [675]	valid_0's binary_logloss: 0.41661	valid_0's auc: 0.844017
# [676]	valid_0's binary_logloss: 0.416671	valid_0's auc: 0.844284
# [677]	valid_0's binary_logloss: 0.416812	valid_0's auc: 0.844017
# [678]	valid_0's binary_logloss: 0.416987	valid_0's auc: 0.84375
# [679]	valid_0's binary_logloss: 0.417047	valid_0's auc: 0.844017
# [680]	valid_0's binary_logloss: 0.417252	valid_0's auc: 0.844017
# [681]	valid_0's binary_logloss: 0.417329	valid_0's auc: 0.84375
# [682]	valid_0's binary_logloss: 0.417425	valid_0's auc: 0.84375
# [683]	valid_0's binary_logloss: 0.41758	valid_0's auc: 0.84375
# [684]	valid_0's binary_logloss: 0.417651	valid_0's auc: 0.844017
# [685]	valid_0's binary_logloss: 0.417727	valid_0's auc: 0.84375
# [686]	valid_0's binary_logloss: 0.417887	valid_0's auc: 0.844017
# [687]	valid_0's binary_logloss: 0.417936	valid_0's auc: 0.844017
# [688]	valid_0's binary_logloss: 0.417951	valid_0's auc: 0.84375
# [689]	valid_0's binary_logloss: 0.418004	valid_0's auc: 0.84375
# [690]	valid_0's binary_logloss: 0.418046	valid_0's auc: 0.84375
# [691]	valid_0's binary_logloss: 0.41823	valid_0's auc: 0.843483
# [692]	valid_0's binary_logloss: 0.418458	valid_0's auc: 0.843216
# [693]	valid_0's binary_logloss: 0.41845	valid_0's auc: 0.843216
# [694]	valid_0's binary_logloss: 0.418599	valid_0's auc: 0.842949
# [695]	valid_0's binary_logloss: 0.418676	valid_0's auc: 0.842682
# [696]	valid_0's binary_logloss: 0.41873	valid_0's auc: 0.842682
# [697]	valid_0's binary_logloss: 0.418822	valid_0's auc: 0.842682
# [698]	valid_0's binary_logloss: 0.418927	valid_0's auc: 0.842949
# [699]	valid_0's binary_logloss: 0.419025	valid_0's auc: 0.842682
# [700]	valid_0's binary_logloss: 0.419231	valid_0's auc: 0.842415
# [701]	valid_0's binary_logloss: 0.41921	valid_0's auc: 0.842415
# [702]	valid_0's binary_logloss: 0.419237	valid_0's auc: 0.842415
# [703]	valid_0's binary_logloss: 0.419406	valid_0's auc: 0.842147
# [704]	valid_0's binary_logloss: 0.419441	valid_0's auc: 0.842147
# [705]	valid_0's binary_logloss: 0.419533	valid_0's auc: 0.84188
# [706]	valid_0's binary_logloss: 0.419663	valid_0's auc: 0.842147
# [707]	valid_0's binary_logloss: 0.419692	valid_0's auc: 0.842147
# [708]	valid_0's binary_logloss: 0.419823	valid_0's auc: 0.842147
# [709]	valid_0's binary_logloss: 0.419889	valid_0's auc: 0.84188
# [710]	valid_0's binary_logloss: 0.419969	valid_0's auc: 0.84188
# [711]	valid_0's binary_logloss: 0.420201	valid_0's auc: 0.841346
# [712]	valid_0's binary_logloss: 0.420292	valid_0's auc: 0.841613
# [713]	valid_0's binary_logloss: 0.420359	valid_0's auc: 0.841346
# [714]	valid_0's binary_logloss: 0.42047	valid_0's auc: 0.841613
# [715]	valid_0's binary_logloss: 0.420547	valid_0's auc: 0.841079
# [716]	valid_0's binary_logloss: 0.420601	valid_0's auc: 0.841346
# [717]	valid_0's binary_logloss: 0.420642	valid_0's auc: 0.841079
# [718]	valid_0's binary_logloss: 0.420729	valid_0's auc: 0.841346
# [719]	valid_0's binary_logloss: 0.420797	valid_0's auc: 0.840812
# [720]	valid_0's binary_logloss: 0.420962	valid_0's auc: 0.840812
# [721]	valid_0's binary_logloss: 0.42103	valid_0's auc: 0.841079
# [722]	valid_0's binary_logloss: 0.42108	valid_0's auc: 0.841079
# [723]	valid_0's binary_logloss: 0.42124	valid_0's auc: 0.841079
# [724]	valid_0's binary_logloss: 0.421249	valid_0's auc: 0.841346
# [725]	valid_0's binary_logloss: 0.421309	valid_0's auc: 0.841079
# [726]	valid_0's binary_logloss: 0.421484	valid_0's auc: 0.841346
# [727]	valid_0's binary_logloss: 0.421665	valid_0's auc: 0.841079
# [728]	valid_0's binary_logloss: 0.421697	valid_0's auc: 0.841613
# [729]	valid_0's binary_logloss: 0.421693	valid_0's auc: 0.841346
# [730]	valid_0's binary_logloss: 0.421808	valid_0's auc: 0.841346
# [731]	valid_0's binary_logloss: 0.421887	valid_0's auc: 0.841346
# [732]	valid_0's binary_logloss: 0.421935	valid_0's auc: 0.841346
# [733]	valid_0's binary_logloss: 0.422135	valid_0's auc: 0.841079
# [734]	valid_0's binary_logloss: 0.422256	valid_0's auc: 0.841079
# [735]	valid_0's binary_logloss: 0.422303	valid_0's auc: 0.840812
# [736]	valid_0's binary_logloss: 0.42226	valid_0's auc: 0.840812
# [737]	valid_0's binary_logloss: 0.42233	valid_0's auc: 0.840278
# [738]	valid_0's binary_logloss: 0.422402	valid_0's auc: 0.840545
# [739]	valid_0's binary_logloss: 0.422438	valid_0's auc: 0.840545
# [740]	valid_0's binary_logloss: 0.422489	valid_0's auc: 0.840812
# [741]	valid_0's binary_logloss: 0.422532	valid_0's auc: 0.840812
# [742]	valid_0's binary_logloss: 0.422512	valid_0's auc: 0.840812
# [743]	valid_0's binary_logloss: 0.422704	valid_0's auc: 0.840812
# [744]	valid_0's binary_logloss: 0.422757	valid_0's auc: 0.840812
# [745]	valid_0's binary_logloss: 0.422816	valid_0's auc: 0.840812
# [746]	valid_0's binary_logloss: 0.422923	valid_0's auc: 0.840812
# [747]	valid_0's binary_logloss: 0.42293	valid_0's auc: 0.840812
# [748]	valid_0's binary_logloss: 0.42295	valid_0's auc: 0.840812
# [749]	valid_0's binary_logloss: 0.423004	valid_0's auc: 0.841079
# [750]	valid_0's binary_logloss: 0.423088	valid_0's auc: 0.840545
# [751]	valid_0's binary_logloss: 0.423134	valid_0's auc: 0.840545
# [752]	valid_0's binary_logloss: 0.423115	valid_0's auc: 0.840812
# [753]	valid_0's binary_logloss: 0.423183	valid_0's auc: 0.840545
# [754]	valid_0's binary_logloss: 0.423194	valid_0's auc: 0.840812
# [755]	valid_0's binary_logloss: 0.423158	valid_0's auc: 0.840545
# [756]	valid_0's binary_logloss: 0.423314	valid_0's auc: 0.840545
# [757]	valid_0's binary_logloss: 0.423362	valid_0's auc: 0.840278
# [758]	valid_0's binary_logloss: 0.423498	valid_0's auc: 0.840812
# [759]	valid_0's binary_logloss: 0.423532	valid_0's auc: 0.840812
# [760]	valid_0's binary_logloss: 0.423584	valid_0's auc: 0.841079
# [761]	valid_0's binary_logloss: 0.423736	valid_0's auc: 0.840545
# [762]	valid_0's binary_logloss: 0.423725	valid_0's auc: 0.840545
# [763]	valid_0's binary_logloss: 0.423815	valid_0's auc: 0.840278
# [764]	valid_0's binary_logloss: 0.423798	valid_0's auc: 0.840812
# [765]	valid_0's binary_logloss: 0.423836	valid_0's auc: 0.840545
# [766]	valid_0's binary_logloss: 0.423941	valid_0's auc: 0.840812
# [767]	valid_0's binary_logloss: 0.424021	valid_0's auc: 0.840545
# [768]	valid_0's binary_logloss: 0.424087	valid_0's auc: 0.840278
# [769]	valid_0's binary_logloss: 0.424245	valid_0's auc: 0.840278
# [770]	valid_0's binary_logloss: 0.424275	valid_0's auc: 0.840278
# [771]	valid_0's binary_logloss: 0.424345	valid_0's auc: 0.839744
# [772]	valid_0's binary_logloss: 0.424413	valid_0's auc: 0.839744
# [773]	valid_0's binary_logloss: 0.424388	valid_0's auc: 0.839744
# [774]	valid_0's binary_logloss: 0.424544	valid_0's auc: 0.840011
# [775]	valid_0's binary_logloss: 0.424509	valid_0's auc: 0.840278
# [776]	valid_0's binary_logloss: 0.424563	valid_0's auc: 0.840011
# [777]	valid_0's binary_logloss: 0.424727	valid_0's auc: 0.840011
# [778]	valid_0's binary_logloss: 0.424808	valid_0's auc: 0.840011
# [779]	valid_0's binary_logloss: 0.424755	valid_0's auc: 0.840011
# [780]	valid_0's binary_logloss: 0.424786	valid_0's auc: 0.840011
# [781]	valid_0's binary_logloss: 0.424785	valid_0's auc: 0.840011
# [782]	valid_0's binary_logloss: 0.424832	valid_0's auc: 0.840011
# [783]	valid_0's binary_logloss: 0.424966	valid_0's auc: 0.840011
# [784]	valid_0's binary_logloss: 0.425175	valid_0's auc: 0.840011
# [785]	valid_0's binary_logloss: 0.425247	valid_0's auc: 0.840011
# [786]	valid_0's binary_logloss: 0.425242	valid_0's auc: 0.840011
# [787]	valid_0's binary_logloss: 0.425257	valid_0's auc: 0.840278
# [788]	valid_0's binary_logloss: 0.425346	valid_0's auc: 0.840278
# [789]	valid_0's binary_logloss: 0.425432	valid_0's auc: 0.840278
# [790]	valid_0's binary_logloss: 0.425481	valid_0's auc: 0.840545
# [791]	valid_0's binary_logloss: 0.425493	valid_0's auc: 0.840812
# [792]	valid_0's binary_logloss: 0.425504	valid_0's auc: 0.840812
# [793]	valid_0's binary_logloss: 0.425612	valid_0's auc: 0.841079
# [794]	valid_0's binary_logloss: 0.425615	valid_0's auc: 0.840812
# [795]	valid_0's binary_logloss: 0.42561	valid_0's auc: 0.840812
# [796]	valid_0's binary_logloss: 0.42566	valid_0's auc: 0.840812
# [797]	valid_0's binary_logloss: 0.425748	valid_0's auc: 0.840812
# [798]	valid_0's binary_logloss: 0.425907	valid_0's auc: 0.840545
# [799]	valid_0's binary_logloss: 0.425988	valid_0's auc: 0.840545
# [800]	valid_0's binary_logloss: 0.425943	valid_0's auc: 0.840812
# [801]	valid_0's binary_logloss: 0.425955	valid_0's auc: 0.841079
# [802]	valid_0's binary_logloss: 0.426069	valid_0's auc: 0.840812
# [803]	valid_0's binary_logloss: 0.426072	valid_0's auc: 0.840812
# [804]	valid_0's binary_logloss: 0.426128	valid_0's auc: 0.841079
# [805]	valid_0's binary_logloss: 0.426098	valid_0's auc: 0.841079
# [806]	valid_0's binary_logloss: 0.426064	valid_0's auc: 0.841079
# [807]	valid_0's binary_logloss: 0.426169	valid_0's auc: 0.841079
# [808]	valid_0's binary_logloss: 0.426269	valid_0's auc: 0.841079
# [809]	valid_0's binary_logloss: 0.426294	valid_0's auc: 0.840812
# [810]	valid_0's binary_logloss: 0.426287	valid_0's auc: 0.841346
# [811]	valid_0's binary_logloss: 0.426425	valid_0's auc: 0.840545
# Early stopping, best iteration is:
# [411]	valid_0's binary_logloss: 0.397384	valid_0's auc: 0.853098
# LGBMClassifier(colsample_bytree=1, learning_rate=0.005,
#                metric='binary_logloss,auc', min_child_samples=3,
#                n_estimators=2000, objective='binary', random_state=2022,
#                reg_alpha=0.25, reg_lambda=0.25, subsample=1)

# %%
y_pred = model_lgb.predict_proba(test_X )[:, 1]

#检验
# y_pred = model_lgb.predict_proba(eval_X)[:, 1]

# %%
y_pred
# Out:
# array([0.04450229, 0.67472199, 0.04113017, 0.23386015, 0.04432557,
#        0.04428882, 0.04559408, 0.05075431, 0.03993   , 0.08454841,
#        0.48050959, 0.04426041, 0.73744223, 0.06269685, 0.05821558,
#        0.5122063 , 0.0470799 , 0.07107535, 0.84389564, 0.04809511,
#        0.04676854, 0.1050921 , 0.41179043, 0.07817654, 0.05664665,
#        0.72329511, 0.04617284, 0.06104678, 0.43555065, 0.06727085,
#        0.34764166, 0.05187247, 0.33486001, 0.04548454, 0.05226527,
#        0.04906979, 0.73290562, 0.09554679, 0.0481585 , 0.05622999,
#        0.68383538, 0.09729701, 0.09673428, 0.04462841, 0.04122801,
#        0.05511438, 0.05499749, 0.05472274, 0.81988323, 0.03991549,
#        0.04556638, 0.09497858, 0.04109058, 0.26199281, 0.80683037,
#        0.05587904, 0.17433596, 0.24682284, 0.04940198, 0.53951237,
#        0.04871664, 0.0450678 , 0.04419178, 0.64092838, 0.03947132,
#        0.04021508, 0.81084068, 0.51208672, 0.09959905, 0.04441955,
#        0.06773921, 0.05523019, 0.43959214, 0.84388496, 0.06070642,
#        0.04310396, 0.04479834, 0.04743196, 0.70445202, 0.05042985,
#        0.05708983, 0.04256964, 0.83220912, 0.08906488, 0.06994351,
#        0.04783421, 0.07298304, 0.04929559, 0.10032905, 0.71220118,
#        0.0444125 , 0.36309412, 0.81212343, 0.06229525, 0.03993   ,
#        0.04507078, 0.14960172, 0.09625964, 0.68979322, 0.0404048 ,
#        0.23857986, 0.61733982, 0.04621349, 0.05523831, 0.05544023,
#        0.71468433, 0.46480086, 0.73153768, 0.06945025, 0.10842793,
#        0.04054959, 0.04318323, 0.06638841, 0.03909287, 0.04298356,
#        0.33023028, 0.82790879, 0.05775909, 0.8425711 , 0.04102282,
#        0.04594082, 0.0521429 , 0.42223202, 0.77781941, 0.07389893,
#        0.2852647 , 0.04054961, 0.04109937, 0.49949579, 0.04109058,
#        0.04093802, 0.48480804, 0.05417039, 0.04256964, 0.06397351,
#        0.03909287, 0.04575523, 0.49908536, 0.36095363, 0.22651641,
#        0.09601626, 0.05587686, 0.65560155, 0.06686262, 0.71423371,
#        0.74911683, 0.06397287, 0.06520805, 0.05094658, 0.04494369,
#        0.0525909 , 0.44136117, 0.84109873, 0.68177468, 0.04230786,
#        0.04255192, 0.67437058, 0.05158688, 0.06185032, 0.05800602,
#        0.51379326, 0.07247246, 0.57516856, 0.64604468, 0.55989175,
#        0.71289821, 0.07183311, 0.04109058, 0.81184352, 0.06554167,
#        0.03947132, 0.06724495, 0.22613088, 0.63090551, 0.05466927,
#        0.62779165, 0.0584636 , 0.10003128, 0.06582072, 0.04354208,
#        0.04472792, 0.055873  , 0.04356764, 0.0396221 , 0.07354332,
#        0.8250654 , 0.04546674, 0.72698273, 0.04885953, 0.07268168,
#        0.13755756, 0.04256964, 0.18852526, 0.57999499, 0.70292173,
#        0.0421979 , 0.07829879, 0.04210734, 0.04256964, 0.64495275,
#        0.05337414, 0.04985745, 0.85735738, 0.04441638, 0.06721275,
#        0.04654997, 0.04981126, 0.05124315, 0.09178217, 0.04795422,
#        0.05189256, 0.04323171, 0.06584461, 0.04214334, 0.62416901,
#        0.06461886, 0.37798135, 0.04408973, 0.042965  , 0.41588833,
#        0.04256964, 0.21966018, 0.05900292, 0.05121223, 0.05203237,
#        0.58335043, 0.04590054, 0.03909287, 0.75783848, 0.05005834,
#        0.05916215, 0.05347013, 0.05095342, 0.05160309, 0.15745328,
#        0.84186094, 0.04256964, 0.03909287, 0.04228598, 0.04080983,
#        0.34529938, 0.06058043, 0.05119884, 0.04917045, 0.04256964,
#        0.69534817, 0.058831  , 0.04569591, 0.04158402, 0.05585608,
#        0.54759211, 0.64212602, 0.6021501 , 0.04108303, 0.04067306,
#        0.04581843, 0.33222391, 0.05777548, 0.5593859 , 0.10550873,
#        0.86479911, 0.05368234, 0.44761042, 0.06162373, 0.05061968,
#        0.07717572, 0.04689046, 0.04555964, 0.07955383, 0.04117991,
#        0.67023852, 0.10745289, 0.04509488, 0.68483324, 0.5698942 ,
#        0.05111742, 0.04473674, 0.04855144, 0.81431945, 0.04347784,
#        0.04301928, 0.10614569, 0.06202539, 0.65126947, 0.55450527,
#        0.05282455, 0.444096  , 0.08327711, 0.71680121, 0.47502369,
#        0.26267382, 0.4088875 , 0.14169155, 0.09586038, 0.55259101,
#        0.05032658, 0.04233944, 0.04119812, 0.23186971, 0.04747802])

# %%
fig, ax = plt.subplots(figsize=(6,18))
lgb.plot_importance(model_lgb, max_num_features=70, ax = ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
#检验
# roc_auc_score(eval_y, y_pred)

# %%
submission = pd.read_csv('./data/sampleSubmission.csv')
submission['fraud_reported'] = y_pred
submission.to_csv('./submission/submission.csv', index=None)

# %% [markdown]
# ## 使用五折交叉验证的LightGBM

# %%
from sklearn.model_selection import StratifiedKFold, KFold
import lightgbm as lgb

# %%
params_lgb = {
    'num_leaves': 2**5-1, 'reg_alpha': 0.25, 'reg_lambda': 0.25, 'objective': 'binary', 'metric': 'binary_logloss,auc',
    'max_depth': -1, 'learning_rate': 0.001, 'min_child_samples': 3, 'random_state': 2022,
    #'n_estimators': 2000, 
    'subsample': 1, 'colsample_bytree': 1, #'scale_pos_weight': 3
}

# %%
NFOLD = 7

# %%
kf = StratifiedKFold(n_splits = NFOLD, shuffle = True, random_state = 2022)

y_pred = np.zeros(len(test_X))

#检验
# y_pred = np.zeros(len(eval_X))

# %%
mean_valscore = []
for fold, (train_index, val_index) in enumerate(kf.split(train_X, train_y)):
    X_fold_train, X_fold_val = train_X.iloc[train_index, :], train_X.iloc[val_index, :]
    y_fold_train, y_fold_val = train_y.iloc[train_index], train_y.iloc[val_index]
    train_set = lgb.Dataset(X_fold_train, y_fold_train)
    val_set = lgb.Dataset(X_fold_val, y_fold_val, reference=train_set)

    model_lgb = lgb.train(params_lgb, train_set, num_boost_round=2000, early_stopping_rounds=500,
                      valid_sets = val_set, verbose_eval=100)
    
    mean_valscore.append(model_lgb.best_score['valid_0']['auc'])

    y_pred += model_lgb.predict(test_X)/kf.n_splits
    
print('valscore:', mean_valscore)
print('mean_valscore:', np.mean(mean_valscore))
    
    #检验
#     y_pred += model_lgb.predict(eval_X, num_iteration=model_lgb.best_iteration)/kf.n_splits

# y_pred = [1 if y > 0.5 else 0 for y in y_pred]
# rmse = metrics.accuracy_score(y_pred,y_test)
# print(rmse)
# Out:
# [LightGBM] [Info] Number of positive: 156, number of negative: 444
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000653 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3132
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.260000 -> initscore=-1.045969
# [LightGBM] [Info] Start training from score -1.045969
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's binary_logloss: 0.532117	valid_0's auc: 0.837867
# [200]	valid_0's binary_logloss: 0.50676	valid_0's auc: 0.842133
# [300]	valid_0's binary_logloss: 0.488243	valid_0's auc: 0.8368
# [400]	valid_0's binary_logloss: 0.470356	valid_0's auc: 0.84
# [500]	valid_0's binary_logloss: 0.456112	valid_0's auc: 0.844
# Early stopping, best iteration is:
# [4]	valid_0's binary_logloss: 0.560921	valid_0's auc: 0.856
# [LightGBM] [Info] Number of positive: 155, number of negative: 445
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000792 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3141
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258333 -> initscore=-1.054649
# [LightGBM] [Info] Start training from score -1.054649
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's binary_logloss: 0.536387	valid_0's auc: 0.839397
# [200]	valid_0's binary_logloss: 0.512005	valid_0's auc: 0.831081
# [300]	valid_0's binary_logloss: 0.487163	valid_0's auc: 0.837838
# [400]	valid_0's binary_logloss: 0.469419	valid_0's auc: 0.831341
# [500]	valid_0's binary_logloss: 0.455594	valid_0's auc: 0.837058
# Early stopping, best iteration is:
# [18]	valid_0's binary_logloss: 0.565691	valid_0's auc: 0.851871
# [LightGBM] [Info] Number of positive: 155, number of negative: 445
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000743 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3158
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258333 -> initscore=-1.054649
# [LightGBM] [Info] Start training from score -1.054649
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's binary_logloss: 0.541821	valid_0's auc: 0.790021
# [200]	valid_0's binary_logloss: 0.520242	valid_0's auc: 0.794179
# [300]	valid_0's binary_logloss: 0.503506	valid_0's auc: 0.7921
# [400]	valid_0's binary_logloss: 0.491262	valid_0's auc: 0.797557
# [500]	valid_0's binary_logloss: 0.481145	valid_0's auc: 0.802235
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.572667	valid_0's auc: 0.823805
# [LightGBM] [Info] Number of positive: 155, number of negative: 445
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000819 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3136
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258333 -> initscore=-1.054649
# [LightGBM] [Info] Start training from score -1.054649
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's binary_logloss: 0.547571	valid_0's auc: 0.804834
# [200]	valid_0's binary_logloss: 0.52792	valid_0's auc: 0.801715
# [300]	valid_0's binary_logloss: 0.510925	valid_0's auc: 0.809771
# [400]	valid_0's binary_logloss: 0.49786	valid_0's auc: 0.810811
# [500]	valid_0's binary_logloss: 0.489403	valid_0's auc: 0.811331
# [600]	valid_0's binary_logloss: 0.482896	valid_0's auc: 0.802495
# [700]	valid_0's binary_logloss: 0.478193	valid_0's auc: 0.793659
# [800]	valid_0's binary_logloss: 0.473822	valid_0's auc: 0.795218
# Early stopping, best iteration is:
# [358]	valid_0's binary_logloss: 0.502188	valid_0's auc: 0.81185
# [LightGBM] [Info] Number of positive: 155, number of negative: 445
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000906 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3131
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258333 -> initscore=-1.054649
# [LightGBM] [Info] Start training from score -1.054649
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's binary_logloss: 0.531792	valid_0's auc: 0.893971
# [200]	valid_0's binary_logloss: 0.497937	valid_0's auc: 0.894231
# [300]	valid_0's binary_logloss: 0.470149	valid_0's auc: 0.910603
# [400]	valid_0's binary_logloss: 0.449363	valid_0's auc: 0.919958
# [500]	valid_0's binary_logloss: 0.431527	valid_0's auc: 0.918399
# [600]	valid_0's binary_logloss: 0.415806	valid_0's auc: 0.913202
# [700]	valid_0's binary_logloss: 0.402008	valid_0's auc: 0.911123
# [800]	valid_0's binary_logloss: 0.389707	valid_0's auc: 0.913721
# Early stopping, best iteration is:
# [379]	valid_0's binary_logloss: 0.453626	valid_0's auc: 0.920478
# [LightGBM] [Info] Number of positive: 155, number of negative: 445
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000938 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3140
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258333 -> initscore=-1.054649
# [LightGBM] [Info] Start training from score -1.054649
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's binary_logloss: 0.535542	valid_0's auc: 0.884875
# [200]	valid_0's binary_logloss: 0.502521	valid_0's auc: 0.882796
# [300]	valid_0's binary_logloss: 0.475619	valid_0's auc: 0.878119
# [400]	valid_0's binary_logloss: 0.454734	valid_0's auc: 0.877079
# [500]	valid_0's binary_logloss: 0.437379	valid_0's auc: 0.887994
# Early stopping, best iteration is:
# [4]	valid_0's binary_logloss: 0.571183	valid_0's auc: 0.908524
# [LightGBM] [Info] Number of positive: 155, number of negative: 445
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000796 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3145
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258333 -> initscore=-1.054649
# [LightGBM] [Info] Start training from score -1.054649
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's binary_logloss: 0.525027	valid_0's auc: 0.907225
# [200]	valid_0's binary_logloss: 0.48883	valid_0's auc: 0.914241
# [300]	valid_0's binary_logloss: 0.45854	valid_0's auc: 0.918139
# [400]	valid_0's binary_logloss: 0.437093	valid_0's auc: 0.909563
# [500]	valid_0's binary_logloss: 0.418734	valid_0's auc: 0.908264
# Early stopping, best iteration is:
# [43]	valid_0's binary_logloss: 0.550672	valid_0's auc: 0.926715
# valscore: [0.856, 0.8518711018711018, 0.8238045738045738, 0.8118503118503119, 0.9204781704781705, 0.9085239085239085, 0.9267151767151767]
# mean_valscore: 0.8713204633204633

# %%
#检验
# roc_auc_score(eval_y, y_pred)

# %%
submission = pd.read_csv('./data/sampleSubmission.csv')
submission['fraud_reported'] = y_pred
submission.to_csv('./submission/submission_Kfold.csv', index=None)
