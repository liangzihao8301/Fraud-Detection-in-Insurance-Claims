# %%
#增加交叉特征
#Score: Score: 0.89048
#使用5折交叉验证,增加scale_pos_weight参数
#Score: Score: 0.89292
#增加G/L
#Score: 0.88696
#交叉特征增加location_type，不使用G/L
#Score: 0.88777
#增加incident_location_type、incident_location_street、policy_bind_date_year&auto_year_diff、incident_date_year&auto_year_diff、duration
#

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib # 注意这个也要import一次
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score, mean_squared_error, roc_curve, auc
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")

# %%
#数据加载
train_data = pd.read_csv('./data/train.csv')
test_data = pd.read_csv('./data/test.csv')

# %%
datas = pd.concat((train_data, test_data))
datas.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 数据探索

# %%
cat_columns = datas.select_dtypes(include=['O']).columns
numerical_columns = datas.select_dtypes(exclude=['O']).columns

# %%
col_name = []
unique_value = []
for col in cat_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_cat_col_unique = pd.DataFrame()
df_cat_col_unique['col_name'] = col_name
df_cat_col_unique['unique_value'] = unique_value
df_cat_col_unique = df_cat_col_unique.sort_values('unique_value', ascending= False)
# df_cat_col_unique

# %%
col_name = []
unique_value = []
for col in numerical_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_numerical_col_unique = pd.DataFrame()
df_numerical_col_unique['col_name'] = col_name
df_numerical_col_unique['unique_value'] = unique_value
df_numerical_col_unique = df_numerical_col_unique.sort_values('unique_value', ascending= False)
# df_numerical_col_unique

# %%
df_cat_col_unique
# df_numerical_col_unique
# Out:
#                    col_name  unique_value
# 15        incident_location          1000
# 0          policy_bind_date           951
# 8             incident_date            60
# 19               auto_model            39
# 6           insured_hobbies            20
# 5        insured_occupation            14
# 18                auto_make            14
# 4   insured_education_level             7
# 13           incident_state             7
# 14            incident_city             7
# 7      insured_relationship             6
# 12    authorities_contacted             5
# 9             incident_type             4
# 11        incident_severity             4
# 10           collision_type             4
# 1              policy_state             3
# 2                policy_csl             3
# 16          property_damage             3
# 17  police_report_available             3
# 3               insured_sex             2

# %% [markdown]
# ## 特征工程

# %% [markdown]
# #### 标签编码 policy_bind_date、incident_date

# %%
datas['policy_bind_date'] = pd.to_datetime(datas['policy_bind_date'])
datas['incident_date'] = pd.to_datetime(datas['incident_date'])

# %%
datas['policy_bind_date_year'] = datas['policy_bind_date'].dt.year
datas['policy_bind_date_month'] = datas['policy_bind_date'].dt.month
datas['policy_bind_date_day'] = datas['policy_bind_date'].dt.day
datas['policy_bind_date_weekday'] = datas['policy_bind_date'].dt.weekday

datas['incident_date_year'] = datas['incident_date'].dt.year
datas['incident_date_month'] = datas['incident_date'].dt.month
datas['incident_date_day'] = datas['incident_date'].dt.day
datas['incident_date_weekday'] = datas['incident_date'].dt.weekday

# %%
# 查看最小、最大日期
# datas.policy_bind_date.min() #1990-01-08
# datas.policy_bind_date.max() #2015-02-22

# datas.incident_date.min() #2015-01-01
# datas.incident_date.max() #2015-03-01

# %%
base_date = datas.policy_bind_date.min()
#转换为diff
datas['policy_bind_date_diff'] = (datas['policy_bind_date'] - base_date).dt.days
datas['incident_date_diff'] = (datas['incident_date'] - base_date).dt.days
datas['incident_date&policy_bind_date_diff'] = datas['incident_date_diff'] - datas['policy_bind_date_diff']

# %% [markdown]
# #### 构造交叉业务特征

# %%
datas['injury_claim_pct'] = datas['injury_claim']/datas['total_claim_amount']
datas['property_claim_pct'] = datas['property_claim']/datas['total_claim_amount']
datas['vehicle_claim_pct'] = datas['vehicle_claim']/datas['total_claim_amount']

# %%
datas['is_injury_claim'] = datas['injury_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_property_claim'] = datas['property_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_vehicle_claim'] = datas['vehicle_claim'].apply(lambda x: '1' if x >0 else '0')

# %%
datas['incident_type_&_is_injury_claim'] = datas['incident_type'] + '_' + datas['is_injury_claim']
datas['incident_type_&_is_property_claim'] = datas['incident_type'] + '_' + datas['is_property_claim']
datas['incident_type_&_is_vehicle_claim'] = datas['incident_type'] + '_' + datas['is_vehicle_claim']

datas['collision_type_&_is_injury_claim'] = datas['collision_type'] + '_' + datas['is_injury_claim']
datas['collision_type_&_is_property_claim'] = datas['collision_type'] + '_' + datas['is_property_claim']
datas['collision_type_&_is_vehicle_claim'] = datas['collision_type'] + '_' + datas['is_vehicle_claim']

# %%
datas['umbrella_limit_2_total_claim_amount'] = datas['umbrella_limit']/datas['total_claim_amount']

# %%
# datas['G/L'] = datas['capital-gains'] + datas['capital-loss']

# %%
datas['incident_location_type'] = datas['incident_location'].apply(lambda x: x.split()[-1])
datas['incident_location_street'] = datas['incident_location'].apply(lambda x: ' '.join(x.split()[-2:]))

# %%
#购车年份与投保年份之差
datas['policy_bind_date_year&auto_year_diff'] = datas['policy_bind_date_year'] - datas['auto_year']

#购车年份与出险年份之差
datas['incident_date_year&auto_year_diff'] = datas['incident_date_year'] - datas['auto_year']

#成为客户的时长与购报后出险时长之差
datas['duration'] = round((datas['incident_date'] - datas['policy_bind_date']).dt.days/30) - datas['months_as_customer']

# %%
# datas[['incident_type', 'collision_type', 'policy_csl', 'policy_annual_premium', 'umbrella_limit', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'capital-gains', 'capital-loss']][datas['fraud_reported'] > 0]

# %%
#检查单个特征
# datas.incident_city.nunique()
# datas['incident_type'].value_counts()

# %%
datas.drop(['policy_bind_date', 'incident_date', '_c39', 'incident_location', 'policy_number', 'insured_zip'], axis= 1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_columns = datas.select_dtypes(include= ['O']).columns

# %%
for col in cat_columns:
    le = LabelEncoder()
    datas[col] = le.fit_transform(datas[col])

datas[cat_columns]
# Out:
#      policy_state  policy_csl  insured_sex  insured_education_level  \
# 0               1           2            0                        5
# 1               0           1            1                        3
# 2               0           2            0                        2
# 3               2           2            1                        3
# 4               2           0            0                        4
# ..            ...         ...          ...                      ...
# 995             0           2            0                        1
# 996             1           1            1                        4
# 997             1           2            0                        0
# 998             1           0            0                        4
# 999             1           0            1                        5
#
#      insured_occupation  insured_hobbies  insured_relationship  incident_type  \
# 0                    10               15                     1              2
# 1                     2               14                     2              0
# 2                     6               16                     5              2
# 3                    13               18                     3              0
# 4                     2               18                     3              0
# ..                  ...              ...                   ...            ...
# 995                   9               11                     1              1
# 996                   0               12                     4              0
# 997                   7               10                     1              2
# 998                  10               10                     4              0
# 999                  10                7                     2              2
#
#      collision_type  incident_severity  ...  is_property_claim  \
# 0                 3                  2  ...                  1
# 1                 3                  1  ...                  1
# 2                 3                  2  ...                  1
# 3                 1                  0  ...                  1
# 4                 2                  2  ...                  1
# ..              ...                ...  ...                ...
# 995               0                  3  ...                  1
# 996               3                  2  ...                  1
# 997               2                  1  ...                  1
# 998               3                  1  ...                  1
# 999               1                  1  ...                  1
#
#      is_vehicle_claim  incident_type_&_is_injury_claim  \
# 0                   0                                5
# 1                   0                                1
# 2                   0                                5
# 3                   0                                1
# 4                   0                                1
# ..                ...                              ...
# 995                 0                                3
# 996                 0                                1
# 997                 0                                5
# 998                 0                                1
# 999                 0                                5
#
#      incident_type_&_is_property_claim  incident_type_&_is_vehicle_claim  \
# 0                                    5                                 2
# 1                                    1                                 0
# 2                                    5                                 2
# 3                                    1                                 0
# 4                                    1                                 0
# ..                                 ...                               ...
# 995                                  3                                 1
# 996                                  1                                 0
# 997                                  5                                 2
# 998                                  1                                 0
# 999                                  5                                 2
#
#      collision_type_&_is_injury_claim  collision_type_&_is_property_claim  \
# 0                                   7                                   7
# 1                                   7                                   7
# 2                                   7                                   7
# 3                                   3                                   3
# 4                                   5                                   5
# ..                                ...                                 ...
# 995                                 1                                   1
# 996                                 7                                   7
# 997                                 5                                   5
# 998                                 7                                   7
# 999                                 3                                   3
#
#      collision_type_&_is_vehicle_claim  incident_location_type  \
# 0                                    3                       4
# 1                                    3                       0
# 2                                    3                       0
# 3                                    1                       0
# 4                                    2                       0
# ..                                 ...                     ...
# 995                                  0                       5
# 996                                  3                       1
# 997                                  2                       0
# 998                                  3                       4
# 999                                  1                       3
#
#      incident_location_street
# 0                         106
# 1                         144
# 2                          78
# 3                         144
# 4                          18
# ..                        ...
# 995                       125
# 996                        73
# 997                        78
# 998                       100
# 999                        93
#
# [1000 rows x 28 columns]

# %%
# 数据集切分
train = datas[datas['fraud_reported'].notnull()]
test = datas[datas['fraud_reported'].isnull()]

# %%
train_X = train.drop(['fraud_reported'], axis=1)
train_y = train['fraud_reported']
test_X = test.drop(['fraud_reported'], axis=1)

# %%
#增加检验
# train_X,eval_X,train_y,eval_y = train_test_split(train_X, train_y, test_size=0.2, random_state=2022, stratify=train_y)

# %% [markdown]
# ## 使用lgbm 训练

# %%
import lightgbm as lgb

# %%
model_lgb = lgb.LGBMClassifier(
            num_leaves=2**5-1, reg_alpha=0.25, reg_lambda=0.25, objective='binary',
            max_depth=-1, learning_rate=0.005, min_child_samples=3, random_state=2022,
            n_estimators=2000, subsample=1, colsample_bytree=1,
        )

# %%
model_lgb.fit(train_X, train_y)
# Out:
# LGBMClassifier(colsample_bytree=1, learning_rate=0.005, min_child_samples=3,
#                n_estimators=2000, objective='binary', random_state=2022,
#                reg_alpha=0.25, reg_lambda=0.25, subsample=1)

# %%
y_pred = model_lgb.predict_proba(test_X)[:, 1]

#检验
# y_pred = model_lgb.predict_proba(eval_X)[:, 1]

# %%
y_pred
# Out:
# array([1.31248008e-02, 3.18037530e-01, 5.11240594e-03, 2.87712811e-02,
#        1.86754201e-03, 6.07650274e-03, 4.18409258e-03, 6.77287914e-03,
#        1.81909754e-03, 1.79537396e-03, 4.99757954e-02, 3.60250886e-03,
#        5.77568437e-01, 2.87057495e-03, 3.09658830e-03, 5.87845503e-01,
#        9.35539633e-03, 1.46700558e-02, 9.43991162e-01, 6.26243006e-03,
#        2.16648306e-02, 3.98612230e-01, 9.52440316e-01, 4.69268300e-02,
#        2.38998131e-02, 8.87035561e-01, 3.78563737e-03, 6.90909039e-03,
#        2.40839678e-01, 5.10239683e-02, 7.97933923e-01, 2.83426246e-02,
#        3.74890734e-01, 3.61547298e-03, 1.22258866e-02, 9.62587433e-03,
#        6.72719191e-01, 3.39565822e-03, 2.09359323e-03, 8.06922795e-02,
#        5.74200192e-01, 1.05729684e-02, 8.79456975e-03, 1.01409338e-02,
#        1.06442288e-02, 4.66738711e-03, 3.52749265e-03, 2.01668996e-02,
#        4.69677084e-01, 2.04203639e-03, 6.74111764e-03, 7.73404986e-02,
#        3.69352736e-03, 2.26554681e-01, 9.31816930e-01, 4.41148453e-03,
#        4.39323806e-03, 5.39363739e-01, 7.00680916e-03, 5.94646197e-01,
#        4.77827756e-03, 7.14348810e-03, 3.70769981e-03, 6.52712049e-01,
#        1.26386455e-02, 1.72680309e-03, 5.62387838e-01, 9.72693755e-01,
#        2.16692717e-02, 3.69421007e-03, 1.47618090e-03, 1.57383628e-01,
#        3.45855765e-01, 7.86319681e-01, 3.59943517e-03, 8.16261904e-03,
#        3.26515209e-03, 9.22009968e-04, 9.44003881e-01, 1.04245933e-02,
#        8.12449535e-03, 3.24439732e-03, 9.24244091e-01, 2.46819990e-02,
#        1.14236619e-02, 5.63867162e-03, 2.22863263e-02, 1.06691443e-02,
#        2.26342196e-02, 2.84314884e-01, 6.59422934e-03, 4.06729612e-01,
#        9.50380413e-01, 4.09021914e-03, 1.01006137e-03, 2.72565907e-03,
#        5.54782789e-02, 4.44031791e-03, 2.89822482e-01, 5.98770820e-03,
#        4.84820765e-02, 9.64456915e-01, 4.60415574e-03, 2.97352183e-03,
#        1.63220906e-03, 8.06175752e-01, 4.41952462e-02, 5.00503263e-01,
#        2.50349414e-02, 3.12606383e-03, 1.71294891e-03, 3.69976157e-03,
#        2.69629179e-02, 2.17447846e-03, 2.81489819e-03, 1.22876315e-01,
#        9.67790523e-01, 5.63169657e-03, 7.05040118e-01, 4.10062242e-03,
#        6.34432868e-03, 7.23536006e-03, 9.34917526e-01, 8.43647268e-01,
#        3.90243005e-01, 3.32981616e-01, 3.49286516e-03, 1.90639246e-03,
#        9.00191832e-01, 2.48546279e-03, 2.28200073e-03, 3.26917280e-01,
#        6.11103421e-03, 1.67508779e-02, 3.40357006e-03, 1.60875353e-03,
#        1.04669706e-02, 5.97314440e-01, 9.30529186e-01, 2.04008811e-02,
#        1.55105409e-02, 1.15183213e-02, 7.64458319e-01, 1.56854931e-02,
#        5.15379118e-01, 6.70236295e-01, 2.25576738e-02, 5.05015796e-03,
#        9.67683754e-03, 2.68611370e-03, 8.23859153e-03, 7.90233966e-01,
#        8.03234891e-01, 4.72661630e-01, 7.64027632e-03, 2.52969514e-03,
#        7.59874720e-01, 2.61682561e-03, 1.39634053e-02, 2.29226519e-02,
#        1.39366208e-01, 1.06900543e-02, 7.49375319e-01, 6.77371305e-01,
#        7.61616929e-01, 6.65693925e-01, 5.94562106e-03, 1.54991107e-03,
#        7.85817335e-01, 1.30442313e-02, 1.52267551e-03, 3.07242775e-02,
#        4.98984683e-01, 7.58580094e-01, 6.92882195e-03, 9.79281825e-01,
#        3.59253340e-03, 1.13051583e-02, 1.51364299e-02, 3.70845902e-03,
#        2.03203614e-03, 1.85947630e-02, 2.86089362e-03, 2.96637637e-03,
#        2.09052324e-02, 9.24596763e-01, 9.66717567e-03, 9.74327426e-01,
#        3.06281797e-03, 2.00778877e-02, 4.64219378e-03, 1.79655272e-02,
#        4.25706441e-02, 9.39729418e-01, 8.68561258e-01, 3.29024536e-03,
#        3.85577009e-02, 1.60842310e-03, 2.18250542e-03, 6.12134415e-01,
#        3.58550766e-02, 5.59173556e-03, 9.72571002e-01, 3.22107775e-02,
#        5.29641351e-03, 9.99039430e-03, 1.70284906e-02, 1.67110503e-01,
#        1.06561056e-02, 4.09496996e-03, 2.10836153e-03, 2.00561043e-03,
#        2.25745963e-03, 3.84473802e-03, 1.77391605e-01, 3.37834743e-02,
#        6.29851211e-02, 2.66628763e-03, 6.45306133e-03, 7.95738215e-01,
#        1.23433333e-02, 2.90453803e-02, 1.16098494e-02, 1.27144040e-02,
#        1.37336262e-02, 9.03721353e-01, 1.41843513e-03, 1.53264946e-02,
#        9.84573088e-01, 2.92217643e-02, 9.55001225e-03, 2.71617597e-02,
#        3.45491098e-03, 4.76069333e-03, 7.92927116e-01, 7.86232203e-01,
#        2.39079931e-03, 2.82331934e-03, 1.16980379e-03, 2.58178369e-03,
#        3.27844383e-01, 6.67117658e-03, 3.50859917e-03, 5.20949819e-03,
#        1.42640633e-03, 6.33416367e-01, 1.25296749e-02, 2.26637795e-02,
#        1.57758236e-03, 1.12374158e-02, 3.58655246e-01, 3.25336552e-01,
#        2.64913790e-01, 1.61421749e-03, 9.72691449e-04, 6.25699039e-03,
#        2.44760346e-01, 5.06159846e-03, 9.46374788e-01, 1.51007464e-02,
#        8.89114680e-01, 5.03267331e-03, 8.42683029e-01, 3.17339518e-03,
#        5.76070824e-03, 1.69042178e-02, 7.49878219e-02, 2.45902223e-02,
#        4.40966186e-03, 1.67086358e-03, 9.29199298e-01, 7.95184817e-03,
#        1.62213443e-03, 6.52056293e-01, 4.52086209e-01, 7.31377055e-03,
#        6.73097674e-03, 3.14211216e-03, 7.80539000e-01, 2.68710847e-03,
#        2.15564553e-03, 9.20285744e-03, 7.12354418e-03, 7.86700660e-01,
#        4.95977404e-01, 6.30791391e-03, 8.40309988e-01, 1.46469548e-01,
#        2.02428037e-01, 9.68497578e-01, 7.95471190e-03, 8.79081243e-01,
#        1.77618288e-01, 3.06540266e-02, 4.25928587e-01, 3.39189300e-03,
#        1.83980207e-03, 7.62646989e-04, 1.86731181e-02, 3.17125600e-03])

# %%
fig, ax = plt.subplots(figsize=(6,18))
lgb.plot_importance(model_lgb, max_num_features=50, ax = ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
#检验
# roc_auc_score(eval_y, y_pred)

# %%
# submission = pd.read_csv('./data/sampleSubmission.csv')
# submission['fraud_reported'] = y_pred
# submission.to_csv('./submission/submission.csv', index=None)

# %% [markdown]
# ## 使用五折交叉验证的LightGBM

# %%
from sklearn.model_selection import StratifiedKFold, KFold
import lightgbm as lgb

# %%
params_lgb = {
    'num_leaves': 2**5-1, 'reg_alpha': 0.25, 'reg_lambda': 0.25, 'objective': 'binary',
    'max_depth': -1, 'learning_rate': 0.005, 'min_child_samples': 3, 'random_state': 2022,
    #'n_estimators': 2000, 
    'subsample': 1, 'colsample_bytree': 1, 'scale_pos_weight': 3
}

# %%
NFOLD = 10

# %%
kf = StratifiedKFold(n_splits = NFOLD, shuffle = True, random_state = 2022)

y_pred = np.zeros(len(test_X))

#检验
# y_pred = np.zeros(len(eval_X))

# %%
for fold, (train_index, val_index) in enumerate(kf.split(train_X, train_y)):
    X_fold_train, X_fold_val = train_X.iloc[train_index, :], train_X.iloc[val_index, :]
    y_fold_train, y_fold_val = train_y.iloc[train_index], train_y.iloc[val_index]
    train_set = lgb.Dataset(X_fold_train, y_fold_train)
    val_set = lgb.Dataset(X_fold_val, y_fold_val, reference=train_set)

    model_lgb = lgb.train(params_lgb, train_set, num_boost_round=2000, #early_stopping_rounds=50,
                      valid_sets = val_set, verbose_eval=100)

    print('kf.n_splits:', kf.n_splits)
    y_pred += model_lgb.predict(test_X, num_iteration=model_lgb.best_iteration)/kf.n_splits
    
    #检验
#     y_pred += model_lgb.predict(eval_X, num_iteration=model_lgb.best_iteration)/kf.n_splits

# y_pred = [1 if y > 0.5 else 0 for y in y_pred]
# rmse = metrics.accuracy_score(y_pred,y_test)
# print(rmse)
# Out:
# [LightGBM] [Info] Number of positive: 163, number of negative: 467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000690 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2837
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258730 -> initscore=-1.052579
# [LightGBM] [Info] Start training from score -1.052579
# [100]	valid_0's binary_logloss: 0.461975
# [200]	valid_0's binary_logloss: 0.438013
# [300]	valid_0's binary_logloss: 0.43379
# [400]	valid_0's binary_logloss: 0.455693
# [500]	valid_0's binary_logloss: 0.459869
# [600]	valid_0's binary_logloss: 0.468844
# [700]	valid_0's binary_logloss: 0.484507
# [800]	valid_0's binary_logloss: 0.499077
# [900]	valid_0's binary_logloss: 0.50748
# [1000]	valid_0's binary_logloss: 0.514974
# [1100]	valid_0's binary_logloss: 0.519523
# [1200]	valid_0's binary_logloss: 0.529024
# [1300]	valid_0's binary_logloss: 0.542198
# [1400]	valid_0's binary_logloss: 0.553655
# [1500]	valid_0's binary_logloss: 0.561029
# [1600]	valid_0's binary_logloss: 0.565391
# [1700]	valid_0's binary_logloss: 0.569688
# [1800]	valid_0's binary_logloss: 0.573616
# [1900]	valid_0's binary_logloss: 0.577684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.579385
# kf.n_splits: 10
# [LightGBM] [Info] Number of positive: 163, number of negative: 467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000651 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2846
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258730 -> initscore=-1.052579
# [LightGBM] [Info] Start training from score -1.052579
# [100]	valid_0's binary_logloss: 0.46024
# [200]	valid_0's binary_logloss: 0.459028
# [300]	valid_0's binary_logloss: 0.463896
# [400]	valid_0's binary_logloss: 0.457313
# [500]	valid_0's binary_logloss: 0.470292
# [600]	valid_0's binary_logloss: 0.479133
# [700]	valid_0's binary_logloss: 0.495233
# [800]	valid_0's binary_logloss: 0.50906
# [900]	valid_0's binary_logloss: 0.512385
# [1000]	valid_0's binary_logloss: 0.520676
# [1100]	valid_0's binary_logloss: 0.525423
# [1200]	valid_0's binary_logloss: 0.531516
# [1300]	valid_0's binary_logloss: 0.535075
# [1400]	valid_0's binary_logloss: 0.53943
# [1500]	valid_0's binary_logloss: 0.545629
# [1600]	valid_0's binary_logloss: 0.552514
# [1700]	valid_0's binary_logloss: 0.562168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's binary_logloss: 0.567414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.574219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.582782
# kf.n_splits: 10
# [LightGBM] [Info] Number of positive: 163, number of negative: 467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000757 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2850
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258730 -> initscore=-1.052579
# [LightGBM] [Info] Start training from score -1.052579
# [100]	valid_0's binary_logloss: 0.447596
# [200]	valid_0's binary_logloss: 0.427932
# [300]	valid_0's binary_logloss: 0.443669
# [400]	valid_0's binary_logloss: 0.462602
# [500]	valid_0's binary_logloss: 0.486544
# [600]	valid_0's binary_logloss: 0.493668
# [700]	valid_0's binary_logloss: 0.49598
# [800]	valid_0's binary_logloss: 0.50359
# [900]	valid_0's binary_logloss: 0.518246
# [1000]	valid_0's binary_logloss: 0.533042
# [1100]	valid_0's binary_logloss: 0.543605
# [1200]	valid_0's binary_logloss: 0.552022
# [1300]	valid_0's binary_logloss: 0.559214
# [1400]	valid_0's binary_logloss: 0.565795
# [1500]	valid_0's binary_logloss: 0.570036
# [1600]	valid_0's binary_logloss: 0.573402
# [1700]	valid_0's binary_logloss: 0.577911
# [1800]	valid_0's binary_logloss: 0.583175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.587181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.587702
# kf.n_splits: 10
# [LightGBM] [Info] Number of positive: 163, number of negative: 467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000772 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2859
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258730 -> initscore=-1.052579
# [LightGBM] [Info] Start training from score -1.052579
# [100]	valid_0's binary_logloss: 0.464986
# [200]	valid_0's binary_logloss: 0.431311
# [300]	valid_0's binary_logloss: 0.416481
# [400]	valid_0's binary_logloss: 0.414599
# [500]	valid_0's binary_logloss: 0.422322
# [600]	valid_0's binary_logloss: 0.431644
# [700]	valid_0's binary_logloss: 0.444743
# [800]	valid_0's binary_logloss: 0.456645
# [900]	valid_0's binary_logloss: 0.467879
# [1000]	valid_0's binary_logloss: 0.479203
# [1100]	valid_0's binary_logloss: 0.490046
# [1200]	valid_0's binary_logloss: 0.499692
# [1300]	valid_0's binary_logloss: 0.50897
# [1400]	valid_0's binary_logloss: 0.514717
# [1500]	valid_0's binary_logloss: 0.529977
# [1600]	valid_0's binary_logloss: 0.545017
# [1700]	valid_0's binary_logloss: 0.557573
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's binary_logloss: 0.569046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.580291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.592295
# kf.n_splits: 10
# [LightGBM] [Info] Number of positive: 163, number of negative: 467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000656 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2844
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258730 -> initscore=-1.052579
# [LightGBM] [Info] Start training from score -1.052579
# [100]	valid_0's binary_logloss: 0.525294
# [200]	valid_0's binary_logloss: 0.502499
# [300]	valid_0's binary_logloss: 0.503233
# [400]	valid_0's binary_logloss: 0.515705
# [500]	valid_0's binary_logloss: 0.523667
# [600]	valid_0's binary_logloss: 0.5388
# [700]	valid_0's binary_logloss: 0.552776
# [800]	valid_0's binary_logloss: 0.571416
# [900]	valid_0's binary_logloss: 0.59027
# [1000]	valid_0's binary_logloss: 0.60391
# [1100]	valid_0's binary_logloss: 0.61364
# [1200]	valid_0's binary_logloss: 0.623838
# [1300]	valid_0's binary_logloss: 0.632727
# [1400]	valid_0's binary_logloss: 0.638285
# [1500]	valid_0's binary_logloss: 0.647047
# [1600]	valid_0's binary_logloss: 0.656042
# [1700]	valid_0's binary_logloss: 0.665306
# [1800]	valid_0's binary_logloss: 0.673677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.683566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.6889
# kf.n_splits: 10
# [LightGBM] [Info] Number of positive: 163, number of negative: 467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001771 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2849
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258730 -> initscore=-1.052579
# [LightGBM] [Info] Start training from score -1.052579
# [100]	valid_0's binary_logloss: 0.455229
# [200]	valid_0's binary_logloss: 0.419578
# [300]	valid_0's binary_logloss: 0.415644
# [400]	valid_0's binary_logloss: 0.422898
# [500]	valid_0's binary_logloss: 0.435944
# [600]	valid_0's binary_logloss: 0.44524
# [700]	valid_0's binary_logloss: 0.454674
# [800]	valid_0's binary_logloss: 0.460492
# [900]	valid_0's binary_logloss: 0.466093
# [1000]	valid_0's binary_logloss: 0.474055
# [1100]	valid_0's binary_logloss: 0.484211
# [1200]	valid_0's binary_logloss: 0.489386
# [1300]	valid_0's binary_logloss: 0.495192
# [1400]	valid_0's binary_logloss: 0.500598
# [1500]	valid_0's binary_logloss: 0.507498
# [1600]	valid_0's binary_logloss: 0.514728
# [1700]	valid_0's binary_logloss: 0.520781
# [1800]	valid_0's binary_logloss: 0.525457
# [1900]	valid_0's binary_logloss: 0.532493
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.536768
# kf.n_splits: 10
# [LightGBM] [Info] Number of positive: 163, number of negative: 467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000676 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2837
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258730 -> initscore=-1.052579
# [LightGBM] [Info] Start training from score -1.052579
# [100]	valid_0's binary_logloss: 0.426615
# [200]	valid_0's binary_logloss: 0.375258
# [300]	valid_0's binary_logloss: 0.357458
# [400]	valid_0's binary_logloss: 0.355205
# [500]	valid_0's binary_logloss: 0.358785
# [600]	valid_0's binary_logloss: 0.368419
# [700]	valid_0's binary_logloss: 0.382884
# [800]	valid_0's binary_logloss: 0.39479
# [900]	valid_0's binary_logloss: 0.405468
# [1000]	valid_0's binary_logloss: 0.419811
# [1100]	valid_0's binary_logloss: 0.433186
# [1200]	valid_0's binary_logloss: 0.442895
# [1300]	valid_0's binary_logloss: 0.446668
# [1400]	valid_0's binary_logloss: 0.449986
# [1500]	valid_0's binary_logloss: 0.455475
# [1600]	valid_0's binary_logloss: 0.461058
# [1700]	valid_0's binary_logloss: 0.468149
# [1800]	valid_0's binary_logloss: 0.471364
# [1900]	valid_0's binary_logloss: 0.473845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.475539
# kf.n_splits: 10
# [LightGBM] [Info] Number of positive: 163, number of negative: 467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000668 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2847
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258730 -> initscore=-1.052579
# [LightGBM] [Info] Start training from score -1.052579
# [100]	valid_0's binary_logloss: 0.43464
# [200]	valid_0's binary_logloss: 0.403587
# [300]	valid_0's binary_logloss: 0.401872
# [400]	valid_0's binary_logloss: 0.414273
# [500]	valid_0's binary_logloss: 0.416083
# [600]	valid_0's binary_logloss: 0.418147
# [700]	valid_0's binary_logloss: 0.423394
# [800]	valid_0's binary_logloss: 0.430494
# [900]	valid_0's binary_logloss: 0.438995
# [1000]	valid_0's binary_logloss: 0.44882
# [1100]	valid_0's binary_logloss: 0.457015
# [1200]	valid_0's binary_logloss: 0.46385
# [1300]	valid_0's binary_logloss: 0.471015
# [1400]	valid_0's binary_logloss: 0.474117
# [1500]	valid_0's binary_logloss: 0.481334
# [1600]	valid_0's binary_logloss: 0.485929
# [1700]	valid_0's binary_logloss: 0.488485
# [1800]	valid_0's binary_logloss: 0.492237
# [1900]	valid_0's binary_logloss: 0.49538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.500221
# kf.n_splits: 10
# [LightGBM] [Info] Number of positive: 163, number of negative: 467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000695 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2841
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258730 -> initscore=-1.052579
# [LightGBM] [Info] Start training from score -1.052579
# [100]	valid_0's binary_logloss: 0.370992
# [200]	valid_0's binary_logloss: 0.295325
# [300]	valid_0's binary_logloss: 0.253513
# [400]	valid_0's binary_logloss: 0.243064
# [500]	valid_0's binary_logloss: 0.237384
# [600]	valid_0's binary_logloss: 0.237039
# [700]	valid_0's binary_logloss: 0.239986
# [800]	valid_0's binary_logloss: 0.247319
# [900]	valid_0's binary_logloss: 0.250157
# [1000]	valid_0's binary_logloss: 0.258323
# [1100]	valid_0's binary_logloss: 0.259147
# [1200]	valid_0's binary_logloss: 0.260039
# [1300]	valid_0's binary_logloss: 0.260399
# [1400]	valid_0's binary_logloss: 0.262179
# [1500]	valid_0's binary_logloss: 0.263778
# [1600]	valid_0's binary_logloss: 0.26608
# [1700]	valid_0's binary_logloss: 0.269989
# [1800]	valid_0's binary_logloss: 0.273141
# [1900]	valid_0's binary_logloss: 0.275608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.277692
# kf.n_splits: 10
# [LightGBM] [Info] Number of positive: 162, number of negative: 468
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000807 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2844
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.257143 -> initscore=-1.060872
# [LightGBM] [Info] Start training from score -1.060872
# [100]	valid_0's binary_logloss: 0.430731
# [200]	valid_0's binary_logloss: 0.377176
# [300]	valid_0's binary_logloss: 0.354934
# [400]	valid_0's binary_logloss: 0.342772
# [500]	valid_0's binary_logloss: 0.351837
# [600]	valid_0's binary_logloss: 0.362381
# [700]	valid_0's binary_logloss: 0.363806
# [800]	valid_0's binary_logloss: 0.369792
# [900]	valid_0's binary_logloss: 0.377929
# [1000]	valid_0's binary_logloss: 0.386888
# [1100]	valid_0's binary_logloss: 0.396268
# [1200]	valid_0's binary_logloss: 0.405815
# [1300]	valid_0's binary_logloss: 0.416604
# [1400]	valid_0's binary_logloss: 0.422629
# [1500]	valid_0's binary_logloss: 0.427919
# [1600]	valid_0's binary_logloss: 0.43314
# [1700]	valid_0's binary_logloss: 0.438459
# [1800]	valid_0's binary_logloss: 0.442676
# [1900]	valid_0's binary_logloss: 0.444178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.44561
# kf.n_splits: 10

# %%
#检验
# roc_auc_score(eval_y, y_pred)

# %%
submission = pd.read_csv('./data/sampleSubmission.csv')
submission['fraud_reported'] = y_pred
submission.to_csv('./submission/submission_Kfold.csv', index=None)
