# %%
#增加交叉特征
#Score: Score: 0.89048
#交叉特征增加G/L
#Score: 0.88533
#交叉特征增加location_type，不使用G/L
#Score: 0.88858

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib # 注意这个也要import一次
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score, mean_squared_error, roc_curve, auc
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")

# %%
#数据加载
train_data = pd.read_csv('./data/train.csv')
test_data = pd.read_csv('./data/test.csv')

# %%
datas = pd.concat((train_data, test_data))
datas.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 数据探索

# %%
cat_columns = datas.select_dtypes(include=['O']).columns
numerical_columns = datas.select_dtypes(exclude=['O']).columns

# %%
col_name = []
unique_value = []
for col in cat_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_cat_col_unique = pd.DataFrame()
df_cat_col_unique['col_name'] = col_name
df_cat_col_unique['unique_value'] = unique_value
df_cat_col_unique = df_cat_col_unique.sort_values('unique_value', ascending= False)
# df_cat_col_unique

# %%
col_name = []
unique_value = []
for col in numerical_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_numerical_col_unique = pd.DataFrame()
df_numerical_col_unique['col_name'] = col_name
df_numerical_col_unique['unique_value'] = unique_value
df_numerical_col_unique = df_numerical_col_unique.sort_values('unique_value', ascending= False)
# df_numerical_col_unique

# %%
df_cat_col_unique
# df_numerical_col_unique
# Out:
#                    col_name  unique_value
# 15        incident_location          1000
# 0          policy_bind_date           951
# 8             incident_date            60
# 19               auto_model            39
# 6           insured_hobbies            20
# 5        insured_occupation            14
# 18                auto_make            14
# 4   insured_education_level             7
# 13           incident_state             7
# 14            incident_city             7
# 7      insured_relationship             6
# 12    authorities_contacted             5
# 9             incident_type             4
# 11        incident_severity             4
# 10           collision_type             4
# 1              policy_state             3
# 2                policy_csl             3
# 16          property_damage             3
# 17  police_report_available             3
# 3               insured_sex             2

# %% [markdown]
# ## 特征工程

# %% [markdown]
# #### 标签编码 policy_bind_date、incident_date

# %%
datas['policy_bind_date'] = pd.to_datetime(datas['policy_bind_date'])
datas['incident_date'] = pd.to_datetime(datas['incident_date'])

# %%
datas['policy_bind_date_year'] = datas['policy_bind_date'].dt.year
datas['policy_bind_date_month'] = datas['policy_bind_date'].dt.month
datas['policy_bind_date_day'] = datas['policy_bind_date'].dt.day
datas['policy_bind_date_weekday'] = datas['policy_bind_date'].dt.weekday

datas['incident_date_year'] = datas['incident_date'].dt.year
datas['incident_date_month'] = datas['incident_date'].dt.month
datas['incident_date_day'] = datas['incident_date'].dt.day
datas['incident_date_weekday'] = datas['incident_date'].dt.weekday

# %%
# 查看最小、最大日期
# datas.policy_bind_date.min() #1990-01-08
# datas.policy_bind_date.max() #2015-02-22

# datas.incident_date.min() #2015-01-01
# datas.incident_date.max() #2015-03-01

# %%
base_date = datas.policy_bind_date.min()
#转换为diff
datas['policy_bind_date_diff'] = (datas['policy_bind_date'] - base_date).dt.days
datas['incident_date_diff'] = (datas['incident_date'] - base_date).dt.days
datas['incident_date&policy_bind_date_diff'] = datas['incident_date_diff'] - datas['policy_bind_date_diff']

# %% [markdown]
# #### 构造交叉业务特征

# %%
datas['injury_claim_pct'] = datas['injury_claim']/datas['total_claim_amount']
datas['property_claim_pct'] = datas['property_claim']/datas['total_claim_amount']
datas['vehicle_claim_pct'] = datas['vehicle_claim']/datas['total_claim_amount']

# %%
datas['is_injury_claim'] = datas['injury_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_property_claim'] = datas['property_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_vehicle_claim'] = datas['vehicle_claim'].apply(lambda x: '1' if x >0 else '0')

# %%
datas['incident_type_&_is_injury_claim'] = datas['incident_type'] + '_' + datas['is_injury_claim']
datas['incident_type_&_is_property_claim'] = datas['incident_type'] + '_' + datas['is_property_claim']
datas['incident_type_&_is_vehicle_claim'] = datas['incident_type'] + '_' + datas['is_vehicle_claim']

datas['collision_type_&_is_injury_claim'] = datas['collision_type'] + '_' + datas['is_injury_claim']
datas['collision_type_&_is_property_claim'] = datas['collision_type'] + '_' + datas['is_property_claim']
datas['collision_type_&_is_vehicle_claim'] = datas['collision_type'] + '_' + datas['is_vehicle_claim']

# %%
datas['umbrella_limit_2_total_claim_amount'] = datas['umbrella_limit']/datas['total_claim_amount']

# %%
# datas['G/L'] = datas['capital-gains'] + datas['capital-loss']

# %%
datas['location_type'] = datas['incident_location'].apply(lambda x: x.split()[-1])

# %%
# datas[['incident_type', 'collision_type', 'policy_csl', 'policy_annual_premium', 'umbrella_limit', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'capital-gains', 'capital-loss']][datas['fraud_reported'] > 0]

# %%
#检查单个特征
# datas.incident_city.nunique()
# datas['incident_type'].value_counts()

# %%
datas.drop(['policy_bind_date', 'incident_date', '_c39', 'incident_location', 'policy_number', 'insured_zip'], axis= 1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_columns = datas.select_dtypes(include= ['O']).columns

# %%
for col in cat_columns:
    le = LabelEncoder()
    datas[col] = le.fit_transform(datas[col])

datas[cat_columns]
# Out:
#      policy_state  policy_csl  insured_sex  insured_education_level  \
# 0               1           2            0                        5
# 1               0           1            1                        3
# 2               0           2            0                        2
# 3               2           2            1                        3
# 4               2           0            0                        4
# ..            ...         ...          ...                      ...
# 995             0           2            0                        1
# 996             1           1            1                        4
# 997             1           2            0                        0
# 998             1           0            0                        4
# 999             1           0            1                        5
#
#      insured_occupation  insured_hobbies  insured_relationship  incident_type  \
# 0                    10               15                     1              2
# 1                     2               14                     2              0
# 2                     6               16                     5              2
# 3                    13               18                     3              0
# 4                     2               18                     3              0
# ..                  ...              ...                   ...            ...
# 995                   9               11                     1              1
# 996                   0               12                     4              0
# 997                   7               10                     1              2
# 998                  10               10                     4              0
# 999                  10                7                     2              2
#
#      collision_type  incident_severity  ...  is_injury_claim  \
# 0                 3                  2  ...                1
# 1                 3                  1  ...                1
# 2                 3                  2  ...                1
# 3                 1                  0  ...                1
# 4                 2                  2  ...                1
# ..              ...                ...  ...              ...
# 995               0                  3  ...                1
# 996               3                  2  ...                1
# 997               2                  1  ...                1
# 998               3                  1  ...                1
# 999               1                  1  ...                1
#
#      is_property_claim  is_vehicle_claim  incident_type_&_is_injury_claim  \
# 0                    1                 0                                5
# 1                    1                 0                                1
# 2                    1                 0                                5
# 3                    1                 0                                1
# 4                    1                 0                                1
# ..                 ...               ...                              ...
# 995                  1                 0                                3
# 996                  1                 0                                1
# 997                  1                 0                                5
# 998                  1                 0                                1
# 999                  1                 0                                5
#
#      incident_type_&_is_property_claim  incident_type_&_is_vehicle_claim  \
# 0                                    5                                 2
# 1                                    1                                 0
# 2                                    5                                 2
# 3                                    1                                 0
# 4                                    1                                 0
# ..                                 ...                               ...
# 995                                  3                                 1
# 996                                  1                                 0
# 997                                  5                                 2
# 998                                  1                                 0
# 999                                  5                                 2
#
#      collision_type_&_is_injury_claim  collision_type_&_is_property_claim  \
# 0                                   7                                   7
# 1                                   7                                   7
# 2                                   7                                   7
# 3                                   3                                   3
# 4                                   5                                   5
# ..                                ...                                 ...
# 995                                 1                                   1
# 996                                 7                                   7
# 997                                 5                                   5
# 998                                 7                                   7
# 999                                 3                                   3
#
#      collision_type_&_is_vehicle_claim  location_type
# 0                                    3              4
# 1                                    3              0
# 2                                    3              0
# 3                                    1              0
# 4                                    2              0
# ..                                 ...            ...
# 995                                  0              5
# 996                                  3              1
# 997                                  2              0
# 998                                  3              4
# 999                                  1              3
#
# [1000 rows x 27 columns]

# %%
# 数据集切分
train = datas[datas['fraud_reported'].notnull()]
test = datas[datas['fraud_reported'].isnull()]

# %%
train_X = train.drop(['fraud_reported'], axis=1)
train_y = train['fraud_reported']
test_X = test.drop(['fraud_reported'], axis=1)

# %% [markdown]
# ## 使用lgbm 训练

# %%
import lightgbm as lgb

# %%
model_lgb = lgb.LGBMClassifier(
            num_leaves=2**5-1, reg_alpha=0.25, reg_lambda=0.25, objective='binary',
            max_depth=-1, learning_rate=0.005, min_child_samples=3, random_state=2022,
            n_estimators=2000, subsample=1, colsample_bytree=1,
        )

# %%
model_lgb.fit(train_X, train_y)
# Out:
# LGBMClassifier(colsample_bytree=1, learning_rate=0.005, min_child_samples=3,
#                n_estimators=2000, objective='binary', random_state=2022,
#                reg_alpha=0.25, reg_lambda=0.25, subsample=1)

# %%
y_pred = model_lgb.predict_proba(test_X)[:, 1]

# %%
y_pred
# Out:
# array([1.42013860e-02, 2.02432374e-01, 8.71635151e-03, 2.11145449e-02,
#        1.67094095e-03, 2.47964682e-02, 2.97490962e-03, 1.10284330e-02,
#        1.49522417e-03, 2.48090063e-03, 8.98094669e-02, 4.83634940e-03,
#        7.95839372e-01, 2.64143561e-03, 4.01242087e-03, 8.23534124e-01,
#        7.26599111e-03, 5.45174463e-03, 5.58641413e-01, 4.38664522e-03,
#        4.87599560e-03, 5.43478258e-01, 8.51650009e-01, 1.44091119e-02,
#        9.96715550e-03, 9.14336513e-01, 2.22764127e-03, 6.52707099e-03,
#        1.48905675e-01, 7.37245076e-02, 8.76077166e-01, 9.14233240e-02,
#        5.28409553e-01, 4.38833961e-03, 1.05190079e-02, 1.44778273e-02,
#        5.10834609e-01, 2.84940890e-03, 1.74156806e-03, 1.06459663e-01,
#        6.42285356e-01, 6.69906969e-03, 6.66132672e-03, 1.47381878e-02,
#        1.59460852e-02, 3.46591322e-03, 3.45156323e-03, 1.67324660e-02,
#        6.46351048e-01, 1.89064815e-03, 3.72194301e-03, 8.39908466e-02,
#        2.94668285e-03, 6.48157526e-02, 9.46579170e-01, 7.86389205e-03,
#        6.09075854e-03, 6.53690287e-01, 6.22654767e-03, 5.84017086e-01,
#        7.32537999e-03, 1.76223873e-02, 2.16995745e-03, 7.26864502e-01,
#        4.50572605e-03, 3.10215782e-03, 8.78382307e-01, 9.79761912e-01,
#        2.65293878e-02, 4.18321857e-03, 3.06871127e-03, 1.30746910e-01,
#        2.90048519e-01, 8.21625741e-01, 1.79695819e-03, 1.91852555e-02,
#        2.83472051e-03, 1.30017476e-03, 8.96028883e-01, 2.11607027e-02,
#        9.48358054e-03, 6.73376727e-03, 9.26165969e-01, 2.93390585e-02,
#        7.05130393e-03, 7.87560940e-03, 4.17256559e-02, 6.14044069e-03,
#        3.41648659e-02, 2.79220002e-01, 1.20758767e-02, 5.68574937e-01,
#        9.38854618e-01, 8.46183587e-03, 1.23836195e-03, 3.56276502e-03,
#        4.59968070e-02, 4.70339627e-03, 1.96130177e-01, 3.55924661e-03,
#        3.60330722e-02, 9.49283409e-01, 4.32260936e-03, 3.11366998e-03,
#        2.00327443e-03, 4.86665505e-01, 6.08631569e-02, 5.31889013e-01,
#        1.33119522e-01, 3.45662480e-03, 2.24235581e-03, 3.09666184e-03,
#        3.31758613e-02, 3.46368573e-03, 2.16100515e-03, 3.58837069e-01,
#        9.70196123e-01, 6.15506186e-03, 6.65252057e-01, 4.55105649e-03,
#        4.16959186e-03, 7.68323081e-03, 9.51784897e-01, 8.43762681e-01,
#        3.06294428e-01, 5.89737594e-01, 2.18069713e-03, 1.35926812e-03,
#        7.96170667e-01, 2.44365062e-03, 3.91684522e-03, 4.93318455e-01,
#        2.48916919e-02, 5.55134786e-03, 4.95156561e-03, 1.39383650e-03,
#        8.53933665e-03, 8.04419118e-01, 9.26419747e-01, 4.35340431e-02,
#        2.47024456e-02, 5.68366242e-03, 6.78173465e-01, 2.62547386e-02,
#        5.31001275e-01, 8.50668443e-01, 4.88167814e-02, 7.41140111e-03,
#        1.09648612e-02, 1.41116708e-03, 4.31733969e-03, 4.47789036e-01,
#        8.12664797e-01, 5.90084062e-01, 3.56620614e-03, 2.36437150e-03,
#        8.27670561e-01, 2.95804657e-03, 5.49491452e-02, 1.46814105e-02,
#        6.11597370e-02, 1.30637275e-02, 6.70575421e-01, 4.14010335e-01,
#        8.84970563e-01, 8.00188528e-01, 7.57116691e-03, 1.61652373e-03,
#        8.25086689e-01, 7.59261011e-03, 2.09008597e-03, 2.46358934e-02,
#        4.22657050e-01, 7.78358957e-01, 7.49084384e-03, 9.76421398e-01,
#        7.38941141e-03, 1.81062220e-02, 6.40706212e-03, 4.36947868e-03,
#        1.25496546e-03, 1.12980043e-02, 2.56000638e-03, 2.73599323e-03,
#        1.95348771e-02, 9.17784058e-01, 1.34788509e-02, 9.79798959e-01,
#        9.26225447e-03, 2.96400141e-02, 9.37513032e-03, 2.16120049e-02,
#        1.25788481e-02, 8.95702033e-01, 8.71188291e-01, 2.39794425e-03,
#        9.58592039e-02, 4.09701523e-03, 3.96748156e-03, 7.38018637e-01,
#        4.29294136e-02, 7.14200666e-03, 9.69663434e-01, 1.47791564e-02,
#        5.49867224e-03, 1.87043839e-02, 9.43891352e-03, 1.11934154e-01,
#        6.20300046e-03, 3.59168660e-03, 4.63377234e-03, 1.72475387e-03,
#        4.14866825e-03, 2.20670325e-03, 2.32970377e-01, 3.17419237e-02,
#        7.68797778e-02, 2.25556988e-03, 6.26260439e-03, 6.30774049e-01,
#        2.80672438e-02, 4.18461995e-02, 1.07733097e-02, 1.00441374e-02,
#        1.19542641e-02, 9.30962652e-01, 2.00085671e-03, 3.62770570e-02,
#        8.17256405e-01, 1.91701994e-02, 1.15673625e-02, 1.38132070e-02,
#        1.62706891e-03, 3.44132970e-03, 8.79150157e-01, 9.71167243e-01,
#        3.03153762e-03, 2.82555640e-03, 9.18623821e-04, 2.40792175e-03,
#        1.53144373e-01, 4.94841316e-03, 3.66411277e-03, 1.19493802e-02,
#        1.59997460e-03, 5.63287604e-01, 7.02741104e-03, 1.63517148e-02,
#        3.99654041e-03, 3.48477025e-02, 3.53906264e-01, 4.50963841e-01,
#        3.57516928e-01, 1.70269243e-03, 1.05896096e-03, 9.49380832e-03,
#        2.35377370e-01, 6.76805789e-03, 9.19747917e-01, 2.37617641e-02,
#        9.44534490e-01, 4.71453957e-03, 7.56064422e-01, 4.94471010e-03,
#        5.39664055e-03, 2.14264704e-02, 2.77775320e-02, 2.87418802e-02,
#        3.38934018e-03, 2.41825458e-03, 9.38074304e-01, 6.36516522e-03,
#        3.55051639e-03, 6.48687156e-01, 2.95879895e-01, 2.03929970e-02,
#        1.02872353e-02, 3.86769308e-03, 9.78308387e-01, 1.98678859e-03,
#        1.34575489e-03, 2.94535528e-02, 3.81863065e-03, 7.98090312e-01,
#        4.74879247e-01, 2.86453355e-03, 8.56892612e-01, 5.07554366e-02,
#        2.32625826e-01, 8.23927571e-01, 1.32314077e-02, 9.09998144e-01,
#        8.79961071e-02, 7.19226531e-02, 6.35777488e-01, 2.60723511e-03,
#        2.51801234e-03, 8.62167670e-04, 1.38116730e-02, 2.72157499e-03])

# %%
fig, ax = plt.subplots(figsize=(6,18))
lgb.plot_importance(model_lgb, max_num_features=60, ax = ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
submission = pd.read_csv('./data/sampleSubmission.csv')
submission['fraud_reported'] = y_pred
submission.to_csv('./submission/submission.csv', index=None)
