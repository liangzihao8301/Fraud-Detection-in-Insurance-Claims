# %%
#增加交叉特征
#Score: Score: 0.89048
#使用5折交叉验证,增加scale_pos_weight参数
#Score: Score: 0.89292
#增加G/L
#Score: 0.88696

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib # 注意这个也要import一次
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score, mean_squared_error, roc_curve, auc
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")

# %%
#数据加载
train_data = pd.read_csv('./data/train.csv')
test_data = pd.read_csv('./data/test.csv')

# %%
datas = pd.concat((train_data, test_data))
datas.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 数据探索

# %%
cat_columns = datas.select_dtypes(include=['O']).columns
numerical_columns = datas.select_dtypes(exclude=['O']).columns

# %%
col_name = []
unique_value = []
for col in cat_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_cat_col_unique = pd.DataFrame()
df_cat_col_unique['col_name'] = col_name
df_cat_col_unique['unique_value'] = unique_value
df_cat_col_unique = df_cat_col_unique.sort_values('unique_value', ascending= False)
# df_cat_col_unique

# %%
col_name = []
unique_value = []
for col in numerical_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_numerical_col_unique = pd.DataFrame()
df_numerical_col_unique['col_name'] = col_name
df_numerical_col_unique['unique_value'] = unique_value
df_numerical_col_unique = df_numerical_col_unique.sort_values('unique_value', ascending= False)
# df_numerical_col_unique

# %%
df_cat_col_unique
# df_numerical_col_unique
# Out:
#                    col_name  unique_value
# 15        incident_location          1000
# 0          policy_bind_date           951
# 8             incident_date            60
# 19               auto_model            39
# 6           insured_hobbies            20
# 5        insured_occupation            14
# 18                auto_make            14
# 4   insured_education_level             7
# 13           incident_state             7
# 14            incident_city             7
# 7      insured_relationship             6
# 12    authorities_contacted             5
# 9             incident_type             4
# 11        incident_severity             4
# 10           collision_type             4
# 1              policy_state             3
# 2                policy_csl             3
# 16          property_damage             3
# 17  police_report_available             3
# 3               insured_sex             2

# %% [markdown]
# ## 特征工程

# %% [markdown]
# #### 标签编码 policy_bind_date、incident_date

# %%
datas['policy_bind_date'] = pd.to_datetime(datas['policy_bind_date'])
datas['incident_date'] = pd.to_datetime(datas['incident_date'])

# %%
datas['policy_bind_date_year'] = datas['policy_bind_date'].dt.year
datas['policy_bind_date_month'] = datas['policy_bind_date'].dt.month
datas['policy_bind_date_day'] = datas['policy_bind_date'].dt.day
datas['policy_bind_date_weekday'] = datas['policy_bind_date'].dt.weekday

datas['incident_date_year'] = datas['incident_date'].dt.year
datas['incident_date_month'] = datas['incident_date'].dt.month
datas['incident_date_day'] = datas['incident_date'].dt.day
datas['incident_date_weekday'] = datas['incident_date'].dt.weekday

# %%
# 查看最小、最大日期
# datas.policy_bind_date.min() #1990-01-08
# datas.policy_bind_date.max() #2015-02-22

# datas.incident_date.min() #2015-01-01
# datas.incident_date.max() #2015-03-01

# %%
base_date = datas.policy_bind_date.min()
#转换为diff
datas['policy_bind_date_diff'] = (datas['policy_bind_date'] - base_date).dt.days
datas['incident_date_diff'] = (datas['incident_date'] - base_date).dt.days
datas['incident_date&policy_bind_date_diff'] = datas['incident_date_diff'] - datas['policy_bind_date_diff']

# %% [markdown]
# #### 构造交叉业务特征

# %%
datas['injury_claim_pct'] = datas['injury_claim']/datas['total_claim_amount']
datas['property_claim_pct'] = datas['property_claim']/datas['total_claim_amount']
datas['vehicle_claim_pct'] = datas['vehicle_claim']/datas['total_claim_amount']

# %%
datas['is_injury_claim'] = datas['injury_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_property_claim'] = datas['property_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_vehicle_claim'] = datas['vehicle_claim'].apply(lambda x: '1' if x >0 else '0')

# %%
datas['incident_type_&_is_injury_claim'] = datas['incident_type'] + '_' + datas['is_injury_claim']
datas['incident_type_&_is_property_claim'] = datas['incident_type'] + '_' + datas['is_property_claim']
datas['incident_type_&_is_vehicle_claim'] = datas['incident_type'] + '_' + datas['is_vehicle_claim']

datas['collision_type_&_is_injury_claim'] = datas['collision_type'] + '_' + datas['is_injury_claim']
datas['collision_type_&_is_property_claim'] = datas['collision_type'] + '_' + datas['is_property_claim']
datas['collision_type_&_is_vehicle_claim'] = datas['collision_type'] + '_' + datas['is_vehicle_claim']

# %%
datas['umbrella_limit_2_total_claim_amount'] = datas['umbrella_limit']/datas['total_claim_amount']

# %%
# datas['G/L'] = datas['capital-gains'] + datas['capital-loss']

# %%
datas[['incident_type', 'collision_type', 'policy_csl', 'policy_annual_premium', 'umbrella_limit', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'capital-gains', 'capital-loss']][datas['fraud_reported'] > 0]
# Out:
#                 incident_type   collision_type policy_csl  \
# 3     Multi-vehicle Collision  Front Collision   500/1000
# 5     Multi-vehicle Collision   Rear Collision    100/300
# 8     Multi-vehicle Collision   Rear Collision    100/300
# 11    Multi-vehicle Collision   Rear Collision   500/1000
# 15    Multi-vehicle Collision   Rear Collision    100/300
# ..                        ...              ...        ...
# 689   Multi-vehicle Collision   Side Collision   500/1000
# 694  Single Vehicle Collision   Rear Collision    250/500
# 695  Single Vehicle Collision  Front Collision    250/500
# 696   Multi-vehicle Collision   Rear Collision    250/500
# 698   Multi-vehicle Collision   Rear Collision   500/1000
#
#      policy_annual_premium  umbrella_limit  total_claim_amount  injury_claim  \
# 3                  1848.81               0               68520         11420
# 5                  1516.34               0               59400         13200
# 8                   998.19               0               78600         13100
# 11                  795.31               0               40810          3710
# 15                 1266.92               0               71500         16500
# ..                     ...             ...                 ...           ...
# 689                1282.93               0               66880          6080
# 694                1194.00               0               66780          7420
# 695                1262.08               0               60170         10940
# 696                1483.91         8000000               70600          7060
# 698                1030.95               0               35900          7180
#
#      property_claim  vehicle_claim  capital-gains  capital-loss
# 3              5710          51390              0        -49000
# 5              6600          39600          11000             0
# 8             19650          45850          43700        -66300
# 11             7420          29680              0        -51000
# 15            11000          44000              0             0
# ..              ...            ...            ...           ...
# 689           12160          48640              0             0
# 694            7420          51940              0             0
# 695           10940          38290          48500             0
# 696           14120          49420              0        -33600
# 698            3590          25130          47200             0
#
# [181 rows x 11 columns]

# %%
#检查单个特征
# datas.incident_city.nunique()
# datas['incident_type'].value_counts()

# %%
datas.drop(['policy_bind_date', 'incident_date', '_c39', 'incident_location', 'policy_number', 'insured_zip'], axis= 1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_columns = datas.select_dtypes(include= ['O']).columns

# %%
for col in cat_columns:
    le = LabelEncoder()
    datas[col] = le.fit_transform(datas[col])

datas[cat_columns]
# Out:
#      policy_state  policy_csl  insured_sex  insured_education_level  \
# 0               1           2            0                        5
# 1               0           1            1                        3
# 2               0           2            0                        2
# 3               2           2            1                        3
# 4               2           0            0                        4
# ..            ...         ...          ...                      ...
# 995             0           2            0                        1
# 996             1           1            1                        4
# 997             1           2            0                        0
# 998             1           0            0                        4
# 999             1           0            1                        5
#
#      insured_occupation  insured_hobbies  insured_relationship  incident_type  \
# 0                    10               15                     1              2
# 1                     2               14                     2              0
# 2                     6               16                     5              2
# 3                    13               18                     3              0
# 4                     2               18                     3              0
# ..                  ...              ...                   ...            ...
# 995                   9               11                     1              1
# 996                   0               12                     4              0
# 997                   7               10                     1              2
# 998                  10               10                     4              0
# 999                  10                7                     2              2
#
#      collision_type  incident_severity  ...  auto_model  is_injury_claim  \
# 0                 3                  2  ...          26                1
# 1                 3                  1  ...          10                1
# 2                 3                  2  ...          36                1
# 3                 1                  0  ...          21                1
# 4                 2                  2  ...          14                1
# ..              ...                ...  ...         ...              ...
# 995               0                  3  ...          27                1
# 996               3                  2  ...          17                1
# 997               2                  1  ...          30                1
# 998               3                  1  ...          26                1
# 999               1                  1  ...          10                1
#
#      is_property_claim  is_vehicle_claim  incident_type_&_is_injury_claim  \
# 0                    1                 0                                5
# 1                    1                 0                                1
# 2                    1                 0                                5
# 3                    1                 0                                1
# 4                    1                 0                                1
# ..                 ...               ...                              ...
# 995                  1                 0                                3
# 996                  1                 0                                1
# 997                  1                 0                                5
# 998                  1                 0                                1
# 999                  1                 0                                5
#
#      incident_type_&_is_property_claim  incident_type_&_is_vehicle_claim  \
# 0                                    5                                 2
# 1                                    1                                 0
# 2                                    5                                 2
# 3                                    1                                 0
# 4                                    1                                 0
# ..                                 ...                               ...
# 995                                  3                                 1
# 996                                  1                                 0
# 997                                  5                                 2
# 998                                  1                                 0
# 999                                  5                                 2
#
#      collision_type_&_is_injury_claim  collision_type_&_is_property_claim  \
# 0                                   7                                   7
# 1                                   7                                   7
# 2                                   7                                   7
# 3                                   3                                   3
# 4                                   5                                   5
# ..                                ...                                 ...
# 995                                 1                                   1
# 996                                 7                                   7
# 997                                 5                                   5
# 998                                 7                                   7
# 999                                 3                                   3
#
#      collision_type_&_is_vehicle_claim
# 0                                    3
# 1                                    3
# 2                                    3
# 3                                    1
# 4                                    2
# ..                                 ...
# 995                                  0
# 996                                  3
# 997                                  2
# 998                                  3
# 999                                  1
#
# [1000 rows x 26 columns]

# %%
# 数据集切分
train = datas[datas['fraud_reported'].notnull()]
test = datas[datas['fraud_reported'].isnull()]

# %%
train_X = train.drop(['fraud_reported'], axis=1)
train_y = train['fraud_reported']
test_X = test.drop(['fraud_reported'], axis=1)

# %% [markdown]
# ## 使用lgbm 训练

# %%
import lightgbm as lgb

# %%
model_lgb = lgb.LGBMClassifier(
            num_leaves=2**5-1, reg_alpha=0.25, reg_lambda=0.25, objective='binary',
            max_depth=-1, learning_rate=0.005, min_child_samples=3, random_state=2022,
            n_estimators=2000, subsample=1, colsample_bytree=1,
        )

# %%
model_lgb.fit(train_X, train_y)
# Out:
# LGBMClassifier(colsample_bytree=1, learning_rate=0.005, min_child_samples=3,
#                n_estimators=2000, objective='binary', random_state=2022,
#                reg_alpha=0.25, reg_lambda=0.25, subsample=1)

# %%
y_pred = model_lgb.predict_proba(test_X)[:, 1]

# %%
y_pred
# Out:
# array([2.82044556e-02, 2.03475702e-01, 6.53763115e-03, 1.83423377e-02,
#        1.99226625e-03, 2.85407775e-02, 3.92617163e-03, 1.23527458e-02,
#        1.32499123e-03, 2.94570169e-03, 8.82403716e-02, 4.84745890e-03,
#        7.03755908e-01, 2.85972882e-03, 6.39652257e-03, 7.38022512e-01,
#        5.81388059e-03, 6.91932022e-03, 5.39440014e-01, 3.53190455e-03,
#        3.48732162e-03, 5.71642039e-01, 8.80842764e-01, 1.16094725e-02,
#        8.69509353e-03, 9.23700351e-01, 2.10717374e-03, 5.81769454e-03,
#        1.75362001e-01, 7.69017324e-02, 8.32113278e-01, 9.82622659e-02,
#        3.16148458e-01, 4.52671881e-03, 8.44552787e-03, 1.29622742e-02,
#        6.53528481e-01, 4.69045646e-03, 1.81002028e-03, 7.01192487e-02,
#        6.35539295e-01, 7.37469874e-03, 8.65819279e-03, 1.27808331e-02,
#        1.31316325e-02, 6.33472309e-03, 4.76697444e-03, 1.62257893e-02,
#        6.08476455e-01, 2.15582211e-03, 4.38113168e-03, 1.00553276e-01,
#        3.15081286e-03, 1.28082838e-01, 9.31396575e-01, 7.56704648e-03,
#        6.71880467e-03, 4.44136983e-01, 7.77229356e-03, 6.94394297e-01,
#        7.81284824e-03, 1.87142260e-02, 2.57315929e-03, 7.83300214e-01,
#        6.60017339e-03, 3.66372767e-03, 8.31871369e-01, 9.75180970e-01,
#        2.96327024e-02, 3.30119448e-03, 2.99548027e-03, 1.60205055e-01,
#        2.74884736e-01, 8.20866211e-01, 2.22213832e-03, 1.20783471e-02,
#        2.33479351e-03, 1.29255533e-03, 8.69757687e-01, 1.59530702e-02,
#        1.42946130e-02, 5.37404799e-03, 8.33808978e-01, 2.15445293e-02,
#        9.67395540e-03, 1.25536939e-02, 4.42198676e-02, 7.08796863e-03,
#        3.07014733e-02, 2.46070763e-01, 8.06622518e-03, 5.65087511e-01,
#        9.13248040e-01, 7.05097556e-03, 1.22866564e-03, 3.34910425e-03,
#        5.36354266e-02, 3.18582167e-03, 9.45187072e-02, 5.28861781e-03,
#        2.34533802e-02, 9.19564584e-01, 5.53516293e-03, 2.10477052e-03,
#        1.88710340e-03, 4.83834712e-01, 4.71315902e-02, 5.30249320e-01,
#        1.10118291e-01, 2.65513899e-03, 2.30410389e-03, 3.76038884e-03,
#        2.93129835e-02, 3.70376774e-03, 2.34723363e-03, 3.47724174e-01,
#        9.72941392e-01, 8.70248040e-03, 6.94425898e-01, 4.34693161e-03,
#        3.98735971e-03, 5.60253346e-03, 9.50508041e-01, 8.28206543e-01,
#        3.37488841e-01, 4.11853113e-01, 2.63183503e-03, 1.30218166e-03,
#        7.92955184e-01, 2.92621812e-03, 3.66132118e-03, 3.86304930e-01,
#        2.66688312e-02, 5.35452146e-03, 4.31234144e-03, 1.30809550e-03,
#        1.28938392e-02, 7.16309609e-01, 9.25607786e-01, 2.74880337e-02,
#        3.99054546e-02, 6.93224281e-03, 6.50322978e-01, 2.64584507e-02,
#        5.50550992e-01, 7.88184264e-01, 6.31248527e-02, 1.04659034e-02,
#        1.11055883e-02, 1.27307033e-03, 5.70162750e-03, 4.24079920e-01,
#        6.93988291e-01, 4.49723587e-01, 3.43486839e-03, 1.91089116e-03,
#        7.36219246e-01, 3.24646385e-03, 4.79252781e-02, 2.74464334e-02,
#        5.25539030e-02, 1.41602935e-02, 6.97778055e-01, 5.15902196e-01,
#        8.78970427e-01, 7.65092591e-01, 1.01399126e-02, 1.85693466e-03,
#        9.05698735e-01, 9.48170931e-03, 1.87811121e-03, 3.39214473e-02,
#        4.34689246e-01, 7.58924754e-01, 6.55675365e-03, 9.59689173e-01,
#        8.07612371e-03, 1.61821205e-02, 6.04070524e-03, 4.18758378e-03,
#        1.62541324e-03, 1.43340103e-02, 3.59699350e-03, 3.13196731e-03,
#        2.76308053e-02, 9.23916359e-01, 1.16011012e-02, 9.71582732e-01,
#        1.09058068e-02, 2.86350365e-02, 6.33509859e-03, 1.16990643e-02,
#        1.57746922e-02, 9.06187740e-01, 8.66737334e-01, 2.76798169e-03,
#        8.47540454e-02, 2.44427098e-03, 4.39538601e-03, 7.56379196e-01,
#        3.08783146e-02, 4.57285573e-03, 9.72636621e-01, 2.48885774e-02,
#        7.98754199e-03, 1.08340956e-02, 9.10944489e-03, 1.27168007e-01,
#        6.30635828e-03, 3.91896673e-03, 3.00180854e-03, 1.76556607e-03,
#        4.79520328e-03, 2.81077387e-03, 1.35757039e-01, 3.82767909e-02,
#        9.73329035e-02, 1.35336026e-03, 7.51021940e-03, 5.66350288e-01,
#        3.66617380e-02, 4.44043587e-02, 1.60169694e-02, 1.71481201e-02,
#        1.39852238e-02, 9.16488628e-01, 2.35261679e-03, 3.07631025e-02,
#        8.46305654e-01, 1.91908463e-02, 1.27560143e-02, 1.62821108e-02,
#        2.10674126e-03, 4.56437469e-03, 8.93244414e-01, 9.72145962e-01,
#        3.51202819e-03, 2.81732191e-03, 7.31595067e-04, 2.41000408e-03,
#        1.11763614e-01, 3.75154151e-03, 4.97985791e-03, 8.57100494e-03,
#        2.20828391e-03, 6.84268515e-01, 5.69835830e-03, 1.87387353e-02,
#        4.42544434e-03, 1.71255651e-02, 2.34328188e-01, 3.73024331e-01,
#        1.93436244e-01, 2.14271700e-03, 1.35555179e-03, 1.09399899e-02,
#        2.57238176e-01, 6.81496987e-03, 9.20393243e-01, 2.38223926e-02,
#        8.93357623e-01, 3.22177720e-03, 8.13867839e-01, 7.45606754e-03,
#        9.09227931e-03, 2.11974800e-02, 1.77118080e-02, 1.69337946e-02,
#        3.71592574e-03, 2.84934648e-03, 9.25913113e-01, 9.34592167e-03,
#        2.87199457e-03, 2.90142839e-01, 2.82401046e-01, 1.69989882e-02,
#        7.51878649e-03, 3.53674745e-03, 9.79491608e-01, 2.67428385e-03,
#        1.72491470e-03, 1.81628585e-02, 4.33539878e-03, 8.06397367e-01,
#        4.51780453e-01, 2.84796174e-03, 8.36985250e-01, 5.57284862e-02,
#        2.90444568e-01, 8.78623205e-01, 9.60481808e-03, 9.00763750e-01,
#        1.20977802e-01, 5.63160528e-02, 4.41851423e-01, 3.35105651e-03,
#        2.29681782e-03, 8.02363446e-04, 1.80627298e-02, 2.57848595e-03])

# %%
fig, ax = plt.subplots(figsize=(6,18))
lgb.plot_importance(model_lgb, max_num_features=30, ax = ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
# submission = pd.read_csv('./data/sampleSubmission.csv')
# submission['fraud_reported'] = y_pred
# submission.to_csv('./submission/submission.csv', index=None)

# %% [markdown]
# ## 使用五折交叉验证的LightGBM

# %%
from sklearn.model_selection import StratifiedKFold, KFold
import lightgbm as lgb

# %%
params_lgb = {
    'num_leaves': 2**5-1, 'reg_alpha': 0.25, 'reg_lambda': 0.25, 'objective': 'binary',
    'max_depth': -1, 'learning_rate': 0.005, 'min_child_samples': 3, 'random_state': 2022,
    #'n_estimators': 2000, 
    'subsample': 1, 'colsample_bytree': 1, 'scale_pos_weight': 3
}

# %%
NFOLD = 5

# %%
kf = StratifiedKFold(n_splits = NFOLD, shuffle = True, random_state = 2022)

y_pred = np.zeros(len(test_X))

# %%
for fold, (train_index, val_index) in enumerate(kf.split(train_X, train_y)):
    X_fold_train, X_fold_val = train_X.iloc[train_index, :], train_X.iloc[val_index, :]
    y_fold_train, y_fold_val = train_y[train_index], train_y[val_index]
    train_set = lgb.Dataset(X_fold_train, y_fold_train)
    val_set = lgb.Dataset(X_fold_val, y_fold_val, reference=train_set)

    model_lgb = lgb.train(params_lgb, train_set, num_boost_round=2000, #early_stopping_rounds=50,
                      valid_sets = val_set, verbose_eval=100)

    y_pred += model_lgb.predict(test_X, num_iteration=model_lgb.best_iteration)/kf.n_splits

# y_pred = [1 if y > 0.5 else 0 for y in y_pred]
# rmse = metrics.accuracy_score(y_pred,y_test)
# print(rmse)
# Out:
# [LightGBM] [Info] Number of positive: 145, number of negative: 415
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000531 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2369
# [LightGBM] [Info] Number of data points in the train set: 560, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258929 -> initscore=-1.051545
# [LightGBM] [Info] Start training from score -1.051545
# [100]	valid_0's binary_logloss: 0.4463
# [200]	valid_0's binary_logloss: 0.404732
# [300]	valid_0's binary_logloss: 0.397224
# [400]	valid_0's binary_logloss: 0.399463
# [500]	valid_0's binary_logloss: 0.410852
# [600]	valid_0's binary_logloss: 0.423038
# [700]	valid_0's binary_logloss: 0.438107
# [800]	valid_0's binary_logloss: 0.444475
# [900]	valid_0's binary_logloss: 0.450927
# [1000]	valid_0's binary_logloss: 0.459668
# [1100]	valid_0's binary_logloss: 0.468975
# [1200]	valid_0's binary_logloss: 0.472999
# [1300]	valid_0's binary_logloss: 0.47926
# [1400]	valid_0's binary_logloss: 0.485227
# [1500]	valid_0's binary_logloss: 0.491304
# [1600]	valid_0's binary_logloss: 0.497181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	valid_0's binary_logloss: 0.503877
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's binary_logloss: 0.509507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.515047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.519977
# [LightGBM] [Info] Number of positive: 145, number of negative: 415
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000567 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2373
# [LightGBM] [Info] Number of data points in the train set: 560, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258929 -> initscore=-1.051545
# [LightGBM] [Info] Start training from score -1.051545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's binary_logloss: 0.456127
# [200]	valid_0's binary_logloss: 0.430947
# [300]	valid_0's binary_logloss: 0.440311
# [400]	valid_0's binary_logloss: 0.457937
# [500]	valid_0's binary_logloss: 0.472495
# [600]	valid_0's binary_logloss: 0.491257
# [700]	valid_0's binary_logloss: 0.50234
# [800]	valid_0's binary_logloss: 0.512191
# [900]	valid_0's binary_logloss: 0.524001
# [1000]	valid_0's binary_logloss: 0.534544
# [1100]	valid_0's binary_logloss: 0.541089
# [1200]	valid_0's binary_logloss: 0.550537
# [1300]	valid_0's binary_logloss: 0.560966
# [1400]	valid_0's binary_logloss: 0.569055
# [1500]	valid_0's binary_logloss: 0.576729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	valid_0's binary_logloss: 0.586029
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	valid_0's binary_logloss: 0.595336
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's binary_logloss: 0.60099
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.606784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.610543
# [LightGBM] [Info] Number of positive: 145, number of negative: 415
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000589 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2367
# [LightGBM] [Info] Number of data points in the train set: 560, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258929 -> initscore=-1.051545
# [LightGBM] [Info] Start training from score -1.051545
# [100]	valid_0's binary_logloss: 0.478669
# [200]	valid_0's binary_logloss: 0.464996
# [300]	valid_0's binary_logloss: 0.47224
# [400]	valid_0's binary_logloss: 0.487793
# [500]	valid_0's binary_logloss: 0.503538
# [600]	valid_0's binary_logloss: 0.52452
# [700]	valid_0's binary_logloss: 0.540235
# [800]	valid_0's binary_logloss: 0.549627
# [900]	valid_0's binary_logloss: 0.559438
# [1000]	valid_0's binary_logloss: 0.571609
# [1100]	valid_0's binary_logloss: 0.584664
# [1200]	valid_0's binary_logloss: 0.597325
# [1300]	valid_0's binary_logloss: 0.608694
# [1400]	valid_0's binary_logloss: 0.621669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1500]	valid_0's binary_logloss: 0.63107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	valid_0's binary_logloss: 0.639272
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	valid_0's binary_logloss: 0.648086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's binary_logloss: 0.656964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.664986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.671707
# [LightGBM] [Info] Number of positive: 145, number of negative: 415
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000934 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2364
# [LightGBM] [Info] Number of data points in the train set: 560, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258929 -> initscore=-1.051545
# [LightGBM] [Info] Start training from score -1.051545
# [100]	valid_0's binary_logloss: 0.432807
# [200]	valid_0's binary_logloss: 0.39215
# [300]	valid_0's binary_logloss: 0.38173
# [400]	valid_0's binary_logloss: 0.380468
# [500]	valid_0's binary_logloss: 0.388928
# [600]	valid_0's binary_logloss: 0.394265
# [700]	valid_0's binary_logloss: 0.396849
# [800]	valid_0's binary_logloss: 0.400128
# [900]	valid_0's binary_logloss: 0.406049
# [1000]	valid_0's binary_logloss: 0.411671
# [1100]	valid_0's binary_logloss: 0.416778
# [1200]	valid_0's binary_logloss: 0.422153
# [1300]	valid_0's binary_logloss: 0.425834
# [1400]	valid_0's binary_logloss: 0.429998
# [1500]	valid_0's binary_logloss: 0.433476
# [1600]	valid_0's binary_logloss: 0.437749
# [1700]	valid_0's binary_logloss: 0.443138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's binary_logloss: 0.447632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.45085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.454247
# [LightGBM] [Info] Number of positive: 144, number of negative: 416
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000698 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2365
# [LightGBM] [Info] Number of data points in the train set: 560, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.257143 -> initscore=-1.060872
# [LightGBM] [Info] Start training from score -1.060872
# [100]	valid_0's binary_logloss: 0.402226
# [200]	valid_0's binary_logloss: 0.336391
# [300]	valid_0's binary_logloss: 0.303363
# [400]	valid_0's binary_logloss: 0.294589
# [500]	valid_0's binary_logloss: 0.289511
# [600]	valid_0's binary_logloss: 0.291525
# [700]	valid_0's binary_logloss: 0.301109
# [800]	valid_0's binary_logloss: 0.307708
# [900]	valid_0's binary_logloss: 0.309134
# [1000]	valid_0's binary_logloss: 0.314208
# [1100]	valid_0's binary_logloss: 0.319833
# [1200]	valid_0's binary_logloss: 0.3235
# [1300]	valid_0's binary_logloss: 0.327638
# [1400]	valid_0's binary_logloss: 0.333382
# [1500]	valid_0's binary_logloss: 0.337701
# [1600]	valid_0's binary_logloss: 0.342283
# [1700]	valid_0's binary_logloss: 0.345265
# [1800]	valid_0's binary_logloss: 0.348658
# [1900]	valid_0's binary_logloss: 0.351815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.354316

# %%
submission = pd.read_csv('./data/sampleSubmission.csv')
submission['fraud_reported'] = y_pred
submission.to_csv('./submission/submission.csv', index=None)
