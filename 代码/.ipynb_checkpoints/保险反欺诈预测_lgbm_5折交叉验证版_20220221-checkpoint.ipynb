# %%
#增加交叉特征
#Score: Score: 0.89048
#使用5折交叉验证,增加scale_pos_weight参数
#Score: Score: 0.89292
#增加G/L
#Score: 0.88614

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib # 注意这个也要import一次
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score, mean_squared_error, roc_curve, auc
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")

# %%
#数据加载
train_data = pd.read_csv('./fraud-detection-in-insurance-claims/train.csv')
test_data = pd.read_csv('./fraud-detection-in-insurance-claims/test.csv')

# %%
datas = pd.concat((train_data, test_data))
datas.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 数据探索

# %%
cat_columns = datas.select_dtypes(include=['O']).columns
numerical_columns = datas.select_dtypes(exclude=['O']).columns

# %%
col_name = []
unique_value = []
for col in cat_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_cat_col_unique = pd.DataFrame()
df_cat_col_unique['col_name'] = col_name
df_cat_col_unique['unique_value'] = unique_value
df_cat_col_unique = df_cat_col_unique.sort_values('unique_value', ascending= False)
# df_cat_col_unique

# %%
col_name = []
unique_value = []
for col in numerical_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_numerical_col_unique = pd.DataFrame()
df_numerical_col_unique['col_name'] = col_name
df_numerical_col_unique['unique_value'] = unique_value
df_numerical_col_unique = df_numerical_col_unique.sort_values('unique_value', ascending= False)
# df_numerical_col_unique

# %%
df_cat_col_unique
# df_numerical_col_unique
# Out:
#                    col_name  unique_value
# 6         incident_location          1000
# 16         policy_bind_date           951
# 5             incident_date            60
# 2                auto_model            39
# 11          insured_hobbies            20
# 12       insured_occupation            14
# 1                 auto_make            14
# 10  insured_education_level             7
# 4             incident_city             7
# 8            incident_state             7
# 13     insured_relationship             6
# 0     authorities_contacted             5
# 9             incident_type             4
# 7         incident_severity             4
# 3            collision_type             4
# 15  police_report_available             3
# 17               policy_csl             3
# 18             policy_state             3
# 19          property_damage             3
# 14              insured_sex             2

# %% [markdown]
# ## 特征工程

# %% [markdown]
# #### 标签编码 policy_bind_date、incident_date

# %%
datas['policy_bind_date'] = pd.to_datetime(datas['policy_bind_date'])
datas['incident_date'] = pd.to_datetime(datas['incident_date'])

# %%
datas['policy_bind_date_year'] = datas['policy_bind_date'].dt.year
datas['policy_bind_date_month'] = datas['policy_bind_date'].dt.month
datas['policy_bind_date_day'] = datas['policy_bind_date'].dt.day
datas['policy_bind_date_weekday'] = datas['policy_bind_date'].dt.weekday

datas['incident_date_year'] = datas['incident_date'].dt.year
datas['incident_date_month'] = datas['incident_date'].dt.month
datas['incident_date_day'] = datas['incident_date'].dt.day
datas['incident_date_weekday'] = datas['incident_date'].dt.weekday

# %%
# 查看最小、最大日期
# datas.policy_bind_date.min() #1990-01-08
# datas.policy_bind_date.max() #2015-02-22

# datas.incident_date.min() #2015-01-01
# datas.incident_date.max() #2015-03-01

# %%
base_date = datas.policy_bind_date.min()
#转换为diff
datas['policy_bind_date_diff'] = (datas['policy_bind_date'] - base_date).dt.days
datas['incident_date_diff'] = (datas['incident_date'] - base_date).dt.days
datas['incident_date&policy_bind_date_diff'] = datas['incident_date_diff'] - datas['policy_bind_date_diff']

# %% [markdown]
# #### 构造交叉业务特征

# %%
datas['injury_claim_pct'] = datas['injury_claim']/datas['total_claim_amount']
datas['property_claim_pct'] = datas['property_claim']/datas['total_claim_amount']
datas['vehicle_claim_pct'] = datas['vehicle_claim']/datas['total_claim_amount']

# %%
datas['is_injury_claim'] = datas['injury_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_property_claim'] = datas['property_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_vehicle_claim'] = datas['vehicle_claim'].apply(lambda x: '1' if x >0 else '0')

# %%
datas['incident_type_&_is_injury_claim'] = datas['incident_type'] + '_' + datas['is_injury_claim']
datas['incident_type_&_is_property_claim'] = datas['incident_type'] + '_' + datas['is_property_claim']
datas['incident_type_&_is_vehicle_claim'] = datas['incident_type'] + '_' + datas['is_vehicle_claim']

datas['collision_type_&_is_injury_claim'] = datas['collision_type'] + '_' + datas['is_injury_claim']
datas['collision_type_&_is_property_claim'] = datas['collision_type'] + '_' + datas['is_property_claim']
datas['collision_type_&_is_vehicle_claim'] = datas['collision_type'] + '_' + datas['is_vehicle_claim']

# %%
datas['umbrella_limit_2_total_claim_amount'] = datas['umbrella_limit']/datas['total_claim_amount']

# %%
datas['G/L'] = datas['capital-gains'] - datas['capital-loss']

# %%
# datas[['incident_type', 'collision_type', 'policy_csl', 'policy_annual_premium', 'umbrella_limit', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'capital-gains', 'capital-loss']][datas['fraud_reported'] > 0]

# %%
#检查单个特征
# datas.incident_city.nunique()
# datas['incident_type'].value_counts()

# %%
datas.drop(['policy_bind_date', 'incident_date', '_c39', 'incident_location', 'policy_number', 'insured_zip'], axis= 1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_columns = datas.select_dtypes(include= ['O']).columns

# %%
for col in cat_columns:
    le = LabelEncoder()
    datas[col] = le.fit_transform(datas[col])

datas[cat_columns]
# Out:
#      authorities_contacted  auto_make  auto_model  collision_type  \
# 0                        0          9          26               3
# 1                        3          6          10               3
# 2                        4          7          36               3
# 3                        1         11          21               1
# 4                        1          5          14               2
# 5                        4         10           2               2
# 6                        1         12          18               3
# 7                        0         11          21               3
# 8                        0          4          30               2
# 9                        0         10           1               1
# 10                       0         11          15               2
# 11                       4          5          14               2
# 12                       1          1           4               2
# 13                       0          3          32               1
# 14                       0         13          28               3
# 15                       3          5          13               2
# 16                       3          2          37               3
# 17                       3          0          23               3
# 18                       3          2          22               2
# 19                       1          9          35               2
# 20                       3          5          14               3
# 21                       1          3          32               2
# 22                       2         13          28               0
# 23                       3         10           1               2
# 24                       4          9          35               2
# 25                       2          3          34               0
# 26                       1          5          14               1
# 27                       1          2          38               3
# 28                       1          1           5               3
# 29                       0         12          18               1
# ..                     ...        ...         ...             ...
# 970                      1         12           9               3
# 971                      0          5          13               2
# 972                      4          4          27               3
# 973                      0         11          15               1
# 974                      3         11          19               3
# 975                      3          1           4               1
# 976                      2          0          23               0
# 977                      4          2          38               3
# 978                      1          8           7               1
# 979                      0          5          16               1
# 980                      2          9          29               0
# 981                      0          4          27               3
# 982                      0         10           2               2
# 983                      1         11          19               2
# 984                      3          5          14               3
# 985                      1          7          17               2
# 986                      1          4          30               3
# 987                      4          9          35               2
# 988                      1         10           1               2
# 989                      0          0          23               3
# 990                      4          8           7               1
# 991                      1          8          24               3
# 992                      4         10           3               3
# 993                      2          5          16               0
# 994                      0          1           5               3
# 995                      2          4          27               0
# 996                      1          7          17               3
# 997                      4          4          30               2
# 998                      1          9          26               3
# 999                      0          6          10               1
#
#      incident_city  incident_severity  incident_state  incident_type  \
# 0                5                  2               0              2
# 1                6                  1               0              0
# 2                3                  2               6              2
# 3                3                  0               6              0
# 4                3                  2               4              0
# 5                6                  0               4              0
# 6                0                  2               1              0
# 7                1                  1               6              0
# 8                2                  2               4              0
# 9                1                  0               1              0
# 10               1                  2               4              2
# 11               0                  0               2              0
# 12               6                  2               4              0
# 13               0                  2               6              2
# 14               6                  0               5              0
# 15               0                  0               2              0
# 16               5                  2               6              0
# 17               2                  0               6              0
# 18               4                  1               1              0
# 19               2                  2               6              2
# 20               4                  0               2              0
# 21               0                  1               1              2
# 22               6                  1               1              1
# 23               2                  2               6              2
# 24               5                  1               1              0
# 25               3                  1               0              1
# 26               6                  0               0              2
# 27               4                  1               4              0
# 28               6                  1               4              2
# 29               3                  2               1              2
# ..             ...                ...             ...            ...
# 970              4                  0               1              2
# 971              2                  2               1              0
# 972              6                  1               4              2
# 973              0                  0               1              0
# 974              6                  0               4              2
# 975              3                  2               4              2
# 976              0                  3               6              1
# 977              3                  1               4              0
# 978              3                  2               1              2
# 979              5                  2               4              0
# 980              0                  1               5              3
# 981              1                  1               1              0
# 982              4                  2               6              0
# 983              3                  0               4              0
# 984              2                  0               6              2
# 985              4                  1               1              2
# 986              6                  0               5              2
# 987              2                  1               0              0
# 988              2                  0               5              2
# 989              1                  1               1              2
# 990              0                  2               4              2
# 991              2                  0               4              0
# 992              3                  0               6              2
# 993              3                  1               6              3
# 994              3                  0               4              2
# 995              0                  3               6              1
# 996              1                  2               6              0
# 997              2                  1               1              2
# 998              6                  1               5              0
# 999              2                  1               2              2
#
#      insured_education_level  insured_hobbies  \
# 0                          5               15
# 1                          3               14
# 2                          2               16
# 3                          3               18
# 4                          4               18
# 5                          3               17
# 6                          6                9
# 7                          6                3
# 8                          4               18
# 9                          2                4
# 10                         3               10
# 11                         3               16
# 12                         2               11
# 13                         1                8
# 14                         1                8
# 15                         5               14
# 16                         2                3
# 17                         4               12
# 18                         1                4
# 19                         4                9
# 20                         4               14
# 21                         6               16
# 22                         2                4
# 23                         4                8
# 24                         6               13
# 25                         6               17
# 26                         6                7
# 27                         1                4
# 28                         2               13
# 29                         4               10
# ..                       ...              ...
# 970                        2               19
# 971                        3                7
# 972                        5               15
# 973                        5                0
# 974                        3               16
# 975                        6               16
# 976                        4                4
# 977                        1               17
# 978                        3                6
# 979                        2                3
# 980                        3               13
# 981                        5               15
# 982                        1               13
# 983                        6                7
# 984                        0               11
# 985                        4               12
# 986                        0               10
# 987                        2               16
# 988                        2               19
# 989                        3                6
# 990                        4                1
# 991                        2               17
# 992                        1                8
# 993                        5               17
# 994                        4               18
# 995                        1               11
# 996                        4               12
# 997                        0               10
# 998                        4               10
# 999                        5                7
#
#                    ...                  property_damage  is_injury_claim  \
# 0                  ...                                0                1
# 1                  ...                                0                1
# 2                  ...                                0                1
# 3                  ...                                2                1
# 4                  ...                                2                1
# 5                  ...                                2                1
# 6                  ...                                0                1
# 7                  ...                                1                1
# 8                  ...                                1                1
# 9                  ...                                0                1
# 10                 ...                                0                1
# 11                 ...                                2                1
# 12                 ...                                0                1
# 13                 ...                                0                1
# 14                 ...                                0                1
# 15                 ...                                1                1
# 16                 ...                                1                1
# 17                 ...                                2                1
# 18                 ...                                1                1
# 19                 ...                                1                1
# 20                 ...                                2                1
# 21                 ...                                2                1
# 22                 ...                                2                1
# 23                 ...                                0                1
# 24                 ...                                1                1
# 25                 ...                                1                1
# 26                 ...                                2                1
# 27                 ...                                1                1
# 28                 ...                                2                1
# 29                 ...                                0                1
# ..                 ...                              ...              ...
# 970                ...                                1                1
# 971                ...                                1                1
# 972                ...                                2                1
# 973                ...                                0                1
# 974                ...                                0                1
# 975                ...                                2                1
# 976                ...                                2                1
# 977                ...                                2                1
# 978                ...                                2                1
# 979                ...                                1                1
# 980                ...                                2                1
# 981                ...                                2                1
# 982                ...                                2                1
# 983                ...                                0                1
# 984                ...                                2                1
# 985                ...                                0                1
# 986                ...                                2                1
# 987                ...                                0                1
# 988                ...                                0                1
# 989                ...                                2                1
# 990                ...                                1                1
# 991                ...                                1                1
# 992                ...                                2                1
# 993                ...                                0                1
# 994                ...                                1                1
# 995                ...                                1                1
# 996                ...                                0                1
# 997                ...                                2                1
# 998                ...                                2                1
# 999                ...                                1                1
#
#      is_property_claim  is_vehicle_claim  incident_type_&_is_injury_claim  \
# 0                    1                 0                                5
# 1                    1                 0                                1
# 2                    1                 0                                5
# 3                    1                 0                                1
# 4                    1                 0                                1
# 5                    1                 0                                1
# 6                    1                 0                                1
# 7                    1                 0                                1
# 8                    1                 0                                1
# 9                    1                 0                                1
# 10                   1                 0                                5
# 11                   1                 0                                1
# 12                   1                 0                                1
# 13                   1                 0                                5
# 14                   1                 0                                1
# 15                   1                 0                                1
# 16                   1                 0                                1
# 17                   1                 0                                1
# 18                   1                 0                                1
# 19                   1                 0                                5
# 20                   1                 0                                1
# 21                   1                 0                                5
# 22                   1                 0                                3
# 23                   1                 0                                5
# 24                   1                 0                                1
# 25                   0                 0                                3
# 26                   1                 0                                5
# 27                   1                 0                                1
# 28                   1                 0                                5
# 29                   1                 0                                5
# ..                 ...               ...                              ...
# 970                  1                 0                                5
# 971                  1                 0                                1
# 972                  1                 0                                5
# 973                  1                 0                                1
# 974                  1                 0                                5
# 975                  1                 0                                5
# 976                  1                 0                                3
# 977                  1                 0                                1
# 978                  1                 0                                5
# 979                  1                 0                                1
# 980                  1                 0                                7
# 981                  1                 0                                1
# 982                  1                 0                                1
# 983                  1                 0                                1
# 984                  1                 0                                5
# 985                  1                 0                                5
# 986                  1                 0                                5
# 987                  1                 0                                1
# 988                  1                 0                                5
# 989                  0                 0                                5
# 990                  1                 0                                5
# 991                  1                 0                                1
# 992                  1                 0                                5
# 993                  1                 0                                7
# 994                  1                 0                                5
# 995                  1                 0                                3
# 996                  1                 0                                1
# 997                  1                 0                                5
# 998                  1                 0                                1
# 999                  1                 0                                5
#
#      incident_type_&_is_property_claim  incident_type_&_is_vehicle_claim  \
# 0                                    5                                 2
# 1                                    1                                 0
# 2                                    5                                 2
# 3                                    1                                 0
# 4                                    1                                 0
# 5                                    1                                 0
# 6                                    1                                 0
# 7                                    1                                 0
# 8                                    1                                 0
# 9                                    1                                 0
# 10                                   5                                 2
# 11                                   1                                 0
# 12                                   1                                 0
# 13                                   5                                 2
# 14                                   1                                 0
# 15                                   1                                 0
# 16                                   1                                 0
# 17                                   1                                 0
# 18                                   1                                 0
# 19                                   5                                 2
# 20                                   1                                 0
# 21                                   5                                 2
# 22                                   3                                 1
# 23                                   5                                 2
# 24                                   1                                 0
# 25                                   2                                 1
# 26                                   5                                 2
# 27                                   1                                 0
# 28                                   5                                 2
# 29                                   5                                 2
# ..                                 ...                               ...
# 970                                  5                                 2
# 971                                  1                                 0
# 972                                  5                                 2
# 973                                  1                                 0
# 974                                  5                                 2
# 975                                  5                                 2
# 976                                  3                                 1
# 977                                  1                                 0
# 978                                  5                                 2
# 979                                  1                                 0
# 980                                  7                                 3
# 981                                  1                                 0
# 982                                  1                                 0
# 983                                  1                                 0
# 984                                  5                                 2
# 985                                  5                                 2
# 986                                  5                                 2
# 987                                  1                                 0
# 988                                  5                                 2
# 989                                  4                                 2
# 990                                  5                                 2
# 991                                  1                                 0
# 992                                  5                                 2
# 993                                  7                                 3
# 994                                  5                                 2
# 995                                  3                                 1
# 996                                  1                                 0
# 997                                  5                                 2
# 998                                  1                                 0
# 999                                  5                                 2
#
#      collision_type_&_is_injury_claim  collision_type_&_is_property_claim  \
# 0                                   7                                   7
# 1                                   7                                   7
# 2                                   7                                   7
# 3                                   3                                   3
# 4                                   5                                   5
# 5                                   5                                   5
# 6                                   7                                   7
# 7                                   7                                   7
# 8                                   5                                   5
# 9                                   3                                   3
# 10                                  5                                   5
# 11                                  5                                   5
# 12                                  5                                   5
# 13                                  3                                   3
# 14                                  7                                   7
# 15                                  5                                   5
# 16                                  7                                   7
# 17                                  7                                   7
# 18                                  5                                   5
# 19                                  5                                   5
# 20                                  7                                   7
# 21                                  5                                   5
# 22                                  1                                   1
# 23                                  5                                   5
# 24                                  5                                   5
# 25                                  1                                   0
# 26                                  3                                   3
# 27                                  7                                   7
# 28                                  7                                   7
# 29                                  3                                   3
# ..                                ...                                 ...
# 970                                 7                                   7
# 971                                 5                                   5
# 972                                 7                                   7
# 973                                 3                                   3
# 974                                 7                                   7
# 975                                 3                                   3
# 976                                 1                                   1
# 977                                 7                                   7
# 978                                 3                                   3
# 979                                 3                                   3
# 980                                 1                                   1
# 981                                 7                                   7
# 982                                 5                                   5
# 983                                 5                                   5
# 984                                 7                                   7
# 985                                 5                                   5
# 986                                 7                                   7
# 987                                 5                                   5
# 988                                 5                                   5
# 989                                 7                                   6
# 990                                 3                                   3
# 991                                 7                                   7
# 992                                 7                                   7
# 993                                 1                                   1
# 994                                 7                                   7
# 995                                 1                                   1
# 996                                 7                                   7
# 997                                 5                                   5
# 998                                 7                                   7
# 999                                 3                                   3
#
#      collision_type_&_is_vehicle_claim
# 0                                    3
# 1                                    3
# 2                                    3
# 3                                    1
# 4                                    2
# 5                                    2
# 6                                    3
# 7                                    3
# 8                                    2
# 9                                    1
# 10                                   2
# 11                                   2
# 12                                   2
# 13                                   1
# 14                                   3
# 15                                   2
# 16                                   3
# 17                                   3
# 18                                   2
# 19                                   2
# 20                                   3
# 21                                   2
# 22                                   0
# 23                                   2
# 24                                   2
# 25                                   0
# 26                                   1
# 27                                   3
# 28                                   3
# 29                                   1
# ..                                 ...
# 970                                  3
# 971                                  2
# 972                                  3
# 973                                  1
# 974                                  3
# 975                                  1
# 976                                  0
# 977                                  3
# 978                                  1
# 979                                  1
# 980                                  0
# 981                                  3
# 982                                  2
# 983                                  2
# 984                                  3
# 985                                  2
# 986                                  3
# 987                                  2
# 988                                  2
# 989                                  3
# 990                                  1
# 991                                  3
# 992                                  3
# 993                                  0
# 994                                  3
# 995                                  0
# 996                                  3
# 997                                  2
# 998                                  3
# 999                                  1
#
# [1000 rows x 26 columns]

# %%
# 数据集切分
train = datas[datas['fraud_reported'].notnull()]
test = datas[datas['fraud_reported'].isnull()]

# %%
train_X = train.drop(['fraud_reported'], axis=1)
train_y = train['fraud_reported']
test_X = test.drop(['fraud_reported'], axis=1)

# %% [markdown]
# ## 使用lgbm 训练

# %%
import lightgbm as lgb

# %%
model_lgb = lgb.LGBMClassifier(
            num_leaves=2**5-1, reg_alpha=0.25, reg_lambda=0.25, objective='binary',
            max_depth=-1, learning_rate=0.005, min_child_samples=3, random_state=2022,
            n_estimators=2000, subsample=1, colsample_bytree=1,
        )

# %%
model_lgb.fit(train_X, train_y)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1,
#         importance_type='split', learning_rate=0.005, max_depth=-1,
#         min_child_samples=3, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=2000, n_jobs=-1, num_leaves=31, objective='binary',
#         random_state=2022, reg_alpha=0.25, reg_lambda=0.25, silent=True,
#         subsample=1, subsample_for_bin=200000, subsample_freq=0)

# %%
y_pred = model_lgb.predict_proba(test_X)[:, 1]

# %%
y_pred
# Out:
# array([  1.43200280e-02,   2.76675459e-01,   6.53362381e-03,
#          2.07723219e-02,   1.41789871e-03,   3.38141522e-02,
#          2.83379494e-03,   1.01300523e-02,   1.11230568e-03,
#          3.02572643e-03,   8.30768806e-02,   4.03885067e-03,
#          6.89784845e-01,   2.60458689e-03,   4.17530612e-03,
#          7.29708333e-01,   5.28748927e-03,   5.44201967e-03,
#          5.99926831e-01,   6.22140610e-03,   6.29354956e-03,
#          4.77852224e-01,   8.78733495e-01,   1.05907658e-02,
#          7.26807791e-03,   9.46566538e-01,   1.84318816e-03,
#          6.59380162e-03,   1.19300780e-01,   8.28235076e-02,
#          9.05676729e-01,   3.07510183e-02,   4.33489158e-01,
#          3.81696981e-03,   7.95082694e-03,   1.48248470e-02,
#          7.36086377e-01,   3.67452686e-03,   1.85475768e-03,
#          7.70457917e-02,   5.90402943e-01,   5.40618918e-03,
#          9.00658441e-03,   1.07107412e-02,   7.33583965e-03,
#          4.85994644e-03,   4.89942166e-03,   2.75413801e-02,
#          5.93645246e-01,   1.76347870e-03,   4.98748028e-03,
#          8.57551926e-02,   3.68742989e-03,   1.09963695e-01,
#          9.58845106e-01,   7.48449084e-03,   5.01611424e-03,
#          5.48412913e-01,   6.49035788e-03,   5.71056263e-01,
#          6.60119725e-03,   1.15430385e-02,   2.00201367e-03,
#          6.29340888e-01,   7.86628408e-03,   3.68658417e-03,
#          8.48962230e-01,   9.74741123e-01,   2.47414421e-02,
#          3.94858230e-03,   3.66894016e-03,   1.55540136e-01,
#          4.57552979e-01,   8.60520112e-01,   2.61709340e-03,
#          1.04298118e-02,   3.07875603e-03,   1.17965254e-03,
#          8.65229611e-01,   1.58304360e-02,   9.17573723e-03,
#          8.40763742e-03,   9.29116812e-01,   2.02408143e-02,
#          8.53413712e-03,   8.97731350e-03,   7.06903393e-02,
#          4.83669251e-03,   1.78649145e-02,   2.78931193e-01,
#          1.39209317e-02,   4.66832128e-01,   9.57957437e-01,
#          1.11571554e-02,   1.14135435e-03,   2.72418091e-03,
#          5.86099251e-02,   4.23739277e-03,   1.99704096e-01,
#          6.59649482e-03,   2.93688263e-02,   9.55011860e-01,
#          5.72923906e-03,   2.16546978e-03,   2.45223547e-03,
#          5.47042866e-01,   4.90702391e-02,   6.96251338e-01,
#          9.51296669e-02,   2.11062972e-03,   2.76772926e-03,
#          3.82097458e-03,   2.25419651e-02,   4.54180069e-03,
#          1.78303337e-03,   4.39330931e-01,   9.75181403e-01,
#          5.47610341e-03,   5.47543777e-01,   3.51990162e-03,
#          3.47625221e-03,   4.85168952e-03,   9.60664795e-01,
#          7.81449273e-01,   3.10260985e-01,   5.38042712e-01,
#          1.59761244e-03,   1.61618413e-03,   8.18106761e-01,
#          2.59772342e-03,   2.50706186e-03,   2.97323353e-01,
#          1.71633341e-02,   5.04081712e-03,   4.25346503e-03,
#          8.97791922e-04,   9.35249097e-03,   7.33905525e-01,
#          8.62033411e-01,   2.68985808e-02,   3.12379489e-02,
#          7.33760465e-03,   7.33306016e-01,   2.38767208e-02,
#          5.44587072e-01,   8.81699649e-01,   4.18751085e-02,
#          6.64345950e-03,   1.18862132e-02,   1.69751368e-03,
#          7.55562537e-03,   5.38945906e-01,   7.38112736e-01,
#          4.88930236e-01,   4.81793657e-03,   2.02118882e-03,
#          8.65666729e-01,   3.52915582e-03,   2.63508567e-02,
#          2.68312531e-02,   7.04785633e-02,   1.07523366e-02,
#          5.83397000e-01,   5.43220318e-01,   7.82092562e-01,
#          7.34442118e-01,   9.63775486e-03,   2.78208951e-03,
#          9.13362334e-01,   1.11357537e-02,   2.79632525e-03,
#          5.39502618e-02,   3.54975342e-01,   6.19959679e-01,
#          6.92463934e-03,   9.61636669e-01,   4.99081613e-03,
#          1.44418009e-02,   4.97054909e-03,   3.67873447e-03,
#          1.35036478e-03,   6.57266772e-03,   2.07298903e-03,
#          2.67083292e-03,   2.04249889e-02,   9.47180232e-01,
#          1.28960397e-02,   9.80078101e-01,   7.85521857e-03,
#          4.28286433e-02,   8.39209035e-03,   1.52200728e-02,
#          1.20652538e-02,   9.21215823e-01,   9.31872547e-01,
#          4.37493530e-03,   8.62772503e-02,   3.21248496e-03,
#          4.85341615e-03,   8.07133917e-01,   7.08041815e-02,
#          6.24059058e-03,   9.62669447e-01,   1.94356606e-02,
#          7.97216678e-03,   1.70050752e-02,   1.14993800e-02,
#          2.10487628e-01,   5.50377648e-03,   4.32854005e-03,
#          4.48162693e-03,   1.64861495e-03,   4.66372889e-03,
#          2.17356905e-03,   2.06362916e-01,   3.12062892e-02,
#          1.47614792e-01,   1.34646894e-03,   9.44073232e-03,
#          7.03548479e-01,   2.97302413e-02,   5.05211848e-02,
#          1.16367751e-02,   1.18357462e-02,   1.25552625e-02,
#          8.92613782e-01,   1.40014301e-03,   2.84346228e-02,
#          8.31782024e-01,   2.45816270e-02,   1.28744322e-02,
#          2.40911360e-02,   3.17381103e-03,   2.20649638e-03,
#          8.58786936e-01,   9.60412855e-01,   2.53404925e-03,
#          4.60755328e-03,   9.50827560e-04,   3.30549527e-03,
#          1.40462049e-01,   5.11398257e-03,   4.00406929e-03,
#          7.51144936e-03,   1.85340395e-03,   4.00635112e-01,
#          4.75969988e-03,   1.07375700e-02,   2.94849453e-03,
#          2.28466881e-02,   2.75726981e-01,   3.02091179e-01,
#          1.80491772e-01,   1.70538780e-03,   1.64775134e-03,
#          1.22955571e-02,   3.24230465e-01,   5.35358133e-03,
#          9.34699620e-01,   2.90036919e-02,   9.30971767e-01,
#          6.46981590e-03,   8.34508223e-01,   3.74636166e-03,
#          6.53612115e-03,   2.13615997e-02,   3.31483803e-02,
#          8.60919167e-03,   4.65520046e-03,   4.05620394e-03,
#          9.61744297e-01,   9.12325009e-03,   4.68861994e-03,
#          5.22552862e-01,   3.14526500e-01,   1.04105158e-02,
#          7.95353782e-03,   2.79419388e-03,   9.55500980e-01,
#          2.12745795e-03,   1.38933120e-03,   1.88432811e-02,
#          3.99540314e-03,   8.52013668e-01,   5.72022240e-01,
#          2.28888621e-03,   8.26637514e-01,   7.23485405e-02,
#          2.96850185e-01,   8.02069272e-01,   1.47603383e-02,
#          8.59936753e-01,   6.14208348e-02,   9.60873206e-02,
#          6.29637310e-01,   2.66166112e-03,   2.70721984e-03,
#          8.09203489e-04,   1.17934101e-02,   4.62745073e-03])

# %%
fig, ax = plt.subplots(figsize=(6,18))
lgb.plot_importance(model_lgb, max_num_features=30, ax = ax)

# %%
submission = pd.read_csv('./fraud-detection-in-insurance-claims/sampleSubmission.csv')
submission['fraud_reported'] = y_pred
submission.to_csv('./submission/submission.csv', index=None)

# %% [markdown]
# ## 使用五折交叉验证的LightGBM

# %%
from sklearn.model_selection import StratifiedKFold, KFold
import lightgbm as lgb

# %%
params_lgb = {
    'num_leaves': 2**5-1, 'reg_alpha': 0.25, 'reg_lambda': 0.25, 'objective': 'binary',
    'max_depth': -1, 'learning_rate': 0.005, 'min_child_samples': 3, 'random_state': 2022,
    #'n_estimators': 2000, 
    'subsample': 1, 'colsample_bytree': 1, 'scale_pos_weight': 3
}

# %%
NFOLD = 5

# %%
kf = StratifiedKFold(n_splits = NFOLD, shuffle = True, random_state = 2022)

y_pred = np.zeros(len(test_X))

# %%
for fold, (train_index, val_index) in enumerate(kf.split(train_X, train_y)):
    X_fold_train, X_fold_val = train_X.iloc[train_index, :], train_X.iloc[val_index, :]
    y_fold_train, y_fold_val = train_y[train_index], train_y[val_index]
    train_set = lgb.Dataset(X_fold_train, y_fold_train)
    val_set = lgb.Dataset(X_fold_val, y_fold_val, reference=train_set)

    model_lgb = lgb.train(params_lgb, train_set, num_boost_round=2000, #early_stopping_rounds=50,
                      valid_sets = val_set, verbose_eval=100)

    y_pred += model_lgb.predict(test_X, num_iteration=model_lgb.best_iteration)/kf.n_splits

# y_pred = [1 if y > 0.5 else 0 for y in y_pred]
# rmse = metrics.accuracy_score(y_pred,y_test)
# print(rmse)
# Out:
# [LightGBM] [Info] Number of positive: 144, number of negative: 415
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000509 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2367
# [LightGBM] [Info] Number of data points in the train set: 559, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.257603 -> initscore=-1.058465
# [LightGBM] [Info] Start training from score -1.058465
# [100]	valid_0's binary_logloss: 0.47781
# [200]	valid_0's binary_logloss: 0.47224
# [300]	valid_0's binary_logloss: 0.487311
# [400]	valid_0's binary_logloss: 0.515636
# [500]	valid_0's binary_logloss: 0.541284
# [600]	valid_0's binary_logloss: 0.570277
# [700]	valid_0's binary_logloss: 0.59629
# [800]	valid_0's binary_logloss: 0.624151
# [900]	valid_0's binary_logloss: 0.64634
# [1000]	valid_0's binary_logloss: 0.664374
# [1100]	valid_0's binary_logloss: 0.677452
# [1200]	valid_0's binary_logloss: 0.689645
# [1300]	valid_0's binary_logloss: 0.703236
# [1400]	valid_0's binary_logloss: 0.717325
# [1500]	valid_0's binary_logloss: 0.728423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	valid_0's binary_logloss: 0.73907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	valid_0's binary_logloss: 0.749701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's binary_logloss: 0.759417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.768021
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.77628
# [LightGBM] [Info] Number of positive: 145, number of negative: 415
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000697 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2371
# [LightGBM] [Info] Number of data points in the train set: 560, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258929 -> initscore=-1.051545
# [LightGBM] [Info] Start training from score -1.051545
# [100]	valid_0's binary_logloss: 0.411199
# [200]	valid_0's binary_logloss: 0.354997
# [300]	valid_0's binary_logloss: 0.332522
# [400]	valid_0's binary_logloss: 0.314065
# [500]	valid_0's binary_logloss: 0.307468
# [600]	valid_0's binary_logloss: 0.307489
# [700]	valid_0's binary_logloss: 0.304913
# [800]	valid_0's binary_logloss: 0.303025
# [900]	valid_0's binary_logloss: 0.303854
# [1000]	valid_0's binary_logloss: 0.303139
# [1100]	valid_0's binary_logloss: 0.304876
# [1200]	valid_0's binary_logloss: 0.306998
# [1300]	valid_0's binary_logloss: 0.309007
# [1400]	valid_0's binary_logloss: 0.312236
# [1500]	valid_0's binary_logloss: 0.317032
# [1600]	valid_0's binary_logloss: 0.322137
# [1700]	valid_0's binary_logloss: 0.32635
# [1800]	valid_0's binary_logloss: 0.330402
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.333359
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.336324
# [LightGBM] [Info] Number of positive: 145, number of negative: 415
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000616 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2366
# [LightGBM] [Info] Number of data points in the train set: 560, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258929 -> initscore=-1.051545
# [LightGBM] [Info] Start training from score -1.051545
# [100]	valid_0's binary_logloss: 0.448545
# [200]	valid_0's binary_logloss: 0.415341
# [300]	valid_0's binary_logloss: 0.411313
# [400]	valid_0's binary_logloss: 0.415815
# [500]	valid_0's binary_logloss: 0.418232
# [600]	valid_0's binary_logloss: 0.425108
# [700]	valid_0's binary_logloss: 0.425883
# [800]	valid_0's binary_logloss: 0.431456
# [900]	valid_0's binary_logloss: 0.436078
# [1000]	valid_0's binary_logloss: 0.44179
# [1100]	valid_0's binary_logloss: 0.448204
# [1200]	valid_0's binary_logloss: 0.452969
# [1300]	valid_0's binary_logloss: 0.457786
# [1400]	valid_0's binary_logloss: 0.464251
# [1500]	valid_0's binary_logloss: 0.470619
# [1600]	valid_0's binary_logloss: 0.475933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	valid_0's binary_logloss: 0.479734
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's binary_logloss: 0.483528
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.490292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.496696
# [LightGBM] [Info] Number of positive: 145, number of negative: 415
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000588 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2362
# [LightGBM] [Info] Number of data points in the train set: 560, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258929 -> initscore=-1.051545
# [LightGBM] [Info] Start training from score -1.051545
# [100]	valid_0's binary_logloss: 0.422792
# [200]	valid_0's binary_logloss: 0.367551
# [300]	valid_0's binary_logloss: 0.339949
# [400]	valid_0's binary_logloss: 0.32927
# [500]	valid_0's binary_logloss: 0.336715
# [600]	valid_0's binary_logloss: 0.344434
# [700]	valid_0's binary_logloss: 0.351562
# [800]	valid_0's binary_logloss: 0.355658
# [900]	valid_0's binary_logloss: 0.360377
# [1000]	valid_0's binary_logloss: 0.364661
# [1100]	valid_0's binary_logloss: 0.368965
# [1200]	valid_0's binary_logloss: 0.37369
# [1300]	valid_0's binary_logloss: 0.378222
# [1400]	valid_0's binary_logloss: 0.383245
# [1500]	valid_0's binary_logloss: 0.388196
# [1600]	valid_0's binary_logloss: 0.393176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	valid_0's binary_logloss: 0.397648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's binary_logloss: 0.401353
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.405005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.407839
# [LightGBM] [Info] Number of positive: 145, number of negative: 416
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2383
# [LightGBM] [Info] Number of data points in the train set: 561, number of used features: 56
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258467 -> initscore=-1.053952
# [LightGBM] [Info] Start training from score -1.053952
# [100]	valid_0's binary_logloss: 0.444227
# [200]	valid_0's binary_logloss: 0.411928
# [300]	valid_0's binary_logloss: 0.406491
# [400]	valid_0's binary_logloss: 0.413512
# [500]	valid_0's binary_logloss: 0.428679
# [600]	valid_0's binary_logloss: 0.442919
# [700]	valid_0's binary_logloss: 0.456982
# [800]	valid_0's binary_logloss: 0.466671
# [900]	valid_0's binary_logloss: 0.475111
# [1000]	valid_0's binary_logloss: 0.481402
# [1100]	valid_0's binary_logloss: 0.488349
# [1200]	valid_0's binary_logloss: 0.492599
# [1300]	valid_0's binary_logloss: 0.500851
# [1400]	valid_0's binary_logloss: 0.510387
# [1500]	valid_0's binary_logloss: 0.519346
# [1600]	valid_0's binary_logloss: 0.527048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	valid_0's binary_logloss: 0.532995
# [1800]	valid_0's binary_logloss: 0.537059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.543366
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.548886

# %%
submission = pd.read_csv('./fraud-detection-in-insurance-claims/sampleSubmission.csv')
submission['fraud_reported'] = y_pred
submission.to_csv('./submission/submission.csv', index=None)
