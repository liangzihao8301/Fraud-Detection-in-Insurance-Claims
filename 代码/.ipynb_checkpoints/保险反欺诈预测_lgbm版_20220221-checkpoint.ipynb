# %%
#增加交叉特征
#Score: Score: 0.89048

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib # 注意这个也要import一次
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score, mean_squared_error, roc_curve, auc
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")

# %%
#数据加载
train_data = pd.read_csv('./fraud-detection-in-insurance-claims/train.csv')
test_data = pd.read_csv('./fraud-detection-in-insurance-claims/test.csv')

# %%
datas = pd.concat((train_data, test_data))
datas.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 数据探索

# %%
cat_columns = datas.select_dtypes(include=['O']).columns
numerical_columns = datas.select_dtypes(exclude=['O']).columns

# %%
col_name = []
unique_value = []
for col in cat_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_cat_col_unique = pd.DataFrame()
df_cat_col_unique['col_name'] = col_name
df_cat_col_unique['unique_value'] = unique_value
df_cat_col_unique = df_cat_col_unique.sort_values('unique_value', ascending= False)
# df_cat_col_unique

# %%
col_name = []
unique_value = []
for col in numerical_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_numerical_col_unique = pd.DataFrame()
df_numerical_col_unique['col_name'] = col_name
df_numerical_col_unique['unique_value'] = unique_value
df_numerical_col_unique = df_numerical_col_unique.sort_values('unique_value', ascending= False)
# df_numerical_col_unique

# %%
df_cat_col_unique
# df_numerical_col_unique
# Out:
#                    col_name  unique_value
# 6         incident_location          1000
# 16         policy_bind_date           951
# 5             incident_date            60
# 2                auto_model            39
# 11          insured_hobbies            20
# 12       insured_occupation            14
# 1                 auto_make            14
# 10  insured_education_level             7
# 4             incident_city             7
# 8            incident_state             7
# 13     insured_relationship             6
# 0     authorities_contacted             5
# 9             incident_type             4
# 7         incident_severity             4
# 3            collision_type             4
# 15  police_report_available             3
# 17               policy_csl             3
# 18             policy_state             3
# 19          property_damage             3
# 14              insured_sex             2

# %% [markdown]
# ## 特征工程

# %% [markdown]
# #### 标签编码 policy_bind_date、incident_date

# %%
datas['policy_bind_date'] = pd.to_datetime(datas['policy_bind_date'])
datas['incident_date'] = pd.to_datetime(datas['incident_date'])

# %%
datas['policy_bind_date_year'] = datas['policy_bind_date'].dt.year
datas['policy_bind_date_month'] = datas['policy_bind_date'].dt.month
datas['policy_bind_date_day'] = datas['policy_bind_date'].dt.day
datas['policy_bind_date_weekday'] = datas['policy_bind_date'].dt.weekday

datas['incident_date_year'] = datas['incident_date'].dt.year
datas['incident_date_month'] = datas['incident_date'].dt.month
datas['incident_date_day'] = datas['incident_date'].dt.day
datas['incident_date_weekday'] = datas['incident_date'].dt.weekday

# %%
# 查看最小、最大日期
# datas.policy_bind_date.min() #1990-01-08
# datas.policy_bind_date.max() #2015-02-22

# datas.incident_date.min() #2015-01-01
# datas.incident_date.max() #2015-03-01

# %%
base_date = datas.policy_bind_date.min()
#转换为diff
datas['policy_bind_date_diff'] = (datas['policy_bind_date'] - base_date).dt.days
datas['incident_date_diff'] = (datas['incident_date'] - base_date).dt.days
datas['incident_date&policy_bind_date_diff'] = datas['incident_date_diff'] - datas['policy_bind_date_diff']

# %% [markdown]
# #### 构造交叉业务特征

# %%
datas['injury_claim_pct'] = datas['injury_claim']/datas['total_claim_amount']
datas['property_claim_pct'] = datas['property_claim']/datas['total_claim_amount']
datas['vehicle_claim_pct'] = datas['vehicle_claim']/datas['total_claim_amount']

# %%
datas['is_injury_claim'] = datas['injury_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_property_claim'] = datas['property_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_vehicle_claim'] = datas['vehicle_claim'].apply(lambda x: '1' if x >0 else '0')

# %%
datas['incident_type_&_is_injury_claim'] = datas['incident_type'] + '_' + datas['is_injury_claim']
datas['incident_type_&_is_property_claim'] = datas['incident_type'] + '_' + datas['is_property_claim']
datas['incident_type_&_is_vehicle_claim'] = datas['incident_type'] + '_' + datas['is_vehicle_claim']

datas['collision_type_&_is_injury_claim'] = datas['collision_type'] + '_' + datas['is_injury_claim']
datas['collision_type_&_is_property_claim'] = datas['collision_type'] + '_' + datas['is_property_claim']
datas['collision_type_&_is_vehicle_claim'] = datas['collision_type'] + '_' + datas['is_vehicle_claim']

# %%
datas['umbrella_limit_2_total_claim_amount'] = datas['umbrella_limit']/datas['total_claim_amount']

# %%
# datas[['incident_type', 'collision_type', 'policy_csl', 'policy_annual_premium', 'umbrella_limit', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'capital-gains', 'capital-loss']][datas['fraud_reported'] > 0]

# %%
#检查单个特征
# datas.incident_city.nunique()
# datas['incident_type'].value_counts()

# %%
datas.drop(['policy_bind_date', 'incident_date', '_c39', 'incident_location', 'policy_number', 'insured_zip'], axis= 1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_columns = datas.select_dtypes(include= ['O']).columns

# %%
for col in cat_columns:
    le = LabelEncoder()
    datas[col] = le.fit_transform(datas[col])

datas[cat_columns]
# Out:
#      authorities_contacted  auto_make  auto_model  collision_type  \
# 0                        0          9          26               3
# 1                        3          6          10               3
# 2                        4          7          36               3
# 3                        1         11          21               1
# 4                        1          5          14               2
# 5                        4         10           2               2
# 6                        1         12          18               3
# 7                        0         11          21               3
# 8                        0          4          30               2
# 9                        0         10           1               1
# 10                       0         11          15               2
# 11                       4          5          14               2
# 12                       1          1           4               2
# 13                       0          3          32               1
# 14                       0         13          28               3
# 15                       3          5          13               2
# 16                       3          2          37               3
# 17                       3          0          23               3
# 18                       3          2          22               2
# 19                       1          9          35               2
# 20                       3          5          14               3
# 21                       1          3          32               2
# 22                       2         13          28               0
# 23                       3         10           1               2
# 24                       4          9          35               2
# 25                       2          3          34               0
# 26                       1          5          14               1
# 27                       1          2          38               3
# 28                       1          1           5               3
# 29                       0         12          18               1
# ..                     ...        ...         ...             ...
# 970                      1         12           9               3
# 971                      0          5          13               2
# 972                      4          4          27               3
# 973                      0         11          15               1
# 974                      3         11          19               3
# 975                      3          1           4               1
# 976                      2          0          23               0
# 977                      4          2          38               3
# 978                      1          8           7               1
# 979                      0          5          16               1
# 980                      2          9          29               0
# 981                      0          4          27               3
# 982                      0         10           2               2
# 983                      1         11          19               2
# 984                      3          5          14               3
# 985                      1          7          17               2
# 986                      1          4          30               3
# 987                      4          9          35               2
# 988                      1         10           1               2
# 989                      0          0          23               3
# 990                      4          8           7               1
# 991                      1          8          24               3
# 992                      4         10           3               3
# 993                      2          5          16               0
# 994                      0          1           5               3
# 995                      2          4          27               0
# 996                      1          7          17               3
# 997                      4          4          30               2
# 998                      1          9          26               3
# 999                      0          6          10               1
#
#      incident_city  incident_severity  incident_state  incident_type  \
# 0                5                  2               0              2
# 1                6                  1               0              0
# 2                3                  2               6              2
# 3                3                  0               6              0
# 4                3                  2               4              0
# 5                6                  0               4              0
# 6                0                  2               1              0
# 7                1                  1               6              0
# 8                2                  2               4              0
# 9                1                  0               1              0
# 10               1                  2               4              2
# 11               0                  0               2              0
# 12               6                  2               4              0
# 13               0                  2               6              2
# 14               6                  0               5              0
# 15               0                  0               2              0
# 16               5                  2               6              0
# 17               2                  0               6              0
# 18               4                  1               1              0
# 19               2                  2               6              2
# 20               4                  0               2              0
# 21               0                  1               1              2
# 22               6                  1               1              1
# 23               2                  2               6              2
# 24               5                  1               1              0
# 25               3                  1               0              1
# 26               6                  0               0              2
# 27               4                  1               4              0
# 28               6                  1               4              2
# 29               3                  2               1              2
# ..             ...                ...             ...            ...
# 970              4                  0               1              2
# 971              2                  2               1              0
# 972              6                  1               4              2
# 973              0                  0               1              0
# 974              6                  0               4              2
# 975              3                  2               4              2
# 976              0                  3               6              1
# 977              3                  1               4              0
# 978              3                  2               1              2
# 979              5                  2               4              0
# 980              0                  1               5              3
# 981              1                  1               1              0
# 982              4                  2               6              0
# 983              3                  0               4              0
# 984              2                  0               6              2
# 985              4                  1               1              2
# 986              6                  0               5              2
# 987              2                  1               0              0
# 988              2                  0               5              2
# 989              1                  1               1              2
# 990              0                  2               4              2
# 991              2                  0               4              0
# 992              3                  0               6              2
# 993              3                  1               6              3
# 994              3                  0               4              2
# 995              0                  3               6              1
# 996              1                  2               6              0
# 997              2                  1               1              2
# 998              6                  1               5              0
# 999              2                  1               2              2
#
#      insured_education_level  insured_hobbies  \
# 0                          5               15
# 1                          3               14
# 2                          2               16
# 3                          3               18
# 4                          4               18
# 5                          3               17
# 6                          6                9
# 7                          6                3
# 8                          4               18
# 9                          2                4
# 10                         3               10
# 11                         3               16
# 12                         2               11
# 13                         1                8
# 14                         1                8
# 15                         5               14
# 16                         2                3
# 17                         4               12
# 18                         1                4
# 19                         4                9
# 20                         4               14
# 21                         6               16
# 22                         2                4
# 23                         4                8
# 24                         6               13
# 25                         6               17
# 26                         6                7
# 27                         1                4
# 28                         2               13
# 29                         4               10
# ..                       ...              ...
# 970                        2               19
# 971                        3                7
# 972                        5               15
# 973                        5                0
# 974                        3               16
# 975                        6               16
# 976                        4                4
# 977                        1               17
# 978                        3                6
# 979                        2                3
# 980                        3               13
# 981                        5               15
# 982                        1               13
# 983                        6                7
# 984                        0               11
# 985                        4               12
# 986                        0               10
# 987                        2               16
# 988                        2               19
# 989                        3                6
# 990                        4                1
# 991                        2               17
# 992                        1                8
# 993                        5               17
# 994                        4               18
# 995                        1               11
# 996                        4               12
# 997                        0               10
# 998                        4               10
# 990                  1                 0                                5
# 991                  1                 0                                1
# 992                  1                 0                                5
# 993                  1                 0                                7
# 994                  1                 0                                5
# 995                  1                 0                                3
# 996                  1                 0                                1
# 997                  1                 0                                5
# 998                  1                 0                                1
# 999                  1                 0                                5
#
#      incident_type_&_is_property_claim  incident_type_&_is_vehicle_claim  \
# 0                                    5                                 2
# 1                                    1                                 0
# 2                                    5                                 2
# 3                                    1                                 0
# 4                                    1                                 0
# 5                                    1                                 0
# 6                                    1                                 0
# 7                                    1                                 0
# 8                                    1                                 0
# 9                                    1                                 0
# 10                                   5                                 2
# 11                                   1                                 0
# 12                                   1                                 0
# 13                                   5                                 2
# 14                                   1                                 0
# 15                                   1                                 0
# 16                                   1                                 0
# 17                                   1                                 0
# 18                                   1                                 0
# 19                                   5                                 2
# 20                                   1                                 0
# 21                                   5                                 2
# 22                                   3                                 1
# 23                                   5                                 2
# 24                                   1                                 0
# 25                                   2                                 1
# 26                                   5                                 2
# 27                                   1                                 0
# 28                                   5                                 2
# 29                                   5                                 2
# ..                                 ...                               ...
# 970                                  5                                 2
# 971                                  1                                 0
# 972                                  5                                 2
# 973                                  1                                 0
# 974                                  5                                 2
# 975                                  5                                 2
# 976                                  3                                 1
# 977                                  1                                 0
# 978                                  5                                 2
# 979                                  1                                 0
# 980                                  7                                 3
# 981                                  1                                 0
# 982                                  1                                 0
# 983                                  1                                 0
# 984                                  5                                 2
# 985                                  5                                 2
# 986                                  5                                 2
# 987                                  1                                 0
# 988                                  5                                 2
# 989                                  4                                 2
# 990                                  5                                 2
# 991                                  1                                 0
# 992                                  5                                 2
# 993                                  7                                 3
# 994                                  5                                 2
# 995                                  3                                 1
# 996                                  1                                 0
# 997                                  5                                 2
# 998                                  1                                 0
# 999                                  5                                 2
#
#      collision_type_&_is_injury_claim  collision_type_&_is_property_claim  \
# 0                                   7                                   7
# 1                                   7                                   7
# 2                                   7                                   7
# 3                                   3                                   3
# 4                                   5                                   5
# 5                                   5                                   5
# 6                                   7                                   7
# 7                                   7                                   7
# 8                                   5                                   5
# 9                                   3                                   3
# 10                                  5                                   5
# 11                                  5                                   5
# 12                                  5                                   5
# 13                                  3                                   3
# 14                                  7                                   7
# 15                                  5                                   5
# 16                                  7                                   7
# 17                                  7                                   7
# 18                                  5                                   5
# 19                                  5                                   5
# 20                                  7                                   7
# 21                                  5                                   5
# 22                                  1                                   1
# 23                                  5                                   5
# 24                                  5                                   5
# 25                                  1                                   0
# 26                                  3                                   3
# 27                                  7                                   7
# 28                                  7                                   7
# 29                                  3                                   3
# ..                                ...                                 ...
# 970                                 7                                   7
# 971                                 5                                   5
# 972                                 7                                   7
# 973                                 3                                   3
# 974                                 7                                   7
# 975                                 3                                   3
# 976                                 1                                   1
# 977                                 7                                   7
# 978                                 3                                   3
# 979                                 3                                   3
# 980                                 1                                   1
# 981                                 7                                   7
# 982                                 5                                   5
# 983                                 5                                   5
# 984                                 7                                   7
# 985                                 5                                   5
# 986                                 7                                   7
# 987                                 5                                   5
# 988                                 5                                   5
# 989                                 7                                   6
# 990                                 3                                   3
# 991                                 7                                   7
# 992                                 7                                   7
# 993                                 1                                   1
# 994                                 7                                   7
# 995                                 1                                   1
# 996                                 7                                   7
# 997                                 5                                   5
# 998                                 7                                   7
# 999                                 3                                   3
#
#      collision_type_&_is_vehicle_claim
# 0                                    3
# 1                                    3
# 2                                    3
# 3                                    1
# 4                                    2
# 5                                    2
# 6                                    3
# 7                                    3
# 8                                    2
# 9                                    1
# 10                                   2
# 11                                   2
# 12                                   2
# 13                                   1
# 14                                   3
# 15                                   2
# 16                                   3
# 17                                   3
# 18                                   2
# 19                                   2
# 20                                   3
# 21                                   2
# 22                                   0
# 23                                   2
# 24                                   2
# 25                                   0
# 26                                   1
# 27                                   3
# 28                                   3
# 29                                   1
# ..                                 ...
# 970                                  3
# 971                                  2
# 972                                  3
# 973                                  1
# 974                                  3
# 975                                  1
# 976                                  0
# 977                                  3
# 978                                  1
# 979                                  1
# 980                                  0
# 981                                  3
# 982                                  2
# 983                                  2
# 984                                  3
# 985                                  2
# 986                                  3
# 987                                  2
# 988                                  2
# 989                                  3
# 990                                  1
# 991                                  3
# 992                                  3
# 993                                  0
# 994                                  3
# 995                                  0
# 996                                  3
# 997                                  2
# 998                                  3
# 999                                  1
#
# [1000 rows x 26 columns]

# %%
# 数据集切分
train = datas[datas['fraud_reported'].notnull()]
test = datas[datas['fraud_reported'].isnull()]

# %%
train_X = train.drop(['fraud_reported'], axis=1)
train_y = train['fraud_reported']
test_X = test.drop(['fraud_reported'], axis=1)

# %% [markdown]
# ## 使用lgbm 训练

# %%
import lightgbm as lgb

# %%
model_lgb = lgb.LGBMClassifier(
            num_leaves=2**5-1, reg_alpha=0.25, reg_lambda=0.25, objective='binary',
            max_depth=-1, learning_rate=0.005, min_child_samples=3, random_state=2022,
            n_estimators=2000, subsample=1, colsample_bytree=1,
        )

# %%
model_lgb.fit(train_X, train_y)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1,
#         importance_type='split', learning_rate=0.005, max_depth=-1,
#         min_child_samples=3, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=2000, n_jobs=-1, num_leaves=31, objective='binary',
#         random_state=2022, reg_alpha=0.25, reg_lambda=0.25, silent=True,
#         subsample=1, subsample_for_bin=200000, subsample_freq=0)

# %%
y_pred = model_lgb.predict_proba(test_X)[:, 1]

# %%
y_pred
# Out:
# array([  2.42400315e-02,   4.46858625e-01,   8.14351041e-03,
#          1.91852983e-02,   1.44779541e-03,   2.05762767e-02,
#          2.05367829e-03,   1.15923451e-02,   1.52955292e-03,
#          2.04309040e-03,   7.21491824e-02,   3.78330221e-03,
#          6.56926778e-01,   2.89504214e-03,   4.90626702e-03,
#          8.18810668e-01,   8.24677692e-03,   8.33522259e-03,
#          5.42819374e-01,   5.16989473e-03,   4.56539035e-03,
#          5.61079440e-01,   8.41912838e-01,   1.71253608e-02,
#          9.40793008e-03,   8.95571218e-01,   2.31114647e-03,
#          7.01513741e-03,   1.77012427e-01,   9.57104536e-02,
#          8.50726509e-01,   7.05871082e-02,   4.89147432e-01,
#          2.22289148e-02,   2.97142023e-01,   6.83559082e-01,
#          7.32528403e-03,   9.79693004e-01,   8.54463618e-03,
#          1.47709986e-02,   5.98309163e-03,   3.71564024e-03,
#          1.18294415e-03,   7.05680146e-03,   2.04317517e-03,
#          2.30065962e-03,   1.99307316e-02,   9.51067354e-01,
#          1.35618778e-02,   9.78580611e-01,   7.59723513e-03,
#          3.34154400e-02,   6.36540515e-03,   1.73237024e-02,
#          1.03811341e-02,   9.19588343e-01,   8.74794815e-01,
#          3.08558448e-03,   6.41971809e-02,   3.29935041e-03,
#          4.42093027e-03,   7.87067008e-01,   2.37228626e-02,
#          6.12805285e-03,   9.72944372e-01,   1.82362949e-02,
#          7.19731796e-03,   1.56296880e-02,   7.73057866e-03,
#          1.02360399e-01,   4.65142446e-03,   4.06613806e-03,
#          2.66719692e-03,   1.69840729e-03,   3.51487779e-03,
#          2.02076038e-03,   3.06425867e-01,   4.61823256e-02,
#          7.82187530e-02,   1.98051633e-03,   8.55337280e-03,
#          6.17298745e-01,   2.32788710e-02,   3.65681006e-02,
#          1.55536905e-02,   1.44184303e-02,   1.56115526e-02,
#          9.43770951e-01,   1.87196259e-03,   3.74000068e-02,
#          8.77796355e-01,   1.70958536e-02,   1.13392358e-02,
#          1.79248618e-02,   2.23313960e-03,   3.15245253e-03,
#          8.67566507e-01,   9.76394238e-01,   3.92037301e-03,
#          3.09330429e-03,   9.45032503e-04,   1.78535760e-03,
#          1.25622582e-01,   7.06466019e-03,   6.01548899e-03,
#          1.22187804e-02,   2.07068058e-03,   6.19615222e-01,
#          5.55282587e-03,   1.36201812e-02,   3.06652283e-03,
#          1.94764050e-02,   2.02823030e-01,   3.77508838e-01,
#          3.43070010e-01,   1.05239813e-03,   9.82011394e-04,
#          1.18782916e-02,   2.05675545e-01,   5.86223393e-03,
#          8.86186798e-01,   1.43575298e-02,   9.41896335e-01,
#          4.92309229e-03,   7.87714900e-01,   5.18858246e-03,
#          8.42091214e-03,   2.20154702e-02,   2.23974586e-02,
#          1.97708733e-02,   4.63397760e-03,   3.30530655e-03,
#          9.43476614e-01,   8.18719489e-03,   2.68484279e-03,
#          5.67877384e-01,   3.48161543e-01,   1.78242718e-02,
#          8.56011852e-03,   3.64829777e-03,   9.81981148e-01,
#          1.90084467e-03,   1.87178102e-03,   2.25591731e-02,
#          4.61800854e-03,   7.89053219e-01,   3.77395337e-01,
#          3.30703844e-03,   8.45840449e-01,   5.43952223e-02,
#          2.82162550e-01,   8.44043080e-01,   1.20791815e-02,
#          8.89035770e-01,   4.26265981e-02,   5.53194016e-02,
#          6.96277196e-01,   3.39474298e-03,   2.73466088e-03,
#          7.56150259e-04,   1.68980506e-02,   3.59182839e-03])

# %%
fig, ax = plt.subplots(figsize=(6,18))
lgb.plot_importance(model_lgb, max_num_features=30, ax = ax)

# %%
submission = pd.read_csv('./fraud-detection-in-insurance-claims/sampleSubmission.csv')
submission['fraud_reported'] = y_pred
submission.to_csv('./submission/submission.csv', index=None)
