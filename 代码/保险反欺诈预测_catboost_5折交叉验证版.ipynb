# %%
#使用5折交叉验证,增加scale_pos_weight参数
#Score: 0.87666
#交叉特征增加location_type，不使用G/L，#增加scale_pos_weight参数2.5
#Score: 0.87503
#增加incident_location_type、incident_location_street、policy_bind_date_year&auto_year_diff、incident_date_year&auto_year_diff、duration、出险情况2、出险车信息
#Score: 0.88316

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib # 注意这个也要import一次
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score, mean_squared_error, roc_curve, auc
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")

# %%
#数据加载
train_data = pd.read_csv('./data/train.csv')
test_data = pd.read_csv('./data/test.csv')

# %%
# train_data.head(10).T
# train_data.isnull().sum()

# %%
datas = pd.concat((train_data, test_data))
datas.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 数据探索

# %%
# datas.tail(5).T

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        1000 non-null   object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               700 non-null    float64
#  39  _c39                         0 non-null      float64
# dtypes: float64(3), int64(17), object(20)
# memory usage: 312.6+ KB

# %%
# datas.describe().T

# %%
# datas.isnull().sum()

# %%
# datas.drop(columns=['_c39'], inplace=True)

# %%
for col in datas.columns:
    print(col, datas[col].nunique())
# Out:
# months_as_customer 391
# age 46
# policy_number 1000
# policy_bind_date 951
# policy_state 3
# policy_csl 3
# policy_deductable 3
# policy_annual_premium 991
# umbrella_limit 11
# insured_zip 995
# insured_sex 2
# insured_education_level 7
# insured_occupation 14
# insured_hobbies 20
# insured_relationship 6
# capital-gains 338
# capital-loss 354
# incident_date 60
# incident_type 4
# collision_type 4
# incident_severity 4
# authorities_contacted 5
# incident_state 7
# incident_city 7
# incident_location 1000
# incident_hour_of_the_day 24
# number_of_vehicles_involved 4
# property_damage 3
# bodily_injuries 3
# witnesses 4
# police_report_available 3
# total_claim_amount 763
# injury_claim 638
# property_claim 626
# vehicle_claim 726
# auto_make 14
# auto_model 39
# auto_year 21
# fraud_reported 2
# _c39 0

# %%
cat_columns = datas.select_dtypes(include='O').columns
numerical_columns = datas.select_dtypes(exclude='O').columns

# %%
cat_columns, numerical_columns
# Out:
# (Index(['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex',
#         'insured_education_level', 'insured_occupation', 'insured_hobbies',
#         'insured_relationship', 'incident_date', 'incident_type',
#         'collision_type', 'incident_severity', 'authorities_contacted',
#         'incident_state', 'incident_city', 'incident_location',
#         'property_damage', 'police_report_available', 'auto_make',
#         'auto_model'],
#        dtype='object'),
#  Index(['months_as_customer', 'age', 'policy_number', 'policy_deductable',
#         'policy_annual_premium', 'umbrella_limit', 'insured_zip',
#         'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#         'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#         'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#         'auto_year', 'fraud_reported', '_c39'],
#        dtype='object'))

# %%
col_name = []
unique_value = []
for col in cat_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_cat_col_unique = pd.DataFrame()
df_cat_col_unique['col_name'] = col_name
df_cat_col_unique['unique_value'] = unique_value
df_cat_col_unique = df_cat_col_unique.sort_values('unique_value', ascending= False)
# df_cat_col_unique

# %%
col_name = []
unique_value = []
for col in numerical_columns:
    # print(col, datas[col].nunique())
    col_name.append(col)
    unique_value.append(datas[col].nunique())

df_numerical_col_unique = pd.DataFrame()
df_numerical_col_unique['col_name'] = col_name
df_numerical_col_unique['unique_value'] = unique_value
df_numerical_col_unique = df_numerical_col_unique.sort_values('unique_value', ascending= False)
# df_numerical_col_unique

# %%
# df_cat_col_unique
df_numerical_col_unique
# Out:
#                        col_name  unique_value
# 2                 policy_number          1000
# 6                   insured_zip           995
# 4         policy_annual_premium           991
# 13           total_claim_amount           763
# 16                vehicle_claim           726
# 14                 injury_claim           638
# 15               property_claim           626
# 0            months_as_customer           391
# 8                  capital-loss           354
# 7                 capital-gains           338
# 1                           age            46
# 9      incident_hour_of_the_day            24
# 17                    auto_year            21
# 5                umbrella_limit            11
# 10  number_of_vehicles_involved             4
# 12                    witnesses             4
# 11              bodily_injuries             3
# 3             policy_deductable             3
# 18               fraud_reported             2
# 19                         _c39             0

# %% [markdown]
# ## 特征工程

# %% [markdown]
# #### 标签编码 policy_bind_date、incident_date

# %%
datas['policy_bind_date'] = pd.to_datetime(datas['policy_bind_date'])
datas['incident_date'] = pd.to_datetime(datas['incident_date'])

# %%
datas['policy_bind_date_year'] = datas['policy_bind_date'].dt.year
datas['policy_bind_date_month'] = datas['policy_bind_date'].dt.month
datas['policy_bind_date_day'] = datas['policy_bind_date'].dt.day
datas['policy_bind_date_weekday'] = datas['policy_bind_date'].dt.weekday

datas['incident_date_year'] = datas['incident_date'].dt.year
datas['incident_date_month'] = datas['incident_date'].dt.month
datas['incident_date_day'] = datas['incident_date'].dt.day
datas['incident_date_weekday'] = datas['incident_date'].dt.weekday

# %%
# 查看最小、最大日期
# datas.policy_bind_date.min() #1990-01-08
# datas.policy_bind_date.max() #2015-02-22

# datas.incident_date.min() #2015-01-01
# datas.incident_date.max() #2015-03-01

# %%
base_date = datas.policy_bind_date.min()
#转换为diff
datas['policy_bind_date_diff'] = (datas['policy_bind_date'] - base_date).dt.days
datas['incident_date_diff'] = (datas['incident_date'] - base_date).dt.days
datas['incident_date&policy_bind_date_diff'] = datas['incident_date_diff'] - datas['policy_bind_date_diff']

# %%
datas.T
# Out:
#                                                           0    \
# months_as_customer                                        187
# age                                                        37
# policy_number                                          125591
# policy_bind_date                          2013-08-08 00:00:00
# policy_state                                               IN
# policy_csl                                           500/1000
# policy_deductable                                        1000
# policy_annual_premium                                 1412.06
# umbrella_limit                                        5000000
# insured_zip                                            450947
# insured_sex                                            FEMALE
# insured_education_level                               Masters
# insured_occupation                            protective-serv
# insured_hobbies                                       reading
# insured_relationship                            not-in-family
# capital-gains                                           60100
# capital-loss                                                0
# incident_date                             2015-01-16 00:00:00
# incident_type                        Single Vehicle Collision
# collision_type                                 Side Collision
# incident_severity                                  Total Loss
# authorities_contacted                               Ambulance
# incident_state                                             NC
# incident_city                                       Riverwood
# incident_location                              7082 Oak Ridge
# incident_hour_of_the_day                                   21
# number_of_vehicles_involved                                 1
# property_damage                                             ?
# bodily_injuries                                             0
# witnesses                                                   3
# police_report_available                                     ?
# total_claim_amount                                      57700
# injury_claim                                             5770
# property_claim                                           5770
# vehicle_claim                                           46160
# auto_make                                              Nissan
# auto_model                                             Maxima
# auto_year                                                2000
# fraud_reported                                            0.0
# _c39                                                      NaN
# policy_bind_date_year                                    2013
# policy_bind_date_month                                      8
# policy_bind_date_day                                        8
# policy_bind_date_weekday                                    3
# incident_date_year                                       2015
# incident_date_month                                         1
# incident_date_day                                          16
# incident_date_weekday                                       4
# policy_bind_date_diff                                    8613
# incident_date_diff                                       9139
# incident_date&policy_bind_date_diff                       526
#
#                                                          1    \
# months_as_customer                                       243
# age                                                       44
# policy_number                                         967713
# policy_bind_date                         1997-12-25 00:00:00
# policy_state                                              IL
# policy_csl                                           250/500
# policy_deductable                                        500
# policy_annual_premium                                 809.11
# umbrella_limit                                             0
# insured_zip                                           600208
# insured_sex                                             MALE
# insured_education_level                                   JD
# insured_occupation                              craft-repair
# insured_hobbies                                         polo
# insured_relationship                          other-relative
# capital-gains                                          33200
# capital-loss                                               0
# incident_date                            2015-01-27 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                                Side Collision
# incident_severity                               Minor Damage
# authorities_contacted                                  Other
# incident_state                                            NC
# incident_city                                    Springfield
# incident_location                        9352 Washington Ave
# incident_hour_of_the_day                                   4
# number_of_vehicles_involved                                3
# property_damage                                            ?
# bodily_injuries                                            2
# witnesses                                                  1
# police_report_available                                  YES
# total_claim_amount                                     51400
# injury_claim                                            5140
# property_claim                                         10280
# vehicle_claim                                          35980
# auto_make                                              Honda
# auto_model                                             Civic
# auto_year                                               1996
# fraud_reported                                           0.0
# _c39                                                     NaN
# policy_bind_date_year                                   1997
# policy_bind_date_month                                    12
# policy_bind_date_day                                      25
# policy_bind_date_weekday                                   3
# incident_date_year                                      2015
# incident_date_month                                        1
# incident_date_day                                         27
# incident_date_weekday                                      1
# policy_bind_date_diff                                   2908
# incident_date_diff                                      9150
# incident_date&policy_bind_date_diff                     6242
#
#                                                           2    \
# months_as_customer                                         24
# age                                                        33
# policy_number                                          649082
# policy_bind_date                          1996-01-19 00:00:00
# policy_state                                               IL
# policy_csl                                           500/1000
# policy_deductable                                        1000
# policy_annual_premium                                 1922.84
# umbrella_limit                                              0
# insured_zip                                            431277
# insured_sex                                            FEMALE
# insured_education_level                           High School
# insured_occupation                          machine-op-inspct
# insured_hobbies                                     skydiving
# insured_relationship                                     wife
# capital-gains                                               0
# capital-loss                                           -45200
# incident_date                             2015-01-24 00:00:00
# incident_type                        Single Vehicle Collision
# collision_type                                 Side Collision
# incident_severity                                  Total Loss
# authorities_contacted                                  Police
# incident_state                                             WV
# incident_city                                       Northbend
# incident_location                            5061 Francis Ave
# incident_hour_of_the_day                                    0
# number_of_vehicles_involved                                 1
# property_damage                                             ?
# bodily_injuries                                             2
# witnesses                                                   1
# police_report_available                                    NO
# total_claim_amount                                      46800
# injury_claim                                             4680
# property_claim                                           9360
# vehicle_claim                                           32760
# auto_make                                                Jeep
# auto_model                                           Wrangler
# auto_year                                                2002
# fraud_reported                                            0.0
# _c39                                                      NaN
# policy_bind_date_year                                    1996
# policy_bind_date_month                                      1
# policy_bind_date_day                                       19
# policy_bind_date_weekday                                    4
# incident_date_year                                       2015
# incident_date_month                                         1
# incident_date_day                                          24
# incident_date_weekday                                       5
# policy_bind_date_diff                                    2202
# incident_date_diff                                       9147
# incident_date&policy_bind_date_diff                      6945
#
#                                                          3    \
# months_as_customer                                       215
# age                                                       42
# policy_number                                         519312
# policy_bind_date                         2008-10-28 00:00:00
# policy_state                                              OH
# policy_csl                                          500/1000
# policy_deductable                                        500
# policy_annual_premium                                1848.81
# umbrella_limit                                             0
# insured_zip                                           435489
# insured_sex                                             MALE
# insured_education_level                                   JD
# insured_occupation                          transport-moving
# insured_hobbies                                  video-games
# insured_relationship                               own-child
# capital-gains                                              0
# capital-loss                                          -49000
# incident_date                            2015-02-06 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                               Front Collision
# incident_severity                               Major Damage
# authorities_contacted                                   Fire
# incident_state                                            WV
# incident_city                                      Northbend
# incident_location                        2457 Washington Ave
# incident_hour_of_the_day                                  20
# number_of_vehicles_involved                                3
# property_damage                                          YES
# bodily_injuries                                            2
# witnesses                                                  2
# police_report_available                                  YES
# total_claim_amount                                     68520
# injury_claim                                           11420
# property_claim                                          5710
# vehicle_claim                                          51390
# auto_make                                             Suburu
# auto_model                                            Legacy
# auto_year                                               2003
# fraud_reported                                           1.0
# _c39                                                     NaN
# policy_bind_date_year                                   2008
# policy_bind_date_month                                    10
# policy_bind_date_day                                      28
# policy_bind_date_weekday                                   1
# incident_date_year                                      2015
# incident_date_month                                        2
# incident_date_day                                          6
# incident_date_weekday                                      4
# policy_bind_date_diff                                   6868
# incident_date_diff                                      9160
# incident_date&policy_bind_date_diff                     2292
#
#                                                          4    \
# months_as_customer                                        85
# age                                                       30
# policy_number                                         190588
# policy_bind_date                         2001-12-09 00:00:00
# policy_state                                              OH
# policy_csl                                           100/300
# policy_deductable                                       1000
# policy_annual_premium                                 796.35
# umbrella_limit                                             0
# insured_zip                                           614166
# insured_sex                                           FEMALE
# insured_education_level                                   MD
# insured_occupation                              craft-repair
# insured_hobbies                                  video-games
# insured_relationship                               own-child
# capital-gains                                          72400
# capital-loss                                          -77000
# incident_date                            2015-02-20 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                                Rear Collision
# incident_severity                                 Total Loss
# authorities_contacted                                   Fire
# incident_state                                            SC
# incident_city                                      Northbend
# incident_location                               2290 4th Ave
# incident_hour_of_the_day                                   9
# number_of_vehicles_involved                                3
# property_damage                                          YES
# bodily_injuries                                            2
# witnesses                                                  1
# police_report_available                                  YES
# total_claim_amount                                     58960
# injury_claim                                            5360
# property_claim                                         10720
# vehicle_claim                                          42880
# auto_make                                               Ford
# auto_model                                              F150
# auto_year                                               2004
# fraud_reported                                           0.0
# _c39                                                     NaN
# policy_bind_date_year                                   2001
# policy_bind_date_month                                    12
# policy_bind_date_day                                       9
# policy_bind_date_weekday                                   6
# incident_date_year                                      2015
# incident_date_month                                        2
# incident_date_day                                         20
# incident_date_weekday                                      4
# policy_bind_date_diff                                   4353
# incident_date_diff                                      9174
# incident_date&policy_bind_date_diff                     4821
#
#                                                          5    \
# months_as_customer                                       310
# age                                                       48
# policy_number                                         670142
# policy_bind_date                         1999-08-06 00:00:00
# policy_state                                              IN
# policy_csl                                           100/300
# policy_deductable                                        500
# policy_annual_premium                                1516.34
# umbrella_limit                                             0
# insured_zip                                           474167
# insured_sex                                           FEMALE
# insured_education_level                                   JD
# insured_occupation                              adm-clerical
# insured_hobbies                                     sleeping
# insured_relationship                               unmarried
# capital-gains                                          11000
# capital-loss                                               0
# incident_date                            2015-01-04 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                                Rear Collision
# incident_severity                               Major Damage
# authorities_contacted                                 Police
# incident_state                                            SC
# incident_city                                    Springfield
# incident_location                           2823 Weaver Lane
# incident_hour_of_the_day                                  11
# number_of_vehicles_involved                                4
# property_damage                                          YES
# bodily_injuries                                            0
# witnesses                                                  2
# police_report_available                                   NO
# total_claim_amount                                     59400
# injury_claim                                           13200
# property_claim                                          6600
# vehicle_claim                                          39600
# auto_make                                               Saab
# auto_model                                                93
# auto_year                                               1996
# fraud_reported                                           1.0
# _c39                                                     NaN
# policy_bind_date_year                                   1999
# policy_bind_date_month                                     8
# policy_bind_date_day                                       6
# policy_bind_date_weekday                                   4
# incident_date_year                                      2015
# incident_date_month                                        1
# incident_date_day                                          4
# incident_date_weekday                                      6
# policy_bind_date_diff                                   3497
# incident_date_diff                                      9127
# incident_date&policy_bind_date_diff                     5630
#
#                                                          6    \
# months_as_customer                                       297
# age                                                       48
# policy_number                                         751612
# policy_bind_date                         2009-06-22 00:00:00
# policy_state                                              IN
# policy_csl                                           250/500
# policy_deductable                                       1000
# policy_annual_premium                                1464.73
# umbrella_limit                                       3000000
# insured_zip                                           443861
# insured_sex                                             MALE
# insured_education_level                                  PhD
# insured_occupation                           exec-managerial
# insured_hobbies                                         golf
# insured_relationship                          other-relative
# capital-gains                                          54900
# capital-loss                                          -36700
# incident_date                            2015-01-25 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                                Side Collision
# incident_severity                                 Total Loss
# authorities_contacted                                   Fire
# incident_state                                            NY
# incident_city                                      Arlington
# incident_location                                8758 5th St
# incident_hour_of_the_day                                  17
# number_of_vehicles_involved                                3
# property_damage                                            ?
# bodily_injuries                                            0
# witnesses                                                  0
# police_report_available                                   NO
# total_claim_amount                                     51480
# injury_claim                                            5720
# property_claim                                          5720
# vehicle_claim                                          40040
# auto_make                                             Toyota
# auto_model                                        Highlander
# auto_year                                               2013
# fraud_reported                                           0.0
# _c39                                                     NaN
# policy_bind_date_year                                   2009
# policy_bind_date_month                                     6
# policy_bind_date_day                                      22
# policy_bind_date_weekday                                   0
# incident_date_year                                      2015
# incident_date_month                                        1
# incident_date_day                                         25
# incident_date_weekday                                      6
# policy_bind_date_diff                                   7105
# incident_date_diff                                      9148
# incident_date&policy_bind_date_diff                     2043
#
#                                                          7    \
# months_as_customer                                       108
# age                                                       29
# policy_number                                         237418
# policy_bind_date                         2007-12-04 00:00:00
# policy_state                                              IN
# policy_csl                                          500/1000
# policy_deductable                                       1000
# policy_annual_premium                                1337.92
# umbrella_limit                                             0
# insured_zip                                           441536
# insured_sex                                           FEMALE
# insured_education_level                                  PhD
# insured_occupation                              armed-forces
# insured_hobbies                               bungie-jumping
# insured_relationship                           not-in-family
# capital-gains                                          71400
# capital-loss                                               0
# incident_date                            2015-02-23 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                                Side Collision
# incident_severity                               Minor Damage
# authorities_contacted                              Ambulance
# incident_state                                            WV
# incident_city                                       Columbus
# incident_location                         7684 Francis Ridge
# incident_hour_of_the_day                                   4
# number_of_vehicles_involved                                3
# property_damage                                           NO
# bodily_injuries                                            2
# witnesses                                                  2
# police_report_available                                  YES
# total_claim_amount                                     61380
# injury_claim                                           11160
# property_claim                                          5580
# vehicle_claim                                          44640
# auto_make                                             Suburu
# auto_model                                            Legacy
# auto_year                                               2012
# fraud_reported                                           0.0
# _c39                                                     NaN
# policy_bind_date_year                                   2007
# policy_bind_date_month                                    12
# policy_bind_date_day                                       4
# policy_bind_date_weekday                                   1
# incident_date_year                                      2015
# incident_date_month                                        2
# incident_date_day                                         23
# incident_date_weekday                                      0
# policy_bind_date_diff                                   6539
# incident_date_diff                                      9177
# incident_date&policy_bind_date_diff                     2638
#
#                                                          8    \
# months_as_customer                                        46
# age                                                       41
# policy_number                                         315041
# policy_bind_date                         2010-11-02 00:00:00
# policy_state                                              OH
# policy_csl                                           100/300
# policy_deductable                                       2000
# policy_annual_premium                                 998.19
# umbrella_limit                                             0
# insured_zip                                           611556
# insured_sex                                           FEMALE
# insured_education_level                                   MD
# insured_occupation                           priv-house-serv
# insured_hobbies                                  video-games
# insured_relationship                                 husband
# capital-gains                                          43700
# capital-loss                                          -66300
# incident_date                            2015-01-23 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                                Rear Collision
# incident_severity                                 Total Loss
# authorities_contacted                              Ambulance
# incident_state                                            SC
# incident_city                                      Hillsdale
# incident_location                              5779 2nd Lane
# incident_hour_of_the_day                                  23
# number_of_vehicles_involved                                3
# property_damage                                           NO
# bodily_injuries                                            1
# witnesses                                                  3
# police_report_available                                    ?
# total_claim_amount                                     78600
# injury_claim                                           13100
# property_claim                                         19650
# vehicle_claim                                          45850
# auto_make                                              Dodge
# auto_model                                               RAM
# auto_year                                               2004
# fraud_reported                                           1.0
# _c39                                                     NaN
# policy_bind_date_year                                   2010
# policy_bind_date_month                                    11
# policy_bind_date_day                                       2
# policy_bind_date_weekday                                   1
# incident_date_year                                      2015
# incident_date_month                                        1
# incident_date_day                                         23
# incident_date_weekday                                      4
# policy_bind_date_diff                                   7603
# incident_date_diff                                      9146
# incident_date&policy_bind_date_diff                     1543
#
#                                                          9    ...  \
# months_as_customer                                       286  ...
# age                                                       41  ...
# policy_number                                         507545  ...
# policy_bind_date                         1998-12-07 00:00:00  ...
# policy_state                                              IL  ...
# policy_csl                                           250/500  ...
# policy_deductable                                       1000  ...
# policy_annual_premium                                1298.85  ...
# umbrella_limit                                       6000000  ...
# insured_zip                                           435967  ...
# insured_sex                                           FEMALE  ...
# insured_education_level                          High School  ...
# insured_occupation                                     sales  ...
# insured_hobbies                                      camping  ...
# insured_relationship                          other-relative  ...
# capital-gains                                          71300  ...
# capital-loss                                          -70300  ...
# incident_date                            2015-01-04 00:00:00  ...
# incident_type                        Multi-vehicle Collision  ...
# collision_type                               Front Collision  ...
# incident_severity                               Major Damage  ...
# authorities_contacted                              Ambulance  ...
# incident_state                                            NY  ...
# incident_city                                       Columbus  ...
# incident_location                           6859 Flute Ridge  ...
# incident_hour_of_the_day                                  16  ...
# number_of_vehicles_involved                                3  ...
# property_damage                                            ?  ...
# bodily_injuries                                            1  ...
# witnesses                                                  3  ...
# police_report_available                                  YES  ...
# total_claim_amount                                     54450  ...
# injury_claim                                            6050  ...
# property_claim                                         12100  ...
# vehicle_claim                                          36300  ...
# auto_make                                               Saab  ...
# auto_model                                               92x  ...
# auto_year                                               2007  ...
# fraud_reported                                           0.0  ...
# _c39                                                     NaN  ...
# policy_bind_date_year                                   1998  ...
# policy_bind_date_month                                    12  ...
# policy_bind_date_day                                       7  ...
# policy_bind_date_weekday                                   0  ...
# incident_date_year                                      2015  ...
# incident_date_month                                        1  ...
# incident_date_day                                          4  ...
# incident_date_weekday                                      6  ...
# policy_bind_date_diff                                   3255  ...
# incident_date_diff                                      9127  ...
# incident_date&policy_bind_date_diff                     5872  ...
#
#                                                           990  \
# months_as_customer                                        359
# age                                                        47
# policy_number                                          828890
# policy_bind_date                          1993-10-20 00:00:00
# policy_state                                               OH
# policy_csl                                            100/300
# policy_deductable                                        2000
# policy_annual_premium                                 1367.68
# umbrella_limit                                              0
# insured_zip                                            613247
# insured_sex                                            FEMALE
# insured_education_level                                    MD
# insured_occupation                          handlers-cleaners
# insured_hobbies                                    basketball
# insured_relationship                                unmarried
# capital-gains                                               0
# capital-loss                                                0
# incident_date                             2015-01-11 00:00:00
# incident_type                        Single Vehicle Collision
# collision_type                                Front Collision
# incident_severity                                  Total Loss
# authorities_contacted                                  Police
# incident_state                                             SC
# incident_city                                       Arlington
# incident_location                             6955 Pine Drive
# incident_hour_of_the_day                                   13
# number_of_vehicles_involved                                 1
# property_damage                                            NO
# bodily_injuries                                             0
# witnesses                                                   3
# police_report_available                                    NO
# total_claim_amount                                      55500
# injury_claim                                             5550
# property_claim                                          11100
# vehicle_claim                                           38850
# auto_make                                            Mercedes
# auto_model                                               C300
# auto_year                                                2012
# fraud_reported                                            NaN
# _c39                                                      NaN
# policy_bind_date_year                                    1993
# policy_bind_date_month                                     10
# policy_bind_date_day                                       20
# policy_bind_date_weekday                                    2
# incident_date_year                                       2015
# incident_date_month                                         1
# incident_date_day                                          11
# incident_date_weekday                                       6
# policy_bind_date_diff                                    1381
# incident_date_diff                                       9134
# incident_date&policy_bind_date_diff                      7753
#
#                                                          991  \
# months_as_customer                                       160
# age                                                       38
# policy_number                                         497929
# policy_bind_date                         2009-09-19 00:00:00
# policy_state                                              OH
# policy_csl                                           250/500
# policy_deductable                                        500
# policy_annual_premium                                1733.56
# umbrella_limit                                             0
# insured_zip                                           441425
# insured_sex                                             MALE
# insured_education_level                          High School
# insured_occupation                                     sales
# insured_hobbies                                     sleeping
# insured_relationship                                    wife
# capital-gains                                              0
# capital-loss                                          -43800
# incident_date                            2015-01-09 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                                Side Collision
# incident_severity                               Major Damage
# authorities_contacted                                   Fire
# incident_state                                            SC
# incident_city                                      Hillsdale
# incident_location                           5894 Flute Drive
# incident_hour_of_the_day                                  13
# number_of_vehicles_involved                                3
# property_damage                                           NO
# bodily_injuries                                            2
# witnesses                                                  1
# police_report_available                                  YES
# total_claim_amount                                     66780
# injury_claim                                            7420
# property_claim                                         14840
# vehicle_claim                                          44520
# auto_make                                           Mercedes
# auto_model                                             ML350
# auto_year                                               1996
# fraud_reported                                           NaN
# _c39                                                     NaN
# policy_bind_date_year                                   2009
# policy_bind_date_month                                     9
# policy_bind_date_day                                      19
# policy_bind_date_weekday                                   5
# incident_date_year                                      2015
# incident_date_month                                        1
# incident_date_day                                          9
# incident_date_weekday                                      4
# policy_bind_date_diff                                   7194
# incident_date_diff                                      9132
# incident_date&policy_bind_date_diff                     1938
#
#                                                           992  \
# months_as_customer                                         80
# age                                                        27
# policy_number                                          193442
# policy_bind_date                          1996-08-05 00:00:00
# policy_state                                               IL
# policy_csl                                            100/300
# policy_deductable                                        1000
# policy_annual_premium                                 1474.17
# umbrella_limit                                              0
# insured_zip                                            440327
# insured_sex                                            FEMALE
# insured_education_level                               College
# insured_occupation                               tech-support
# insured_hobbies                                      exercise
# insured_relationship                                unmarried
# capital-gains                                               0
# capital-loss                                                0
# incident_date                             2015-02-19 00:00:00
# incident_type                        Single Vehicle Collision
# collision_type                                 Side Collision
# incident_severity                                Major Damage
# authorities_contacted                                  Police
# incident_state                                             WV
# incident_city                                       Northbend
# incident_location                               7773 Tree Hwy
# incident_hour_of_the_day                                   13
# number_of_vehicles_involved                                 1
# property_damage                                           YES
# bodily_injuries                                             1
# witnesses                                                   0
# police_report_available                                   YES
# total_claim_amount                                      52800
# injury_claim                                            10560
# property_claim                                           5280
# vehicle_claim                                           36960
# auto_make                                                Saab
# auto_model                                                 95
# auto_year                                                2004
# fraud_reported                                            NaN
# _c39                                                      NaN
# policy_bind_date_year                                    1996
# policy_bind_date_month                                      8
# policy_bind_date_day                                        5
# policy_bind_date_weekday                                    0
# incident_date_year                                       2015
# incident_date_month                                         2
# incident_date_day                                          19
# incident_date_weekday                                       3
# policy_bind_date_diff                                    2401
# incident_date_diff                                       9173
# incident_date&policy_bind_date_diff                      6772
#
#                                                      993  \
# months_as_customer                                   334
# age                                                   47
# policy_number                                     156694
# policy_bind_date                     2001-05-24 00:00:00
# policy_state                                          IL
# policy_csl                                      500/1000
# policy_deductable                                    500
# policy_annual_premium                            1238.89
# umbrella_limit                                         0
# insured_zip                                       600561
# insured_sex                                         MALE
# insured_education_level                          Masters
# insured_occupation                       protective-serv
# insured_hobbies                                 sleeping
# insured_relationship                      other-relative
# capital-gains                                          0
# capital-loss                                           0
# incident_date                        2015-01-31 00:00:00
# incident_type                              Vehicle Theft
# collision_type                                         ?
# incident_severity                           Minor Damage
# authorities_contacted                               None
# incident_state                                        WV
# incident_city                                  Northbend
# incident_location                           9154 MLK Hwy
# incident_hour_of_the_day                               3
# number_of_vehicles_involved                            1
# property_damage                                        ?
# bodily_injuries                                        0
# witnesses                                              3
# police_report_available                               NO
# total_claim_amount                                  6240
# injury_claim                                         960
# property_claim                                       960
# vehicle_claim                                       4320
# auto_make                                           Ford
# auto_model                                        Fusion
# auto_year                                           2011
# fraud_reported                                       NaN
# _c39                                                 NaN
# policy_bind_date_year                               2001
# policy_bind_date_month                                 5
# policy_bind_date_day                                  24
# policy_bind_date_weekday                               3
# incident_date_year                                  2015
# incident_date_month                                    1
# incident_date_day                                     31
# incident_date_weekday                                  5
# policy_bind_date_diff                               4154
# incident_date_diff                                  9154
# incident_date&policy_bind_date_diff                 5000
#
#                                                           994  \
# months_as_customer                                        282
# age                                                        43
# policy_number                                          982678
# policy_bind_date                          2006-07-19 00:00:00
# policy_state                                               OH
# policy_csl                                            250/500
# policy_deductable                                         500
# policy_annual_premium                                 1452.27
# umbrella_limit                                              0
# insured_zip                                            611996
# insured_sex                                              MALE
# insured_education_level                                    MD
# insured_occupation                            farming-fishing
# insured_hobbies                                   video-games
# insured_relationship                            not-in-family
# capital-gains                                           75800
# ...
# umbrella_limit                                   9000000
# insured_zip                                       601748
# insured_sex                                       FEMALE
# insured_education_level                          College
# insured_occupation                        prof-specialty
# insured_hobbies                                 kayaking
# insured_relationship                       not-in-family
# capital-gains                                          0
# capital-loss                                      -78600
# incident_date                        2015-01-30 00:00:00
# incident_type                                 Parked Car
# collision_type                                         ?
# incident_severity                         Trivial Damage
# authorities_contacted                               None
# incident_state                                        WV
# incident_city                                  Arlington
# incident_location                            5540 Sky St
# incident_hour_of_the_day                               9
# number_of_vehicles_involved                            1
# property_damage                                       NO
# bodily_injuries                                        0
# witnesses                                              1
# police_report_available                              YES
# total_claim_amount                                  4700
# injury_claim                                         940
# property_claim                                       470
# vehicle_claim                                       3290
# auto_make                                          Dodge
# auto_model                                          Neon
# auto_year                                           2002
# fraud_reported                                       NaN
# _c39                                                 NaN
# policy_bind_date_year                               1999
# policy_bind_date_month                                 8
# policy_bind_date_day                                  15
# policy_bind_date_weekday                               6
# incident_date_year                                  2015
# incident_date_month                                    1
# incident_date_day                                     30
# incident_date_weekday                                  4
# policy_bind_date_diff                               3506
# incident_date_diff                                  9153
# incident_date&policy_bind_date_diff                 5647
#
#                                                          996  \
# months_as_customer                                       297
# age                                                       47
# policy_number                                         272330
# policy_bind_date                         2009-11-29 00:00:00
# policy_state                                              IN
# policy_csl                                           250/500
# policy_deductable                                        500
# policy_annual_premium                                1616.65
# umbrella_limit                                       7000000
# insured_zip                                           456363
# insured_sex                                             MALE
# insured_education_level                                   MD
# insured_occupation                              adm-clerical
# insured_hobbies                                       movies
# insured_relationship                               unmarried
# capital-gains                                              0
# capital-loss                                          -59500
# incident_date                            2015-01-16 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                                Side Collision
# incident_severity                                 Total Loss
# authorities_contacted                                   Fire
# incident_state                                            WV
# incident_city                                       Columbus
# incident_location                           1087 Flute Drive
# incident_hour_of_the_day                                   0
# number_of_vehicles_involved                                3
# property_damage                                            ?
# bodily_injuries                                            0
# witnesses                                                  3
# police_report_available                                  YES
# total_claim_amount                                     44400
# injury_claim                                            5550
# property_claim                                          5550
# vehicle_claim                                          33300
# auto_make                                               Jeep
# auto_model                                    Grand Cherokee
# auto_year                                               1999
# fraud_reported                                           NaN
# _c39                                                     NaN
# policy_bind_date_year                                   2009
# policy_bind_date_month                                    11
# policy_bind_date_day                                      29
# policy_bind_date_weekday                                   6
# incident_date_year                                      2015
# incident_date_month                                        1
# incident_date_day                                         16
# incident_date_weekday                                      4
# policy_bind_date_diff                                   7265
# incident_date_diff                                      9139
# incident_date&policy_bind_date_diff                     1874
#
#                                                           997  \
# months_as_customer                                        251
# age                                                        39
# policy_number                                          315631
# policy_bind_date                          1999-04-09 00:00:00
# policy_state                                               IN
# policy_csl                                           500/1000
# policy_deductable                                        2000
# policy_annual_premium                                 1231.98
# umbrella_limit                                              0
# insured_zip                                            612908
# insured_sex                                            FEMALE
# insured_education_level                             Associate
# insured_occupation                              other-service
# insured_hobbies                                        hiking
# insured_relationship                            not-in-family
# capital-gains                                               0
# capital-loss                                           -31700
# incident_date                             2015-01-08 00:00:00
# incident_type                        Single Vehicle Collision
# collision_type                                 Rear Collision
# incident_severity                                Minor Damage
# authorities_contacted                                  Police
# incident_state                                             NY
# incident_city                                       Hillsdale
# incident_location                            1381 Francis Ave
# incident_hour_of_the_day                                   10
# number_of_vehicles_involved                                 1
# property_damage                                           YES
# bodily_injuries                                             0
# witnesses                                                   0
# police_report_available                                     ?
# total_claim_amount                                      44240
# injury_claim                                             5530
# property_claim                                           5530
# vehicle_claim                                           33180
# auto_make                                               Dodge
# auto_model                                                RAM
# auto_year                                                1997
# fraud_reported                                            NaN
# _c39                                                      NaN
# policy_bind_date_year                                    1999
# policy_bind_date_month                                      4
# policy_bind_date_day                                        9
# policy_bind_date_weekday                                    4
# incident_date_year                                       2015
# incident_date_month                                         1
# incident_date_day                                           8
# incident_date_weekday                                       3
# policy_bind_date_diff                                    3378
# incident_date_diff                                       9131
# incident_date&policy_bind_date_diff                      5753
#
#                                                          998  \
# months_as_customer                                        54
# age                                                       35
# policy_number                                         445195
# policy_bind_date                         2010-09-27 00:00:00
# policy_state                                              IN
# policy_csl                                           100/300
# policy_deductable                                        500
# policy_annual_premium                                1261.28
# umbrella_limit                                             0
# insured_zip                                           453265
# insured_sex                                           FEMALE
# insured_education_level                                   MD
# insured_occupation                           protective-serv
# insured_hobbies                                       hiking
# insured_relationship                               unmarried
# capital-gains                                          68500
# capital-loss                                          -42100
# incident_date                            2015-02-25 00:00:00
# incident_type                        Multi-vehicle Collision
# collision_type                                Side Collision
# incident_severity                               Minor Damage
# authorities_contacted                                   Fire
# incident_state                                            VA
# incident_city                                    Springfield
# incident_location                           5028 Maple Ridge
# incident_hour_of_the_day                                  21
# number_of_vehicles_involved                                3
# property_damage                                          YES
# bodily_injuries                                            2
# witnesses                                                  0
# police_report_available                                    ?
# total_claim_amount                                     79090
# injury_claim                                           14380
# property_claim                                          7190
# vehicle_claim                                          57520
# auto_make                                             Nissan
# auto_model                                            Maxima
# auto_year                                               2012
# fraud_reported                                           NaN
# _c39                                                     NaN
# policy_bind_date_year                                   2010
# policy_bind_date_month                                     9
# policy_bind_date_day                                      27
# policy_bind_date_weekday                                   0
# incident_date_year                                      2015
# incident_date_month                                        2
# incident_date_day                                         25
# incident_date_weekday                                      2
# policy_bind_date_diff                                   7567
# incident_date_diff                                      9179
# incident_date&policy_bind_date_diff                     1612
#
#                                                           999
# months_as_customer                                        155
# age                                                        34
# policy_number                                          914815
# policy_bind_date                          1990-09-27 00:00:00
# policy_state                                               IN
# policy_csl                                            100/300
# policy_deductable                                         500
# policy_annual_premium                                 1706.79
# umbrella_limit                                              0
# insured_zip                                            462479
# insured_sex                                              MALE
# insured_education_level                               Masters
# insured_occupation                            protective-serv
# insured_hobbies                                       dancing
# insured_relationship                           other-relative
# capital-gains                                               0
# capital-loss                                                0
# incident_date                             2015-01-07 00:00:00
# incident_type                        Single Vehicle Collision
# collision_type                                Front Collision
# incident_severity                                Minor Damage
# authorities_contacted                               Ambulance
# incident_state                                             OH
# incident_city                                       Hillsdale
# incident_location                               9706 MLK Lane
# incident_hour_of_the_day                                    1
# number_of_vehicles_involved                                 1
# property_damage                                            NO
# bodily_injuries                                             1
# witnesses                                                   1
# police_report_available                                   YES
# total_claim_amount                                      77040
# injury_claim                                             8560
# property_claim                                           8560
# vehicle_claim                                           59920
# auto_make                                               Honda
# auto_model                                              Civic
# auto_year                                                1998
# fraud_reported                                            NaN
# _c39                                                      NaN
# policy_bind_date_year                                    1990
# policy_bind_date_month                                      9
# policy_bind_date_day                                       27
# policy_bind_date_weekday                                    3
# incident_date_year                                       2015
# incident_date_month                                         1
# incident_date_day                                           7
# incident_date_weekday                                       2
# policy_bind_date_diff                                     262
# incident_date_diff                                       9130
# incident_date&policy_bind_date_diff                      8868
#
# [51 rows x 1000 columns]

# %% [markdown]
# #### 构造交叉业务特征

# %%
datas['injury_claim_pct'] = datas['injury_claim']/datas['total_claim_amount']
datas['property_claim_pct'] = datas['property_claim']/datas['total_claim_amount']
datas['vehicle_claim_pct'] = datas['vehicle_claim']/datas['total_claim_amount']

# %%
datas['is_injury_claim'] = datas['injury_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_property_claim'] = datas['property_claim'].apply(lambda x: '1' if x >0 else '0')
datas['is_vehicle_claim'] = datas['vehicle_claim'].apply(lambda x: '1' if x >0 else '0')

# %%
datas['incident_type_&_is_injury_claim'] = datas['incident_type'] + '_' + datas['is_injury_claim']
datas['incident_type_&_is_property_claim'] = datas['incident_type'] + '_' + datas['is_property_claim']
datas['incident_type_&_is_vehicle_claim'] = datas['incident_type'] + '_' + datas['is_vehicle_claim']

datas['collision_type_&_is_injury_claim'] = datas['collision_type'] + '_' + datas['is_injury_claim']
datas['collision_type_&_is_property_claim'] = datas['collision_type'] + '_' + datas['is_property_claim']
datas['collision_type_&_is_vehicle_claim'] = datas['collision_type'] + '_' + datas['is_vehicle_claim']

# %%
datas['umbrella_limit_2_total_claim_amount'] = datas['umbrella_limit']/datas['total_claim_amount']

# %%
# datas['G/L'] = datas['capital-gains'] + datas['capital-loss']

# %%
datas['incident_location_type'] = datas['incident_location'].apply(lambda x: x.split()[-1])
datas['incident_location_street'] = datas['incident_location'].apply(lambda x: ' '.join(x.split()[-2:]))

# %%
#购车年份与投保年份之差
datas['policy_bind_date_year&auto_year_diff'] = datas['policy_bind_date_year'] - datas['auto_year']

#购车年份与出险年份之差
datas['incident_date_year&auto_year_diff'] = datas['incident_date_year'] - datas['auto_year']

#成为客户的时长与购报后出险时长之差
datas['duration'] = round((datas['incident_date'] - datas['policy_bind_date']).dt.days/30) - datas['months_as_customer']

# %%
#出险情况2
datas['incident_type&collision_type'] = (datas['incident_type'] + "_" + datas['collision_type'])

datas['incident_type&incident_severity'] = (datas['incident_type'] + "_" + datas['incident_severity'])
datas['collision_type&incident_severity'] = (datas['collision_type'] + "_" + datas['incident_severity'])

datas['incident_type&bodily_injuries'] = (datas['incident_type'] + "_" + datas['bodily_injuries'].apply(lambda x : str(x)))
datas['collision_type&bodily_injuries'] = (datas['collision_type'] + "_" + datas['bodily_injuries'].apply(lambda x : str(x)))

datas['incident_type&property_damage'] = (datas['incident_type'] + "_" + datas['property_damage'])
datas['collision_type&property_damage'] = (datas['collision_type'] + "_" + datas['property_damage'])

datas['incident_type&collision_type&incident_severity&bodily_injuries&property_damage'] = (datas['incident_type'] + "_" + datas['collision_type'] + "_" + datas['incident_severity'] 
 + "_" + datas['bodily_injuries'].apply(lambda x : str(x)) + "_" + datas['property_damage'])

# %%
#出险车信息
datas['auto_make&auto_model'] = datas['auto_make'] + "_" + datas['auto_model']

# %%
# datas[['incident_type', 'collision_type', 'policy_csl', 'policy_annual_premium', 'umbrella_limit', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'capital-gains', 'capital-loss']][datas['fraud_reported'] > 0]

# %%
#检查单个特征
datas.incident_location.nunique()
# datas.incident_location.value_counts()
# Out:
# 1000

# %%
datas.drop(['policy_bind_date', 'incident_date', '_c39', 'incident_location', 'policy_number', 'insured_zip', 'auto_make', 'auto_model'], axis= 1, inplace=True)

# %%
# from sklearn.preprocessing import LabelEncoder

# %%
cat_columns = datas.select_dtypes(include= 'O').columns

# %%
# for col in cat_columns:
#     le = LabelEncoder()
#     datas[col] = le.fit_transform(datas[col])

# datas[cat_columns]

# %%
# 数据集切分
train = datas[datas['fraud_reported'].notnull()]
test = datas[datas['fraud_reported'].isnull()]

# %%
train_X = train.drop(columns=['fraud_reported'])
train_y = train['fraud_reported']
test_X = test.drop(columns=['fraud_reported'])

# %% [markdown]
# ## 使用五折交叉验证的catboost 训练

# %%
from sklearn.model_selection import StratifiedKFold, KFold
import catboost as cb
from catboost import CatBoostClassifier, cv, Pool

# %%
# ### 标记分类变量
# categorical_fea = ['initialListStatus', 'employmentTitle', 'applicationType', 
#                    'title', 'policyCode', 'purpose', 'regionCode', 'postCode',
#                    'verificationStatus', 'homeOwnership']

categorical_fea = list(cat_columns)

# %%
# for i in data_X.columns:
#     if i in categorical_fea:
#         data_X[i] = data_X[i].astype('str')

# %%
# for i in data_X_testA.columns:
#     if i in categorical_fea:
#         data_X_testA[i] = data_X_testA[i].astype('str')

# %%
clfs = []
answers = []
mean_score = 0
cv_scores = []
NFOLD = 5
seed = 2022
CB_INFO_PATH = './catboost_info'

# %%
kf = StratifiedKFold(n_splits=NFOLD, shuffle=True, random_state=seed)

# %%
from catboost.utils import get_gpu_device_count
print('I see %i GPU devices' % get_gpu_device_count())
# Out:
# I see 0 GPU devices

# %%
cv_cat_model = cb.CatBoostClassifier(loss_function='Logloss', eval_metric='AUC', 
                                     iterations=20000, #max_leaves=2**6-1, 
                                     depth=6, learning_rate=0.005,
                                     random_state=2022, od_type="Iter",
#                                      subsample=0.8, colsample_bylevel=0.8, 
                                     min_data_in_leaf=3, l2_leaf_reg=0.5,
                                     scale_pos_weight = 2.5,
#                                      use_best_model=True, 
                                     metric_period=100)

# %%
for fold, (train_index, val_index) in enumerate(kf.split(train_X, train_y)):
    X_train_fold, X_val_fold = train_X.iloc[train_index], train_X.iloc[val_index]
    y_train_fold, y_val_fold = train_y.iloc[train_index], train_y.iloc[val_index]
    
    print("fold:", fold)
    clf = cv_cat_model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold),
                           verbose=100, 
                           cat_features=categorical_fea,
                           )
    clfs.append(clf)

    pred_val_fold = clfs[fold].predict(X_val_fold, prediction_type='Probability',
                                       ntree_end = clfs[fold].get_best_iteration())[:,-1]
    
    print('cat验证的auc:{}'.format(roc_auc_score(y_val_fold, pred_val_fold)))
    mean_score += roc_auc_score(y_val_fold, pred_val_fold) / NFOLD
    cv_scores.append(roc_auc_score(y_val_fold, pred_val_fold))

    pred = clfs[fold].predict(test_X, prediction_type='Probability',
                              ntree_end = clfs[fold].get_best_iteration())[:,-1]
    answers.append(pred)
# Out:
# fold: 0
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	test: 0.8440171	best: 0.8440171 (0)	total: 118ms	remaining: 39m 15s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8696581197
# bestIteration = 14
#
# Shrink model to first 15 iterations.
# cat验证的auc:0.8600427350427351
# fold: 1
# 0:	test: 0.8579060	best: 0.8579060 (0)	total: 70.7ms	remaining: 23m 32s
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.9017094017
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# cat验证的auc:0.8952991452991452
# fold: 2
# 0:	test: 0.8360043	best: 0.8360043 (0)	total: 60.9ms	remaining: 20m 17s
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.9033119658
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# cat验证的auc:0.8360042735042734
# fold: 3
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	test: 0.8301282	best: 0.8301282 (0)	total: 60.8ms	remaining: 20m 15s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8739316239
# bestIteration = 11
#
# Shrink model to first 12 iterations.
# cat验证的auc:0.8418803418803419
# fold: 4
# 0:	test: 0.7467949	best: 0.7467949 (0)	total: 62.3ms	remaining: 20m 45s
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8028846154
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# cat验证的auc:0.7911324786324786
# fold: 5
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	test: 0.8493590	best: 0.8493590 (0)	total: 61.8ms	remaining: 20m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8830128205
# bestIteration = 3
#
# Shrink model to first 4 iterations.
# cat验证的auc:0.8541666666666667
# fold: 6
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	test: 0.8712607	best: 0.8712607 (0)	total: 71ms	remaining: 23m 39s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.936965812
# bestIteration = 35
#
# Shrink model to first 36 iterations.
# cat验证的auc:0.9358974358974359
# fold: 7
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	test: 0.8878205	best: 0.8878205 (0)	total: 62.7ms	remaining: 20m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.9075854701
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# cat验证的auc:0.8878205128205129
# fold: 8
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	test: 0.9583333	best: 0.9583333 (0)	total: 61.9ms	remaining: 20m 37s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.9780982906
# bestIteration = 4
#
# Shrink model to first 5 iterations.
# cat验证的auc:0.9759615384615384
# fold: 9
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	test: 0.8818369	best: 0.8818369 (0)	total: 63.7ms	remaining: 21m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.9035087719
# bestIteration = 4
#
# Shrink model to first 5 iterations.
# cat验证的auc:0.8864809081527347

# %%
print("cat_scotrainre_list:{}".format(cv_scores))
print("cat_score_mean:{}".format(np.mean(cv_scores)))
print("cat_score_std:{}".format(np.std(cv_scores)))
# Out:
# cat_scotrainre_list:[0.8600427350427351, 0.8952991452991452, 0.8360042735042734, 0.8418803418803419, 0.7911324786324786, 0.8541666666666667, 0.9358974358974359, 0.8878205128205129, 0.9759615384615384, 0.8864809081527347]
# cat_score_mean:0.8764686036357862
# cat_score_std:0.04989737589681912

# %%
#最终加权平均的预测结果
cat_pre=sum(answers)/NFOLD
cat_pre
# Out:
# array([0.47626881, 0.51579695, 0.47443731, 0.47606637, 0.47487242,
#        0.47672481, 0.4756046 , 0.47455183, 0.47559588, 0.47425319,
#        0.47536411, 0.4734496 , 0.51590927, 0.47624116, 0.47322468,
#        0.51534503, 0.47525071, 0.47551028, 0.52007971, 0.47482024,
#        0.47490324, 0.47659505, 0.51264022, 0.47553237, 0.4741492 ,
#        0.51625511, 0.47535279, 0.47389808, 0.52609363, 0.4746964 ,
#        0.51658198, 0.47505882, 0.51618675, 0.47637964, 0.47340828,
#        0.47688113, 0.51605373, 0.47406961, 0.4764513 , 0.47406192,
#        0.51691598, 0.47652283, 0.47494282, 0.47524334, 0.47638281,
#        0.47597233, 0.47477261, 0.47255475, 0.51661579, 0.47313118,
#        0.47658721, 0.47568509, 0.47405941, 0.51554653, 0.51533016,
#        0.47649938, 0.47573806, 0.51619042, 0.47343009, 0.51670999,
#        0.4759902 , 0.47596603, 0.47447317, 0.51645159, 0.47476022,
#        0.47523434, 0.52407754, 0.51590036, 0.47481613, 0.4748374 ,
#        0.47574859, 0.47541095, 0.5158206 , 0.52521463, 0.47396383,
#        0.47438111, 0.47542717, 0.47430803, 0.51643424, 0.47458404,
#        0.47440658, 0.47389832, 0.51683005, 0.47512437, 0.47304924,
#        0.47482594, 0.47671   , 0.47648976, 0.47599781, 0.51662921,
#        0.47483644, 0.51622726, 0.51620888, 0.47491332, 0.4734015 ,
#        0.47588741, 0.47496906, 0.47542952, 0.51621143, 0.47435625,
#        0.47660892, 0.51598007, 0.47519229, 0.47549611, 0.47552261,
#        0.52299544, 0.5157418 , 0.51635713, 0.47565722, 0.47442734,
#        0.4755066 , 0.47483966, 0.47612488, 0.47651681, 0.47476174,
#        0.5158688 , 0.52501777, 0.47264233, 0.5159863 , 0.47361302,
#        0.47668256, 0.47638626, 0.51697951, 0.51440333, 0.47636285,
#        0.51581665, 0.47619237, 0.47343558, 0.52420862, 0.47407775,
#        0.47530258, 0.51611261, 0.47661745, 0.47594776, 0.47298923,
#        0.4726593 , 0.47444376, 0.51609233, 0.51706278, 0.47170239,
#        0.47647892, 0.4761742 , 0.51654385, 0.47655963, 0.5161543 ,
#        0.51602612, 0.47500986, 0.47345329, 0.47577273, 0.47492898,
#        0.47568289, 0.51324157, 0.51583345, 0.51624894, 0.47370815,
#        0.47395386, 0.51645053, 0.47470637, 0.4767913 , 0.47661151,
#        0.51537973, 0.47331032, 0.51634065, 0.51220633, 0.51640492,
#        0.51657422, 0.47428099, 0.47298248, 0.51642993, 0.47360284,
#        0.47424454, 0.47652747, 0.51645249, 0.51632887, 0.47384625,
#        0.51704952, 0.4750515 , 0.47514089, 0.47470729, 0.47482121,
#        0.47539974, 0.47455085, 0.47301189, 0.47733975, 0.47429559,
#        0.51545998, 0.47485478, 0.51656102, 0.4774664 , 0.47649379,
#        0.47640632, 0.47468108, 0.4756982 , 0.51666738, 0.51589095,
#        0.47326047, 0.47515049, 0.47550183, 0.47617337, 0.51381919,
#        0.47526861, 0.4731064 , 0.52443341, 0.47423843, 0.47474846,
#        0.47494283, 0.47602901, 0.47528754, 0.47561454, 0.47340802,
#        0.4759159 , 0.47533423, 0.47417408, 0.47396229, 0.51625433,
#        0.47460638, 0.51588669, 0.47559103, 0.47582488, 0.51592861,
#        0.47585431, 0.47659355, 0.47607724, 0.47446329, 0.47537993,
#        0.51720617, 0.4745743 , 0.47641604, 0.5202949 , 0.47571069,
#        0.47468853, 0.47656257, 0.47455716, 0.47495868, 0.51628818,
#        0.52014891, 0.47756571, 0.4750967 , 0.47433082, 0.47476745,
#        0.5200048 , 0.47450542, 0.4756677 , 0.47675944, 0.47292131,
#        0.51582578, 0.47492974, 0.47306928, 0.47533614, 0.47423233,
#        0.51702204, 0.51620279, 0.51630455, 0.47503836, 0.47610428,
#        0.4750169 , 0.51557913, 0.47634895, 0.52668952, 0.47608014,
#        0.51523388, 0.47626649, 0.51573269, 0.47263869, 0.4727722 ,
#        0.47495578, 0.47466155, 0.47461269, 0.47237174, 0.47620794,
#        0.517071  , 0.47513672, 0.47497064, 0.51661126, 0.51656745,
#        0.47590457, 0.47367801, 0.47525278, 0.51947608, 0.47475179,
#        0.47388007, 0.4755238 , 0.4751682 , 0.5155298 , 0.51572578,
#        0.47546346, 0.51667527, 0.47526852, 0.51674614, 0.51833114,
#        0.47504274, 0.51566824, 0.51578276, 0.47339891, 0.51571889,
#        0.47263155, 0.4734508 , 0.47504321, 0.47436782, 0.47454142])

# %%
submission = pd.read_csv('./data/sampleSubmission.csv')
submission['fraud_reported'] = cat_pre
submission.to_csv('./submission/submission_KF_catboost.csv', index=None)
